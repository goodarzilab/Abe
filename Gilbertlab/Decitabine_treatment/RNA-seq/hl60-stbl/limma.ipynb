# %% [markdown]
# # CRIES
# ### Counting Reads for Intronic and Exonic Segments
# https://github.com/csglab/CRIES
#
#
# **Step 1. Creating GTF annotation files**
#
# Intron and exon annotations for `gencode.v34` made within my notebook named `build-genome.ipynb`.
#
# **Step 2. Mapping reads**
#
# `STAR`
#
# **Step 3. Counting reads that map to intronic or exonic segments of each gene**
#
# `featureCounts`
# http://bioinf.wehi.edu.au/featureCounts/

# %%
cat _sh/loop_featureCounts.sh
# Out:
# #!/usr/bin/env bash
# #loop featureCounts intron and exon counts
#
# set -o errexit
# set -o nounset
# set -o xtrace
#
# bam_folder='/rumi/shams/abe/Gilbertlab/Decitabine_treatment/RNA-seq/hl60-bam'
# stbl_folder='/rumi/shams/abe/Gilbertlab/Decitabine_treatment/RNA-seq/hl60-stbl'
# GTF_index='/rumi/shams/genomes/hg38/hg38_ensemble_'
#
# main() {
#   local f
#   for f in ${bam_folder}/*.bam; do
#     base=`basename $f`
#     sample=${base/.bam/};
#     echo -e '----------------------- ' $sample  ' -----------------------'
#     featureCounts -M -T 18 -t intron -g gene_id -a ${GTF_index}introns.gtf -o ${stbl_folder}/counts/${sample}_introns.txt ${f}
#     featureCounts -M -T 18 -t exon -g gene_id -a ${GTF_index}consExons.gtf -o ${stbl_folder}/counts/${sample}_exons.txt ${f}
#   done
# }
#
# mkdir -p $stbl_folder
# mkdir -p ${stbl_folder}/counts
#
# main

# %%
# !multiqc counts/*_exons.txt.summary -f -n counts-exons-multiqc.html
# !multiqc counts/*_introns.txt.summary -f -n counts-introns-multiqc.html
# Out:
# [INFO   ]         multiqc : This is MultiQC v1.9
# [INFO   ]         multiqc : Template    : default
# [INFO   ]         multiqc : Searching   : /rumi/shams/abe/Gilbertlab/Decitabine_treatment/RNA-seq/hl60-stbl/counts/120h_DMSO_rep1_exons.txt.summary
# [INFO   ]         multiqc : Searching   : /rumi/shams/abe/Gilbertlab/Decitabine_treatment/RNA-seq/hl60-stbl/counts/120h_DMSO_rep2_exons.txt.summary
# [INFO   ]         multiqc : Searching   : /rumi/shams/abe/Gilbertlab/Decitabine_treatment/RNA-seq/hl60-stbl/counts/120h_treated_rep1_exons.txt.summary
# [INFO   ]         multiqc : Searching   : /rumi/shams/abe/Gilbertlab/Decitabine_treatment/RNA-seq/hl60-stbl/counts/120h_treated_rep2_exons.txt.summary
# [INFO   ]         multiqc : Searching   : /rumi/shams/abe/Gilbertlab/Decitabine_treatment/RNA-seq/hl60-stbl/counts/6h_DMSO_rep1_exons.txt.summary
# [INFO   ]         multiqc : Searching   : /rumi/shams/abe/Gilbertlab/Decitabine_treatment/RNA-seq/hl60-stbl/counts/6h_DMSO_rep2_exons.txt.summary
# [INFO   ]         multiqc : Searching   : /rumi/shams/abe/Gilbertlab/Decitabine_treatment/RNA-seq/hl60-stbl/counts/6h_treated_rep1_exons.txt.summary
# [INFO   ]         multiqc : Searching   : /rumi/shams/abe/Gilbertlab/Decitabine_treatment/RNA-seq/hl60-stbl/counts/6h_treated_rep2_exons.txt.summary
# [INFO   ]         multiqc : Searching   : /rumi/shams/abe/Gilbertlab/Decitabine_treatment/RNA-seq/hl60-stbl/counts/72h_DMSO_rep1_exons.txt.summary
# [INFO   ]         multiqc : Searching   : /rumi/shams/abe/Gilbertlab/Decitabine_treatment/RNA-seq/hl60-stbl/counts/72h_DMSO_rep2_exons.txt.summary
# [INFO   ]         multiqc : Searching   : /rumi/shams/abe/Gilbertlab/Decitabine_treatment/RNA-seq/hl60-stbl/counts/72h_treated_rep1_exons.txt.summary
# [INFO   ]         multiqc : Searching   : /rumi/shams/abe/Gilbertlab/Decitabine_treatment/RNA-seq/hl60-stbl/counts/72h_treated_rep2_exons.txt.summary
# Searching 12 files..  [####################################]  100%
# [INFO   ]  feature_counts : Found 12 reports
# [INFO   ]         multiqc : Compressing plot data
# [INFO   ]         multiqc : Report      : counts-exons-multiqc.html
# [INFO   ]         multiqc : Data        : counts-exons-multiqc_data
# [INFO   ]         multiqc : MultiQC complete
# [INFO   ]         multiqc : This is MultiQC v1.9
# [INFO   ]         multiqc : Template    : default
# [INFO   ]         multiqc : Searching   : /rumi/shams/abe/Gilbertlab/Decitabine_treatment/RNA-seq/hl60-stbl/counts/120h_DMSO_rep1_introns.txt.summary
# [INFO   ]         multiqc : Searching   : /rumi/shams/abe/Gilbertlab/Decitabine_treatment/RNA-seq/hl60-stbl/counts/120h_DMSO_rep2_introns.txt.summary
# [INFO   ]         multiqc : Searching   : /rumi/shams/abe/Gilbertlab/Decitabine_treatment/RNA-seq/hl60-stbl/counts/120h_treated_rep1_introns.txt.summary
# [INFO   ]         multiqc : Searching   : /rumi/shams/abe/Gilbertlab/Decitabine_treatment/RNA-seq/hl60-stbl/counts/120h_treated_rep2_introns.txt.summary
# [INFO   ]         multiqc : Searching   : /rumi/shams/abe/Gilbertlab/Decitabine_treatment/RNA-seq/hl60-stbl/counts/6h_DMSO_rep1_introns.txt.summary
# [INFO   ]         multiqc : Searching   : /rumi/shams/abe/Gilbertlab/Decitabine_treatment/RNA-seq/hl60-stbl/counts/6h_DMSO_rep2_introns.txt.summary
# [INFO   ]         multiqc : Searching   : /rumi/shams/abe/Gilbertlab/Decitabine_treatment/RNA-seq/hl60-stbl/counts/6h_treated_rep1_introns.txt.summary
# [INFO   ]         multiqc : Searching   : /rumi/shams/abe/Gilbertlab/Decitabine_treatment/RNA-seq/hl60-stbl/counts/6h_treated_rep2_introns.txt.summary
# [INFO   ]         multiqc : Searching   : /rumi/shams/abe/Gilbertlab/Decitabine_treatment/RNA-seq/hl60-stbl/counts/72h_DMSO_rep1_introns.txt.summary
# [INFO   ]         multiqc : Searching   : /rumi/shams/abe/Gilbertlab/Decitabine_treatment/RNA-seq/hl60-stbl/counts/72h_DMSO_rep2_introns.txt.summary
# [INFO   ]         multiqc : Searching   : /rumi/shams/abe/Gilbertlab/Decitabine_treatment/RNA-seq/hl60-stbl/counts/72h_treated_rep1_introns.txt.summary
# [INFO   ]         multiqc : Searching   : /rumi/shams/abe/Gilbertlab/Decitabine_treatment/RNA-seq/hl60-stbl/counts/72h_treated_rep2_introns.txt.summary
# Searching 12 files..  [####################################]  100%
# [INFO   ]  feature_counts : Found 12 reports
# [INFO   ]         multiqc : Compressing plot data
# [INFO   ]         multiqc : Report      : counts-introns-multiqc.html
# [INFO   ]         multiqc : Data        : counts-introns-multiqc_data
# [INFO   ]         multiqc : MultiQC complete

# %%
import os
import subprocess
import glob
import warnings
import pandas as pd
import numpy as np

from rpy2.rinterface import RRuntimeWarning
warnings.filterwarnings("ignore")
warnings.filterwarnings("ignore", category=RRuntimeWarning)

# %% [markdown]
# **Step 4. Normalization** - REMBRANDTS

# %% [markdown]
# #### REMoving Bias from Rna-seq ANalysis of Differential Transcript Stability
# [REMBRANDTS](https://github.com/csglab/REMBRANDTS) is a package for analysis of RNA-seq data across multiple samples in order to obtain unbiased estimates of differential mRNA stability. It uses DESeq to obtain estimates of differential pre-mRNA and mature mRNA abundance across samples, and then estimates a gene-specific bias function that is then subtracted from Δexon–Δintron to provide unbiased differential mRNA stability measures.

# %%
stbldir = '/rumi/shams/abe/Gilbertlab/Decitabine_treatment/RNA-seq/hl60-stbl'

# list path to intron and exon count files 
exon_count_files = glob.glob(f'{stbldir}/counts/*_exons.txt')
intron_count_files = glob.glob(f'{stbldir}/counts/*_introns.txt')

# define gene_ids for each count results for exon and intron 
exon_gene_ids = pd.read_table(exon_count_files[0], skiprows=1)['Geneid'].tolist()
intron_gene_ids = pd.read_table(intron_count_files[0], skiprows=1)['Geneid'].tolist()

# read all count tables into one dataframe 
df_exon = pd.DataFrame({}, index=exon_gene_ids)
df_intron = pd.DataFrame({}, index=intron_gene_ids)

for f in exon_count_files:
    counts = pd.read_table(f, skiprows=1).iloc[:, -1].tolist()
    f_n = f.split('/')[-1].replace('_exons.txt', '')
    df_exon[f_n] = counts
for f in intron_count_files:
    counts = pd.read_table(f, skiprows=1).iloc[:, -1].tolist()
    f_n = f.split('/')[-1].replace('_introns.txt', '')
    df_intron[f_n] = counts

samples = ['6h_DMSO_rep1', '6h_DMSO_rep2', '6h_treated_rep1', '6h_treated_rep2',
 '72h_DMSO_rep1', '72h_DMSO_rep2', '72h_treated_rep1', '72h_treated_rep2',
 '120h_DMSO_rep1', '120h_DMSO_rep2', '120h_treated_rep1', '120h_treated_rep2']
# reorder in to same column order as the meta table rows 
df_exon = df_exon[samples] 
df_intron = df_intron[samples]

# %%
# select overlap gene_ids
overlaps = list(set(df_exon.index)&set(df_intron.index))
# subset by overlap gene_ids 
df_exon = df_exon.loc[overlaps, ]
df_intron = df_intron.loc[overlaps, ]

# write input counts 
for c in samples:
    df_exon.loc[:, c].to_csv(f'{stbldir}/counts/{c}_exons.ol.txt', sep='\t', header=None)    
    df_intron.loc[:, c].to_csv(f'{stbldir}/counts/{c}_introns.ol.txt', sep='\t', header=None)

### Prepare REMBRANDTS inputs
# make meta data for running REMBRANDTS
labels = np.repeat(df_exon.columns.tolist(), 2)
files = [f'{labels[i]}_exons.ol.txt' if i%2==0 else f'{labels[i]}_introns.ol.txt' for i in range(len(labels))]
readtypes = ['exonic' if i%2==0 else 'intronic' for i in range(len(labels))]
meta = pd.DataFrame({'Label':labels, 'File':files, 'ReadType':readtypes, 'Batch':1})
meta.to_csv(f'{stbldir}/input_table.txt', index=False, sep='\t')

# %%
# # Run REMBRANDTS
os.chdir('/rumi/shams/abe/Workflows/REMBRANDTS/')
cmd = f'bash REMBRANDTS.sh Decitabine_treatment {stbldir}/input_table.txt {stbldir}/counts/ 0.99 linear'
subprocess.call(cmd , shell=True)

subprocess.call(f'rm -rv {stbldir}/output', shell=True)
subprocess.call(f'mv -v ./out/Decitabine_treatment/ {stbldir}/output', shell=True)
os.chdir(stbldir)

# clean results 
out = pd.read_table(f'{stbldir}/output/stability.filtered.mx.txt', index_col=0)
out.columns = [i.replace('.x','').replace('.','-')[1:] for i in out.columns]
out.columns
out.to_csv(f'{stbldir}/REMBRANDTS.txt', sep='\t')
print('\n********************************** Finished **********************************\n')
# Out:
# ********************************** Finished **********************************

# %% [markdown]
# # Differential stability
# `Limma` is originally design for micro-array experiments which is mainly doing same task as `DESeq2`.  Comparing to RNA expression analysis, RNA stability may have negetive values; `DESeq2` does not support negetive values but `Limma` does. Therefore, we decided to use `Limma` package instead of `DESeq2` for differential analysis.
#
# I've learned how to use limma from this [DataCamp course | differential-expression-analysis-with-limma-in-r](https://campus.datacamp.com/courses/differential-expression-analysis-with-limma-in-r/).
# However, I found these links useful while browsing.
# - http://genomicsclass.github.io/book/pages/using_limma.html
# - https://www.bioconductor.org/packages/devel/workflows/vignettes/RNAseq123/inst/doc/limmaWorkflow.html

# %%
# %reload_ext rpy2.ipython

# %%
# %%R
# library(edgeR)
# library(Biobase)
# library(rtracklayer)
# library(tidyverse)

# %% [markdown]
# Read gene annotations into R

# %%
# %%R
# GTF = '/rumi/shams/genomes/hg38/hg38_ensemble_genes.gtf'
#
# gtf <- rtracklayer::import(GTF)
# gene2name <- gtf[gtf$type == "gene"] %>% data.frame %>% column_to_rownames('gene_id') %>% dplyr::select('gene_name')

# %%
# %%R
# # meta table
# treats  <- rep(c(rep('DMSO',2), rep('treated',2)),3)
# reps    <- rep(c('rep1','rep2'),6)
# hours   <- c(rep('6h',4),rep('72h',4),rep('120h',4))
# hours = factor (hours, levels = c("6h", "72h", "120h"))
#
# samples = paste(hours, treats, reps, sep='_')
# group = paste(hours, treats, sep='.')
#
# meta <- data.frame(
#     time=factor(hours),
#     cond=factor(treats),
#     group=factor(group),
#     sample_id=samples,
#     row.names=samples)
# meta$cond <- relevel(meta$cond, ref='DMSO')
# meta$group <- relevel(meta$group, ref='6h.DMSO')
# meta$time
# Out:
#  [1] 6h   6h   6h   6h   72h  72h  72h  72h  120h 120h 120h 120h
# Levels: 6h 72h 120h

# %%
# %%R
# # Read `REMBRANDTS` results
# counts <- read.table("REMBRANDTS.txt", row.names = 1, stringsAsFactors=FALSE, header=TRUE)
# colnames(counts) <- samples

# %%
# %%R
# # Make annotation dataframe
# ann = data.frame(
#     name=gene2name[rownames(counts),],
#     row.names=rownames(counts)
# )
#
# # Create ExpressionSet object
# eset <- ExpressionSet(
#     assayData = as.matrix(counts),
#     phenoData = AnnotatedDataFrame(meta),
#     featureData = AnnotatedDataFrame(ann)
# )

# %%
# %%R
# # Create design matrix
# design <- model.matrix(~cond + group, meta)
# # Count the number of samples modeled by each coefficient
# colSums(design)
# Out:
#       (Intercept)       condtreated    group120h.DMSO group120h.treated
#                12                 6                 2                 2
#   group6h.treated     group72h.DMSO  group72h.treated
#                 2                 2                 2

# %%
# %%R
# cm = makeContrasts(
#     # contrast design: treatment at 120h vs dmso at 120h
#     log2FC_120h = condtreated + group120h.treated - group120h.DMSO,
# #     # contrast design: treatment at 72h vs dmso at 72h
# #     comp_72 = condtreated + group72h.treated - group72h.DMSO,
#     # contrast design: treatment at 6h vs dmso at 6h
#     log2FC_6h = condtreated + group6h.treated,
#     levels = design
# )
#
# # Fit coefficients
# fit <- lmFit(eset, design)
# # Fit contrasts
# fit2 <- contrasts.fit(fit, contrasts = cm)
# # Calculate t-statistics
# fit2 <- eBayes(fit2)
# # Summarize results
# results <- decideTests(fit2)
# print (summary (results))
# Out:
# Coefficients not estimable: group72h.treated
#        log2FC_120h log2FC_6h
# Down             3         0
# NotSig        4258      4272
# Up              11         0

# %%
# %%R
# results %>% head
# Out:
# TestResults matrix
#                  Contrasts
#                   log2FC_120h log2FC_6h
#   ENSG00000000419           0         0
#   ENSG00000000457           0         0
#   ENSG00000000460           0         0
#   ENSG00000000938           0         0
#   ENSG00000001084           0         0
#   ENSG00000001167           0         0

# %%
# %%R
# volcanoplot(fit2,highlight = 6, names = fit2$genes[,'name'])

# %% [markdown]
# Box plot generator for top hits ..

# %%
# %%R
# temp = fData(eset) %>% rownames_to_column('row')
# gene = temp$row[temp$name == 'ABHD2']
# # Create a boxplot of a given gene
# boxplot(exprs(eset)[gene, ] ~ pData(eset)[, "cond"],main = fData(eset)[gene, "name"])
# boxplot(exprs(eset)[gene, ] ~ pData(eset)[, "time"],main = fData(eset)[gene, "name"])

# %%
# %%R
# temp = fData(eset) %>% rownames_to_column('row')
# gene = temp$row[temp$name == 'SORD']
# # Create a boxplot of a given gene
# boxplot(exprs(eset)[gene, ] ~ pData(eset)[, "cond"],main = fData(eset)[gene, "name"])
# boxplot(exprs(eset)[gene, ] ~ pData(eset)[, "time"],main = fData(eset)[gene, "name"])

# %% [markdown]
# ## Principal Component Analysis (PCA)
# Just like the RNA-seq experssion analysis, sample `72h_treated_rep2` comes up as an outlier. Removing that from the analysis give us a better representation. Therfore, we can see that treated samples at 6h cluster with the non-treated samples which suggest that 6 hours treatment with the drug is not as effective as 72h and 120h. Although, we will check the variant genes in this time-point in the following statistical analysis.

# %%
# %%R
# # Plot principal components labeled by treatment
# col_by_cond=rep(c(rep("black",2), rep("red",2)),3)
# # plotMDS(eset, labels = pData(eset)[, "sample_id"], col=col_by_cond, gene.selection = "common")

# %%
# %%R
# # Plot principal components labeled by treatment
# filter = !eset@phenoData@data$sample_id == '72h_treated_rep2'
# plotMDS(eset[,filter], labels = pData(eset[,filter])[, "time"], col=col_by_cond[filter], gene.selection = "common")

# %% [markdown]
# ## Normalizing and filtering

# %%
# %%R
# # Create new ExpressionSet to store normalized data
# eset_norm <- eset
# # View the distribution of the raw data
# # p0 = plotDensities(eset_norm) #, legend = FALSE)

# %%
# %%R
# # Log tranform
# exprs(eset_norm) <- log(exprs(eset_norm))
# # plotDensities(eset_norm, legend = FALSE)

# %%
# %%R
# # Quantile normalize
# exprs(eset_norm) <- normalizeBetweenArrays(exprs(eset_norm))
# plotDensities(eset_norm, legend = FALSE)

# %% [markdown]
# Let's write normalized RNA-Stabilities into a file.

# %%
# %%R
# ncu <- exprs(eset_norm) %>% replace_na(0)
# write.table(ncu,'stbl_norm_log_quantile.txt', sep="\t", quote=FALSE, col.names=TRUE)
#
# ncu %>% summary
# Out:
#   6h_DMSO_rep1     6h_DMSO_rep2    6h_treated_rep1  6h_treated_rep2
#  Min.   :-9.527   Min.   :-9.527   Min.   :-9.527   Min.   :-9.527
#  1st Qu.:-2.417   1st Qu.:-2.393   1st Qu.:-2.170   1st Qu.:-2.382
#  Median :-1.231   Median :-1.137   Median : 0.000   Median :-1.098
#  Mean   :-1.372   Mean   :-1.345   Mean   :-1.119   Mean   :-1.335
#  3rd Qu.: 0.000   3rd Qu.: 0.000   3rd Qu.: 0.000   3rd Qu.: 0.000
#  Max.   : 0.000   Max.   : 0.000   Max.   : 0.000   Max.   : 0.000
#  72h_DMSO_rep1    72h_DMSO_rep2    72h_treated_rep1  72h_treated_rep2
#  Min.   :-9.527   Min.   :-9.527   Min.   :-9.5268   Min.   :-9.527
#  1st Qu.:-2.230   1st Qu.:-2.301   1st Qu.:-1.9783   1st Qu.:-2.469
#  Median : 0.000   Median : 0.000   Median : 0.0000   Median :-1.389
#  Mean   :-1.175   Mean   :-1.247   Mean   :-0.9717   Mean   :-1.437
#  3rd Qu.: 0.000   3rd Qu.: 0.000   3rd Qu.: 0.0000   3rd Qu.: 0.000
#  Max.   : 0.000   Max.   : 0.000   Max.   : 0.0000   Max.   : 0.000
#  120h_DMSO_rep1   120h_DMSO_rep2   120h_treated_rep1 120h_treated_rep2
#  Min.   :-9.527   Min.   :-9.527   Min.   :-9.527    Min.   :-9.527
#  1st Qu.:-2.358   1st Qu.:-2.506   1st Qu.:-2.246    1st Qu.:-2.203
#  Median :-0.948   Median :-1.483   Median : 0.000    Median : 0.000
#  Mean   :-1.307   Mean   :-1.484   Mean   :-1.190    Mean   :-1.147
#  3rd Qu.: 0.000   3rd Qu.: 0.000   3rd Qu.: 0.000    3rd Qu.: 0.000
#  Max.   : 0.000   Max.   : 0.000   Max.   : 0.000    Max.   : 0.000

# %%
# %%R 
# library(pheatmap)
# # mostVar Calculate the top n most variable genes in a matrix of gene expression data
# # https://rdrr.io/github/abc-igmm/transcripTools/man/mostVar.html
# mostVar <- function(data, n, i_want_most_var = TRUE) {
#   data.var <- apply(data, 1, stats::var)
#   data[order(data.var, decreasing = i_want_most_var)[1:n],] 
# }

# # scale - Z-Score
# fc <- data.frame(
#     apply(exprs(eset_norm) %>% replace_na(0),2,scale, center=TRUE, scale=TRUE), 
#     row.names=fData(eset_norm)$name
# ) 
# # filter most variable genes
# fc = mostVar(fc,40)
# # Plot heatmap
# h1 <- pheatmap(fc,cluster_cols = FALSE,angle_col=45)
# h1

# %%
# %%R
# # Obtain the summary statistics
# stats_120h <- topTable(fit2, coef = "log2FC_120h", number = nrow(fit2),
#                               sort.by = "none")
#
# # Create histograms of the p-values for each contrast
# hist(stats_120h[, "P.Value"])

# %%
# %%R
# # Obtain the summary statistics
# stats_6h <- topTable(fit2, coef = "log2FC_6h", number = nrow(fit2),
#                               sort.by = "none")
#
# # Create histograms of the p-values for each contrast
# hist(stats_6h[, "P.Value"])

# %% [markdown]
# ## Enrichment testing

# %%
# %%R 
# # Extract the entrez gene IDs
# entrez <- rownames(fit2$genes) 
# # Test for enriched KEGG Pathways
# enrich_kegg <- kegga(fit2, geneid = entrez, species = 'Hs')

# # View the top 20 enriched KEGG pathways
# topKEGG(enrich_kegg)

# %% [markdown]
# Here, I write all results into files which includes log2FC and p.values for contrasts at hour 6 and hour 120, plus gene names and gene ids.

# %%
# %%R
# results = data.frame(ensembl_id=rownames(fit2$genes),gene_name=fit2$genes$name,
#           log2FC_120h=fit2$coef[,'log2FC_120h'], p.value_120h=fit2$p.value[,'log2FC_120h'],
#           log2FC_6h=fit2$coef[,'log2FC_6h'], p.value_6h=fit2$p.value[,'log2FC_6h']
#           )  %>%  remove_rownames  %>% arrange(across(everything(), desc))
#
# write.table(results[,c('ensembl_id','log2FC_6h')] , '6h_delta_stbl.txt',
#             quote = F, col.names=FALSE, row.names=FALSE,sep ='\t')
# write.table(results[,c('ensembl_id','log2FC_120h')] , '120h_delta_stbl.txt',
#             quote = F, col.names=FALSE, row.names=FALSE,sep ='\t')
#
# # all results
# write.table(results,
#             'delta_stbl.full.txt', quote = F, col.names=TRUE, row.names=FALSE,sep ='\t')
# # significant results
# write.table(results[results$p.value_120h<0.05  & abs(results$log2FC_120h)>1,],
#             'delta_stbl.sig.txt', quote = F, col.names=TRUE, row.names=FALSE,sep ='\t')

# %% [markdown]
# ### iPAGE

# %%
# %%bash
# declare -a Comp=('6h' '120h')
#
# for C in "${Comp[@]}"; do
# 	mkdir -p ${C}_PAGE
# 	for f in `ls -d /flash/bin/iPAGEv1.0/PAGE_DATA/ANNOTATIONS/human_ensembl*`; do
# 		base=`basename "$f"`
# 		perl $PAGEDIR/page.pl --expfile=${C}_delta_stbl.txt \
# 		--species=$base --exptype=continuous --ebins=11 --nodups=1
# # 		# remove results from previous run
# 		rm -vr ${C}_PAGE/${base}/
# 		mv -v ${C}_delta_stbl.txt_PAGE/ ${C}_PAGE/${base}/
# 	done
# done
# Out:
# Reading expression data ... 1 by 4271... Done.
# Creating hash ... Done
# Reading GO names table ... entering
# Done.
# Reading GO index table ... entering
# Done.
# go_terms_num: 17689
# Creating hash table for gene names in gene ontology index file ... Done.
# gene num = 4271 out of 4271
# Creating hash table for gene ontology names ... Done.
# Populating the GO profile table ... 4271	17689
# Done.
# Writing internal quantized groups ...Done
# 388 hits go_terms_num = 17689
# cat 3925, mi = 0.00532987, methylated histone binding
# cat 2171, mi = 0.00487617, IRE1-mediated unfolded protein response
# cat 2792, mi = 0.00459759, calcium ion transmembrane transport
# cat 4034, mi = 0.00457462, cholesterol biosynthetic process
# cat 781, mi = 0.00447779, phagocytic vesicle membrane
# cat 3268, mi = 0.00445166, myelin sheath
# cat 2013, mi = 0.00438915, endosomal transport
# cat 3814, mi = 0.00435914, apoptotic mitochondrial changes
# cat 1506, mi = 0.00431893, endoplasmic reticulum-Golgi intermediate compartment
# cat 3894, mi = 0.00429806, RNA secondary structure unwinding
# cat 3751, mi = 0.00422595, nuclear-transcribed mRNA poly(A) tail shortening
# cat 4045, mi = 0.00421680, extrinsic apoptotic signaling pathway via death domain receptors
# cat 2695, mi = 0.00421134, synaptic vesicle
# cat 1206, mi = 0.00420295, Ras guanyl-nucleotide exchange factor activity
# cat 1133, mi = 0.00418136, azurophil granule lumen
#
# RESULTS
# Passed: cat 3925, mi = 0.005, pvalue = 0.001, methylated histone binding
# Passed: cat 2171, mi = 0.005, pvalue = 0.001, IRE1-mediated unfolded protein response
# Passed: cat 2792, mi = 0.005, pvalue = 0.004, calcium ion transmembrane transport
# Passed: cat 4034, mi = 0.005, pvalue = 0.002, cholesterol biosynthetic process
# Passed: cat 781, mi = 0.004, pvalue = 0.004, phagocytic vesicle membrane
# Didn't pass (cutoff=0.0050): cat 3268, mi = 0.004, pvalue = 0.007, myelin sheath
# Didn't pass (cutoff=0.0050): cat 2013, mi = 0.004, pvalue = 0.006, endosomal transport
# Passed: cat 3814, mi = 0.004, pvalue = 0.000, apoptotic mitochondrial changes
# Didn't pass (cutoff=0.0050): cat 1506, mi = 0.004, pvalue = 0.008, endoplasmic reticulum-Golgi intermediate compartment
# Didn't pass (cutoff=0.0050): cat 3894, mi = 0.004, pvalue = 0.008, RNA secondary structure unwinding
# Didn't pass (cutoff=0.0050): cat 3751, mi = 0.004, pvalue = 0.007, nuclear-transcribed mRNA poly(A) tail shortening
# Passed: cat 1206, mi = 0.004, pvalue = 0.004, Ras guanyl-nucleotide exchange factor activity
# Didn't pass (cutoff=0.0050): cat 1850, mi = 0.004, pvalue = 0.006, symporter activity
# Didn't pass (cutoff=0.0050): cat 1330, mi = 0.004, pvalue = 0.008, Hsp90 protein binding
# Passed: cat 1721, mi = 0.004, pvalue = 0.003, negative regulation of extrinsic apoptotic signaling pathway via death domain receptors
# Didn't pass (cutoff=0.0050): cat 1117, mi = 0.004, pvalue = 0.009, ligase activity
# Passed: cat 299, mi = 0.004, pvalue = 0.001, response to wounding
# Didn't pass (cutoff=0.0050): cat 2642, mi = 0.004, pvalue = 0.014, DNA replication initiation
# Didn't pass (cutoff=0.0050): cat 56, mi = 0.004, pvalue = 0.013, cristae formation
# Didn't pass (cutoff=0.0050): cat 1489, mi = 0.004, pvalue = 0.017, ubiquitin binding
# Passed: cat 10198, mi = 0.004, pvalue = 0.002, nuclear export
# Didn't pass (cutoff=0.0050): cat 1965, mi = 0.004, pvalue = 0.021, cellular protein modification process
# Didn't pass (cutoff=0.0050): cat 308, mi = 0.004, pvalue = 0.030, neuron projection development
# Didn't pass (cutoff=0.0050): cat 1119, mi = 0.004, pvalue = 0.031, tRNA aminoacylation for protein translation
# Didn't pass (cutoff=0.0050): cat 4381, mi = 0.004, pvalue = 0.015, caveola
# Didn't pass (cutoff=0.0050): cat 2363, mi = 0.004, pvalue = 0.014, positive regulation of protein serine/threonine kinase activity
# Didn't pass (cutoff=0.0050): cat 1118, mi = 0.004, pvalue = 0.033, aminoacyl-tRNA ligase activity
# Didn't pass (cutoff=0.0050): cat 421, mi = 0.004, pvalue = 0.007, cognition
# Didn't pass (cutoff=0.0050): cat 1876, mi = 0.004, pvalue = 0.027, catalytic step 2 spliceosome
# Didn't pass (cutoff=0.0050): cat 91, mi = 0.004, pvalue = 0.008, integral component of mitochondrial inner membrane
# Didn't pass (cutoff=0.0050): cat 3490, mi = 0.004, pvalue = 0.046, ruffle membrane
# Didn't pass (cutoff=0.0050): cat 1533, mi = 0.003, pvalue = 0.025, transcription factor activity, RNA polymerase II distal enhancer sequence-specific binding
# Didn't pass (cutoff=0.0050): cat 4509, mi = 0.003, pvalue = 0.027, regulation of mitophagy
# Didn't pass (cutoff=0.0050): cat 4332, mi = 0.003, pvalue = 0.036, mRNA polyadenylation
# Didn't pass (cutoff=0.0050): cat 960, mi = 0.003, pvalue = 0.031, regulation of protein phosphorylation
# Didn't pass (cutoff=0.0050): cat 3047, mi = 0.003, pvalue = 0.044, tRNA binding
# Didn't pass (cutoff=0.0050): cat 1553, mi = 0.003, pvalue = 0.051, positive regulation of protein targeting to mitochondrion
# Didn't pass (cutoff=0.0050): cat 1865, mi = 0.003, pvalue = 0.028, nucleosome binding
# Didn't pass (cutoff=0.0050): cat 278, mi = 0.003, pvalue = 0.047, cytokine-mediated signaling pathway
# Didn't pass (cutoff=0.0050): cat 2101, mi = 0.003, pvalue = 0.040, centriole
# Didn't pass (cutoff=0.0050): cat 546, mi = 0.003, pvalue = 0.052, double-strand break repair
# Total number of categories evaluated = 54.
# Number of categories that passed the tests = 10
# Number of clusters: 11
# calculating the p-value matrix.
# Allocating memory ... Done
# Done
# Writing the p-value matrix to file...Done
# perl /flash/bin/iPAGEv1.0/SCRIPTS/mi_go_draw_matrix.pl  --pvaluematrixfile=6h_delta_stbl.txt_PAGE/pvmatrix.txt --expfile=6h_delta_stbl.txt --order=1 --draw_sample_heatmap=false --min=-3 --max=3 --cluster=5 --quantized=0
# Reading matrix ... Done.
# Cluster rows .. best merge is 1, 9, 0.440486531870682
# best merge is 2, 4, 0.540507761534931
# best merge is 0, 6, 0.669892820698065
# best merge is 3, 7, 0.675074902778651
# best merge is 2, 8, 0.677342102404226
# best merge is 1, 3, 0.847890226828479
# order classes
# 2 - 1.67473205174516
# 2 - 1.1012163296767
# 3 - 1.4038459009951
# 2 - 1.68768725694663
# 1 9
# 0 6
# 2 4 8
# 3 7
# 5
# Done.Start drawing
# 0.66	-0.76
# phagocytic vesicle membrane, GO:0030670
# cholesterol biosynthetic process, GO:0006695
# apoptotic mitochondrial changes, GO:0008637
# nuclear export, GO:0051168
# Ras guanyl-nucleotide exchange factor activity, GO:0005088
# calcium ion transmembrane transport, GO:0070588
# IRE1-mediated unfolded protein response, GO:0036498
# negative regulation of extrinsic apoptotic signaling pathway via death domain receptors, GO:1902042
# methylated histone binding, GO:0035064
# response to wounding, GO:0009611
# Outputing EPS file 6h_delta_stbl.txt_PAGE/6h_delta_stbl.txt.summary.eps
# Convert to PDF 6h_delta_stbl.txt_PAGE/6h_delta_stbl.txt.summary.pdf
# Finished.
# perl /flash/bin/iPAGEv1.0/SCRIPTS/mi_go_draw_matrix_html.pl  --pvaluematrixfile=6h_delta_stbl.txt_PAGE/pvmatrix.txt --expfile=6h_delta_stbl.txt --order=1 --draw_sample_heatmap=false --min=-3 --max=3 --cluster=5 --quantized=0
# Done.
# Cluster rows .. best merge is 1, 9, 0.440486531870682
# best merge is 2, 4, 0.540507761534931
# best merge is 0, 6, 0.669892820698065
# best merge is 3, 7, 0.675074902778651
# best merge is 2, 8, 0.677342102404226
# best merge is 1, 3, 0.847890226828479
# order classes
# 2 - 1.67473205174516
# 2 - 1.1012163296767
# 3 - 1.4038459009951
# 2 - 1.68768725694663
# 1 9
# 0 6
# 2 4 8
# 3 7
# 5
# Done.-11.5704225352113	42	0
# -2.40140845070422	42	16.8591549295775
# -1.07042253521126	42	18.3380281690141
# 0.112676056338032	42	19.5211267605634
# 1.14788732394366	42	20.7042253521127
# 1.88732394366197	42	21.5915492957746
# 2.77464788732394	42	22.1830985915493
# 3.80985915492958	42	23.3661971830986
# 4.84507042253522	42	24.2535211267606
# 6.61971830985915	42	25.4366197183099
# 14.9014084507042	42	27.8028169014084
# perl /flash/bin/iPAGEv1.0/SCRIPTS/list_killed_cats.pl --pvmatrixfile=6h_delta_stbl.txt_PAGE/pvmatrix.txt
# DONE
# removed '6h_PAGE/human_ensembl/6h_delta_stbl.txt.summary.eps'
# removed '6h_PAGE/human_ensembl/6h_delta_stbl.txt.summary.html'
# removed '6h_PAGE/human_ensembl/output.ipage_intersections'
# removed '6h_PAGE/human_ensembl/6h_delta_stbl.txt.summary.pdf'
# removed '6h_PAGE/human_ensembl/pvmatrix.txt.killed'
# removed '6h_PAGE/human_ensembl/info.txt'
# removed '6h_PAGE/human_ensembl/SUMMARY/GO:0000775.pdf'
# removed '6h_PAGE/human_ensembl/SUMMARY/GO:0008033.pdf'
# removed '6h_PAGE/human_ensembl/SUMMARY/GO:0000775.eps'
# removed '6h_PAGE/human_ensembl/SUMMARY/GO:0008033.eps'
# removed directory '6h_PAGE/human_ensembl/SUMMARY'
# removed '6h_PAGE/human_ensembl/input.ipage_quantized'
# removed '6h_PAGE/human_ensembl/pvmatrix.txt'
# removed '6h_PAGE/human_ensembl/pvmatrix.txt.log'
# removed '6h_PAGE/human_ensembl/imgsrc/under.eps'
# removed '6h_PAGE/human_ensembl/imgsrc/over.eps'
# removed directory '6h_PAGE/human_ensembl/imgsrc'
# removed directory '6h_PAGE/human_ensembl/'
# renamed '6h_delta_stbl.txt_PAGE/' -> '6h_PAGE/human_ensembl/'
# Reading expression data ... 1 by 4271... Done.
# Creating hash ... Done
# Reading GO names table ... entering
# Done.
# Reading GO index table ... entering
# Done.
# go_terms_num: 181
# Creating hash table for gene names in gene ontology index file ... Done.
# gene num = 4057 out of 4271
# Creating hash table for gene ontology names ... Done.
# Populating the GO profile table ... 4057	181
# Done.
# Writing internal quantized groups ...Done
# 369 hits go_terms_num = 181
# cat 114, mi = 0.00323914, POU5F1_ChIP-seq_regulon
# cat 112, mi = 0.00280619, POLR3G_ChIP-seq_regulon
# cat 9, mi = 0.00263027, BDP1_ChIP-seq_regulon
# cat 131, mi = 0.00257447, SMARCA4_ChIP-seq_regulon
# cat 115, mi = 0.00223482, PPARGC1A_ChIP-seq_regulon
# cat 12, mi = 0.00181026, BRF1_ChIP-seq_regulon
# cat 167, mi = 0.00138663, XRCC4_ChIP-seq_regulon
# cat 13, mi = 0.00121288, BRF2_ChIP-seq_regulon
# cat 0, mi = 0.00000000, ARID3A_ChIP-seq_regulon
# cat 1, mi = 0.00000000, ATF1_ChIP-seq_regulon
# cat 2, mi = 0.00000000, ATF2_ChIP-seq_regulon
# cat 3, mi = 0.00000000, ATF3_ChIP-seq_regulon
# cat 4, mi = 0.00000000, BACH1_ChIP-seq_regulon
# cat 5, mi = 0.00000000, BATF_ChIP-seq_regulon
# cat 6, mi = 0.00000000, BCL11A_ChIP-seq_regulon
#
# RESULTS
# Didn't pass (cutoff=0.0050): cat 114, mi = 0.003, pvalue = 0.076, POU5F1_ChIP-seq_regulon
# Didn't pass (cutoff=0.0050): cat 112, mi = 0.003, pvalue = 0.112, POLR3G_ChIP-seq_regulon
# Didn't pass (cutoff=0.0050): cat 9, mi = 0.003, pvalue = 0.227, BDP1_ChIP-seq_regulon
# Didn't pass (cutoff=0.0050): cat 131, mi = 0.003, pvalue = 0.229, SMARCA4_ChIP-seq_regulon
# Didn't pass (cutoff=0.0050): cat 115, mi = 0.002, pvalue = 0.378, PPARGC1A_ChIP-seq_regulon
# Didn't pass (cutoff=0.0050): cat 12, mi = 0.002, pvalue = 0.622, BRF1_ChIP-seq_regulon
# Didn't pass: cat 167, mi = 0.001, pvalue = 1.000, XRCC4_ChIP-seq_regulon
# Didn't pass: cat 13, mi = 0.001, pvalue = 1.000, BRF2_ChIP-seq_regulon
# Didn't pass: cat 0, mi = 0.000, pvalue = 1.000, ARID3A_ChIP-seq_regulon
# Didn't pass: cat 1, mi = 0.000, pvalue = 1.000, ATF1_ChIP-seq_regulon
# Didn't pass: cat 2, mi = 0.000, pvalue = 1.000, ATF2_ChIP-seq_regulon
# Didn't pass: cat 3, mi = 0.000, pvalue = 1.000, ATF3_ChIP-seq_regulon
# Didn't pass: cat 4, mi = 0.000, pvalue = 1.000, BACH1_ChIP-seq_regulon
# Didn't pass: cat 5, mi = 0.000, pvalue = 1.000, BATF_ChIP-seq_regulon
# Didn't pass: cat 6, mi = 0.000, pvalue = 1.000, BCL11A_ChIP-seq_regulon
# Didn't pass: cat 7, mi = 0.000, pvalue = 1.000, BCL3_ChIP-seq_regulon
# Didn't pass: cat 8, mi = 0.000, pvalue = 1.000, BCLAF1_ChIP-seq_regulon
# Didn't pass: cat 10, mi = 0.000, pvalue = 1.000, BHLHE40_ChIP-seq_regulon
# Didn't pass: cat 11, mi = 0.000, pvalue = 1.000, BRCA1_ChIP-seq_regulon
# Didn't pass: cat 14, mi = 0.000, pvalue = 1.000, CBX2_ChIP-seq_regulon
# Total number of categories evaluated = 10.
# Number of categories that passed the tests = 0
# Number of clusters: 11
# calculating the p-value matrix.
# Allocating memory ... Done
# Done
# Writing the p-value matrix to file...Done
# perl /flash/bin/iPAGEv1.0/SCRIPTS/mi_go_draw_matrix.pl  --pvaluematrixfile=6h_delta_stbl.txt_PAGE/pvmatrix.txt --expfile=6h_delta_stbl.txt --order=1 --draw_sample_heatmap=false --min=-3 --max=3 --cluster=5 --quantized=0
# Reading matrix ... Done.
# Start drawing
# 0.66	-0.76
# Outputing EPS file 6h_delta_stbl.txt_PAGE/6h_delta_stbl.txt.summary.eps
# Convert to PDF 6h_delta_stbl.txt_PAGE/6h_delta_stbl.txt.summary.pdf
# Finished.
# perl /flash/bin/iPAGEv1.0/SCRIPTS/mi_go_draw_matrix_html.pl  --pvaluematrixfile=6h_delta_stbl.txt_PAGE/pvmatrix.txt --expfile=6h_delta_stbl.txt --order=1 --draw_sample_heatmap=false --min=-3 --max=3 --cluster=5 --quantized=0
# perl /flash/bin/iPAGEv1.0/SCRIPTS/list_killed_cats.pl --pvmatrixfile=6h_delta_stbl.txt_PAGE/pvmatrix.txt
# DONE
# removed '6h_PAGE/human_ensembl_encode_tf/pvmatrix.txt'
# removed '6h_PAGE/human_ensembl_encode_tf/info.txt'
# removed '6h_PAGE/human_ensembl_encode_tf/input.ipage_quantized'
# removed '6h_PAGE/human_ensembl_encode_tf/output.ipage_intersections'
# removed '6h_PAGE/human_ensembl_encode_tf/6h_delta_stbl.txt.summary.pdf'
# removed '6h_PAGE/human_ensembl_encode_tf/pvmatrix.txt.killed'
# removed directory '6h_PAGE/human_ensembl_encode_tf/SUMMARY'
# removed '6h_PAGE/human_ensembl_encode_tf/pvmatrix.txt.log'
# removed '6h_PAGE/human_ensembl_encode_tf/6h_delta_stbl.txt.summary.eps'
# removed directory '6h_PAGE/human_ensembl_encode_tf/'
# renamed '6h_delta_stbl.txt_PAGE/' -> '6h_PAGE/human_ensembl_encode_tf/'
# Reading expression data ... 1 by 4271... Done.
# Creating hash ... Done
# Reading GO names table ... entering
# Done.
# Reading GO index table ... entering
# Done.
# go_terms_num: 298
# Creating hash table for gene names in gene ontology index file ... Done.
# gene num = 4145 out of 4271
# Creating hash table for gene ontology names ... Done.
# Populating the GO profile table ... 4145	298
# Done.
# Writing internal quantized groups ...Done
# 377 hits go_terms_num = 298
# cat 200, mi = 0.00519352, chr17q25
# cat 83, mi = 0.00443650, chr22q13
# cat 217, mi = 0.00439760, chr10q24
# cat 241, mi = 0.00421626, chr17q11
# cat 1, mi = 0.00410750, chr1q31
# cat 204, mi = 0.00389452, chr4q12
# cat 142, mi = 0.00359414, chr10p11
# cat 87, mi = 0.00353962, chr1q24
# cat 232, mi = 0.00353776, chr7p13
# cat 6, mi = 0.00348892, chr11q12
# cat 15, mi = 0.00344269, chr3q21
# cat 135, mi = 0.00338791, chr20p11
# cat 140, mi = 0.00335932, chrXp22
# cat 143, mi = 0.00335832, chr10q23
# cat 266, mi = 0.00329323, chr10q21
#
# RESULTS
# Passed: cat 200, mi = 0.005, pvalue = 0.002, chr17q25
# Didn't pass (cutoff=0.0050): cat 83, mi = 0.004, pvalue = 0.007, chr22q13
# Didn't pass (cutoff=0.0050): cat 217, mi = 0.004, pvalue = 0.010, chr10q24
# Didn't pass (cutoff=0.0050): cat 241, mi = 0.004, pvalue = 0.012, chr17q11
# Passed: cat 1, mi = 0.004, pvalue = 0.004, chr1q31
# Didn't pass (cutoff=0.0050): cat 204, mi = 0.004, pvalue = 0.009, chr4q12
# Didn't pass (cutoff=0.0050): cat 142, mi = 0.004, pvalue = 0.022, chr10p11
# Didn't pass (cutoff=0.0050): cat 87, mi = 0.004, pvalue = 0.043, chr1q24
# Didn't pass (cutoff=0.0050): cat 232, mi = 0.004, pvalue = 0.009, chr7p13
# Didn't pass (cutoff=0.0050): cat 6, mi = 0.003, pvalue = 0.054, chr11q12
# Didn't pass (cutoff=0.0050): cat 15, mi = 0.003, pvalue = 0.057, chr3q21
# Didn't pass (cutoff=0.0050): cat 135, mi = 0.003, pvalue = 0.042, chr20p11
# Didn't pass (cutoff=0.0050): cat 140, mi = 0.003, pvalue = 0.072, chrXp22
# Didn't pass (cutoff=0.0050): cat 143, mi = 0.003, pvalue = 0.066, chr10q23
# Didn't pass (cutoff=0.0050): cat 266, mi = 0.003, pvalue = 0.064, chr10q21
# Didn't pass (cutoff=0.0050): cat 215, mi = 0.003, pvalue = 0.081, chr9q21
# Didn't pass (cutoff=0.0050): cat 196, mi = 0.003, pvalue = 0.057, chr7p22
# Didn't pass (cutoff=0.0050): cat 208, mi = 0.003, pvalue = 0.077, chr22q12
# Didn't pass (cutoff=0.0050): cat 35, mi = 0.003, pvalue = 0.073, chr15q22
# Didn't pass (cutoff=0.0050): cat 275, mi = 0.003, pvalue = 0.092, chr9p24
# Didn't pass (cutoff=0.0050): cat 119, mi = 0.003, pvalue = 0.091, chr2p11
# Didn't pass (cutoff=0.0050): cat 105, mi = 0.003, pvalue = 0.043, chr4p14
# Didn't pass (cutoff=0.0050): cat 278, mi = 0.003, pvalue = 0.112, chr2q33
# Didn't pass (cutoff=0.0050): cat 45, mi = 0.003, pvalue = 0.104, chr1p21
# Didn't pass (cutoff=0.0050): cat 91, mi = 0.003, pvalue = 0.062, chr21q21
# Total number of categories evaluated = 15.
# Number of categories that passed the tests = 2
# Number of clusters: 11
# calculating the p-value matrix.
# Allocating memory ... Done
# Done
# Writing the p-value matrix to file...Done
# perl /flash/bin/iPAGEv1.0/SCRIPTS/mi_go_draw_matrix.pl  --pvaluematrixfile=6h_delta_stbl.txt_PAGE/pvmatrix.txt --expfile=6h_delta_stbl.txt --order=1 --draw_sample_heatmap=false --min=-3 --max=3 --cluster=5 --quantized=0
# Reading matrix ... Done.
# Start drawing
# 0.66	-0.76
# chr17q25
# chr1q31
# Outputing EPS file 6h_delta_stbl.txt_PAGE/6h_delta_stbl.txt.summary.eps
# Convert to PDF 6h_delta_stbl.txt_PAGE/6h_delta_stbl.txt.summary.pdf
# Finished.
# perl /flash/bin/iPAGEv1.0/SCRIPTS/mi_go_draw_matrix_html.pl  --pvaluematrixfile=6h_delta_stbl.txt_PAGE/pvmatrix.txt --expfile=6h_delta_stbl.txt --order=1 --draw_sample_heatmap=false --min=-3 --max=3 --cluster=5 --quantized=0
# Done.
# -11.5704225352113	42	0
# -2.40140845070422	42	16.8591549295775
# -1.07042253521126	42	18.3380281690141
# 0.112676056338032	42	19.5211267605634
# 1.14788732394366	42	20.7042253521127
# 1.88732394366197	42	21.5915492957746
# 2.77464788732394	42	22.1830985915493
# 3.80985915492958	42	23.3661971830986
# 4.84507042253522	42	24.2535211267606
# 6.61971830985915	42	25.4366197183099
# 14.9014084507042	42	27.8028169014084
# perl /flash/bin/iPAGEv1.0/SCRIPTS/list_killed_cats.pl --pvmatrixfile=6h_delta_stbl.txt_PAGE/pvmatrix.txt
# DONE
# removed '6h_PAGE/human_ensembl_msigdb_c1/pvmatrix.txt.log'
# removed '6h_PAGE/human_ensembl_msigdb_c1/info.txt'
# removed '6h_PAGE/human_ensembl_msigdb_c1/pvmatrix.txt.killed'
# removed '6h_PAGE/human_ensembl_msigdb_c1/pvmatrix.txt'
# removed '6h_PAGE/human_ensembl_msigdb_c1/6h_delta_stbl.txt.summary.eps'
# removed directory '6h_PAGE/human_ensembl_msigdb_c1/SUMMARY'
# removed '6h_PAGE/human_ensembl_msigdb_c1/input.ipage_quantized'
# removed '6h_PAGE/human_ensembl_msigdb_c1/output.ipage_intersections'
# removed '6h_PAGE/human_ensembl_msigdb_c1/6h_delta_stbl.txt.summary.pdf'
# removed directory '6h_PAGE/human_ensembl_msigdb_c1/'
# renamed '6h_delta_stbl.txt_PAGE/' -> '6h_PAGE/human_ensembl_msigdb_c1/'
# Reading expression data ... 1 by 4271... Done.
# Creating hash ... Done
# Reading GO names table ... entering
# Done.
# Reading GO index table ... entering
# Done.
# go_terms_num: 5529
# Creating hash table for gene names in gene ontology index file ... Done.
# gene num = 4124 out of 4271
# Creating hash table for gene ontology names ... Done.
# Populating the GO profile table ... 4124	5529
# Done.
# Writing internal quantized groups ...Done
# 375 hits go_terms_num = 5529
# cat 4669, mi = 0.00606830, KEGG_CALCIUM_SIGNALING_PATHWAY
# cat 3592, mi = 0.00548577, BILBAN_B_CLL_LPL_DN
# cat 2191, mi = 0.00541537, NADLER_OBESITY_UP
# cat 2499, mi = 0.00536876, DAZARD_UV_RESPONSE_CLUSTER_G1
# cat 4702, mi = 0.00534479, REACTOME_EPIGENETIC_REGULATION_OF_GENE_EXPRESSION
# cat 2758, mi = 0.00509555, TONKS_TARGETS_OF_RUNX1_RUNX1T1_FUSION_HSC_UP
# cat 2100, mi = 0.00493212, BENPORATH_NOS_TARGETS
# cat 1387, mi = 0.00481139, MORI_IMMATURE_B_LYMPHOCYTE_UP
# cat 2323, mi = 0.00474004, LINDSTEDT_DENDRITIC_CELL_MATURATION_D
# cat 1786, mi = 0.00471997, FIGUEROA_AML_METHYLATION_CLUSTER_6_UP
# cat 3825, mi = 0.00466696, BOYLAN_MULTIPLE_MYELOMA_D_UP
# cat 785, mi = 0.00464280, ZHENG_FOXP3_TARGETS_IN_THYMUS_UP
# cat 2377, mi = 0.00460060, REACTOME_DEADENYLATION_DEPENDENT_MRNA_DECAY
# cat 3613, mi = 0.00456103, JI_RESPONSE_TO_FSH_DN
# cat 1191, mi = 0.00453611, REACTOME_TRNA_AMINOACYLATION
#
# RESULTS
# Passed: cat 4669, mi = 0.006, pvalue = 0.000, KEGG_CALCIUM_SIGNALING_PATHWAY
# Passed: cat 3592, mi = 0.005, pvalue = 0.000, BILBAN_B_CLL_LPL_DN
# Passed: cat 2191, mi = 0.005, pvalue = 0.000, NADLER_OBESITY_UP
# Passed: cat 2499, mi = 0.005, pvalue = 0.002, DAZARD_UV_RESPONSE_CLUSTER_G1
# Passed: cat 4702, mi = 0.005, pvalue = 0.001, REACTOME_EPIGENETIC_REGULATION_OF_GENE_EXPRESSION
# Passed: cat 2758, mi = 0.005, pvalue = 0.003, TONKS_TARGETS_OF_RUNX1_RUNX1T1_FUSION_HSC_UP
# Passed: cat 2100, mi = 0.005, pvalue = 0.003, BENPORATH_NOS_TARGETS
# Passed: cat 1387, mi = 0.005, pvalue = 0.002, MORI_IMMATURE_B_LYMPHOCYTE_UP
# Passed: cat 2323, mi = 0.005, pvalue = 0.003, LINDSTEDT_DENDRITIC_CELL_MATURATION_D
# Passed: cat 1786, mi = 0.005, pvalue = 0.005, FIGUEROA_AML_METHYLATION_CLUSTER_6_UP
# Didn't pass (cutoff=0.0050): cat 3825, mi = 0.005, pvalue = 0.005, BOYLAN_MULTIPLE_MYELOMA_D_UP
# Didn't pass (cutoff=0.0050): cat 2377, mi = 0.005, pvalue = 0.006, REACTOME_DEADENYLATION_DEPENDENT_MRNA_DECAY
# Didn't pass (cutoff=0.0050): cat 3613, mi = 0.005, pvalue = 0.007, JI_RESPONSE_TO_FSH_DN
# Didn't pass (cutoff=0.0050): cat 1191, mi = 0.005, pvalue = 0.008, REACTOME_TRNA_AMINOACYLATION
# Didn't pass (cutoff=0.0050): cat 2767, mi = 0.004, pvalue = 0.008, KEGG_AMINOACYL_TRNA_BIOSYNTHESIS
# Didn't pass (cutoff=0.0050): cat 412, mi = 0.004, pvalue = 0.007, BILANGES_SERUM_RESPONSE_TRANSLATION
# Didn't pass (cutoff=0.0050): cat 54, mi = 0.004, pvalue = 0.009, VECCHI_GASTRIC_CANCER_ADVANCED_VS_EARLY_UP
# Didn't pass (cutoff=0.0050): cat 5151, mi = 0.004, pvalue = 0.006, KARLSSON_TGFB1_TARGETS_UP
# Didn't pass (cutoff=0.0050): cat 2534, mi = 0.004, pvalue = 0.007, REACTOME_IRE1ALPHA_ACTIVATES_CHAPERONES
# Didn't pass (cutoff=0.0050): cat 764, mi = 0.004, pvalue = 0.012, PID_PLK1_PATHWAY
# Passed: cat 4442, mi = 0.004, pvalue = 0.003, REACTOME_MITOCHONDRIAL_TRNA_AMINOACYLATION
# Didn't pass (cutoff=0.0050): cat 1688, mi = 0.004, pvalue = 0.013, REACTOME_SIGNALING_BY_TGF_BETA_FAMILY_MEMBERS
# Didn't pass (cutoff=0.0050): cat 487, mi = 0.004, pvalue = 0.010, CASORELLI_ACUTE_PROMYELOCYTIC_LEUKEMIA_UP
# Passed: cat 3285, mi = 0.004, pvalue = 0.000, IVANOV_MUTATED_IN_COLON_CANCER
# Didn't pass (cutoff=0.0050): cat 2354, mi = 0.004, pvalue = 0.015, REACTOME_SIGNALING_BY_TGF_BETA_RECEPTOR_COMPLEX
# Didn't pass (cutoff=0.0050): cat 3817, mi = 0.004, pvalue = 0.010, DORSAM_HOXA9_TARGETS_UP
# Didn't pass (cutoff=0.0050): cat 3352, mi = 0.004, pvalue = 0.013, REACTOME_RRNA_MODIFICATION_IN_THE_NUCLEUS_AND_CYTOSOL
# Didn't pass (cutoff=0.0050): cat 2278, mi = 0.004, pvalue = 0.011, REACTOME_DEADENYLATION_OF_MRNA
# Didn't pass (cutoff=0.0050): cat 975, mi = 0.004, pvalue = 0.014, PID_FANCONI_PATHWAY
# Didn't pass (cutoff=0.0050): cat 4886, mi = 0.004, pvalue = 0.016, REACTOME_TRANSLOCATION_OF_SLC2A4_GLUT4_TO_THE_PLASMA_MEMBRANE
# Didn't pass (cutoff=0.0050): cat 3501, mi = 0.004, pvalue = 0.019, AZARE_NEOPLASTIC_TRANSFORMATION_BY_STAT3_UP
# Didn't pass (cutoff=0.0050): cat 1362, mi = 0.004, pvalue = 0.018, SCHAEFFER_PROSTATE_DEVELOPMENT_6HR_UP
# Didn't pass (cutoff=0.0050): cat 3478, mi = 0.004, pvalue = 0.007, MELLMAN_TUT1_TARGETS_UP
# Didn't pass (cutoff=0.0050): cat 4673, mi = 0.004, pvalue = 0.021, TURASHVILI_BREAST_DUCTAL_CARCINOMA_VS_LOBULAR_NORMAL_UP
# Didn't pass (cutoff=0.0050): cat 4920, mi = 0.004, pvalue = 0.019, REACTOME_ACTIVATION_OF_THE_PRE_REPLICATIVE_COMPLEX
# Didn't pass (cutoff=0.0050): cat 5143, mi = 0.004, pvalue = 0.014, BRUECKNER_TARGETS_OF_MIRLET7A3_DN
# Didn't pass (cutoff=0.0050): cat 5389, mi = 0.004, pvalue = 0.012, ZHAN_MULTIPLE_MYELOMA_CD2_DN
# Didn't pass (cutoff=0.0050): cat 1887, mi = 0.004, pvalue = 0.008, PID_NFAT_TFPATHWAY
# Didn't pass (cutoff=0.0050): cat 2300, mi = 0.004, pvalue = 0.009, MARZEC_IL2_SIGNALING_DN
# Didn't pass (cutoff=0.0050): cat 1656, mi = 0.004, pvalue = 0.022, NIKOLSKY_BREAST_CANCER_20Q12_Q13_AMPLICON
# Didn't pass (cutoff=0.0050): cat 3543, mi = 0.004, pvalue = 0.018, REACTOME_DEACTIVATION_OF_THE_BETA_CATENIN_TRANSACTIVATING_COMPLEX
# Didn't pass (cutoff=0.0050): cat 3600, mi = 0.004, pvalue = 0.020, KRIEG_KDM3A_TARGETS_NOT_HYPOXIA
# Didn't pass (cutoff=0.0050): cat 5306, mi = 0.004, pvalue = 0.023, GINESTIER_BREAST_CANCER_20Q13_AMPLIFICATION_UP
# Didn't pass (cutoff=0.0050): cat 1085, mi = 0.004, pvalue = 0.029, BURTON_ADIPOGENESIS_12
# Total number of categories evaluated = 39.
# Number of categories that passed the tests = 12
# Number of clusters: 11
# calculating the p-value matrix.
# Allocating memory ... Done
# Done
# Writing the p-value matrix to file...Done
# perl /flash/bin/iPAGEv1.0/SCRIPTS/mi_go_draw_matrix.pl  --pvaluematrixfile=6h_delta_stbl.txt_PAGE/pvmatrix.txt --expfile=6h_delta_stbl.txt --order=1 --draw_sample_heatmap=false --min=-3 --max=3 --cluster=5 --quantized=0
# Reading matrix ... Done.
# Cluster rows .. best merge is 2, 11, 0.0766032448424829
# best merge is 0, 10, 0.342473913526719
# best merge is 3, 9, 0.356512285027058
# best merge is 5, 7, 0.372218767669342
# best merge is 1, 8, 0.610607170643322
# best merge is 2, 5, 0.625480575959873
# best merge is 1, 3, 0.793397439783546
# best merge is 4, 6, 0.917435103675905
# order classes
# 2 - 1.02742174058016
# 4 - 1.55276595555171
# 4 - 1.10652911863174
# 0 10
# 1 8 3 9
# 2 11 5 7
# 4
# 6
# Done.Start drawing
# 0.66	-0.76
# KEGG_CALCIUM_SIGNALING_PATHWAY
# REACTOME_MITOCHONDRIAL_TRNA_AMINOACYLATION
# NADLER_OBESITY_UP
# MORI_IMMATURE_B_LYMPHOCYTE_UP
# IVANOV_MUTATED_IN_COLON_CANCER
# LINDSTEDT_DENDRITIC_CELL_MATURATION_D
# REACTOME_EPIGENETIC_REGULATION_OF_GENE_EXPRESSION
# BENPORATH_NOS_TARGETS
# BILBAN_B_CLL_LPL_DN
# DAZARD_UV_RESPONSE_CLUSTER_G1
# FIGUEROA_AML_METHYLATION_CLUSTER_6_UP
# TONKS_TARGETS_OF_RUNX1_RUNX1T1_FUSION_HSC_UP
# Outputing EPS file 6h_delta_stbl.txt_PAGE/6h_delta_stbl.txt.summary.eps
# Convert to PDF 6h_delta_stbl.txt_PAGE/6h_delta_stbl.txt.summary.pdf
# Finished.
# perl /flash/bin/iPAGEv1.0/SCRIPTS/mi_go_draw_matrix_html.pl  --pvaluematrixfile=6h_delta_stbl.txt_PAGE/pvmatrix.txt --expfile=6h_delta_stbl.txt --order=1 --draw_sample_heatmap=false --min=-3 --max=3 --cluster=5 --quantized=0
# Done.
# Cluster rows .. best merge is 2, 11, 0.0766032448424829
# best merge is 0, 10, 0.342473913526719
# best merge is 3, 9, 0.356512285027058
# best merge is 5, 7, 0.372218767669342
# best merge is 1, 8, 0.610607170643322
# best merge is 2, 5, 0.625480575959873
# best merge is 1, 3, 0.793397439783546
# best merge is 4, 6, 0.917435103675905
# order classes
# 2 - 1.02742174058016
# 4 - 1.55276595555171
# 4 - 1.10652911863174
# 0 10
# 1 8 3 9
# 2 11 5 7
# 4
# 6
# Done.-11.5704225352113	42	0
# -2.40140845070422	42	16.8591549295775
# -1.07042253521126	42	18.3380281690141
# 0.112676056338032	42	19.5211267605634
# 1.14788732394366	42	20.7042253521127
# 2.03521126760564	42	21.5915492957746
# 2.92253521126761	42	22.4788732394366
# 3.80985915492958	42	23.3661971830986
# 4.84507042253522	42	24.2535211267606
# 6.61971830985915	42	25.4366197183099
# 14.9014084507042	42	27.8028169014084
# perl /flash/bin/iPAGEv1.0/SCRIPTS/list_killed_cats.pl --pvmatrixfile=6h_delta_stbl.txt_PAGE/pvmatrix.txt
# DONE
# removed '6h_PAGE/human_ensembl_msigdb_c2/info.txt'
# removed '6h_PAGE/human_ensembl_msigdb_c2/output.ipage_intersections'
# removed '6h_PAGE/human_ensembl_msigdb_c2/6h_delta_stbl.txt.summary.html'
# removed '6h_PAGE/human_ensembl_msigdb_c2/pvmatrix.txt.log'
# removed '6h_PAGE/human_ensembl_msigdb_c2/imgsrc/under.eps'
# removed '6h_PAGE/human_ensembl_msigdb_c2/imgsrc/over.eps'
# removed directory '6h_PAGE/human_ensembl_msigdb_c2/imgsrc'
# removed '6h_PAGE/human_ensembl_msigdb_c2/SUMMARY/MILI_PSEUDOPODIA.eps'
# removed '6h_PAGE/human_ensembl_msigdb_c2/SUMMARY/MA_MYELOID_DIFFERENTIATION_DN.eps'
# removed '6h_PAGE/human_ensembl_msigdb_c2/SUMMARY/MILI_PSEUDOPODIA.pdf'
# removed '6h_PAGE/human_ensembl_msigdb_c2/SUMMARY/MA_MYELOID_DIFFERENTIATION_DN.pdf'
# removed directory '6h_PAGE/human_ensembl_msigdb_c2/SUMMARY'
# removed '6h_PAGE/human_ensembl_msigdb_c2/pvmatrix.txt.killed'
# removed '6h_PAGE/human_ensembl_msigdb_c2/6h_delta_stbl.txt.summary.eps'
# removed '6h_PAGE/human_ensembl_msigdb_c2/pvmatrix.txt'
# removed '6h_PAGE/human_ensembl_msigdb_c2/6h_delta_stbl.txt.summary.pdf'
# removed '6h_PAGE/human_ensembl_msigdb_c2/input.ipage_quantized'
# removed directory '6h_PAGE/human_ensembl_msigdb_c2/'
# renamed '6h_delta_stbl.txt_PAGE/' -> '6h_PAGE/human_ensembl_msigdb_c2/'
# Reading expression data ... 1 by 4271... Done.
# Creating hash ... Done
# Reading GO names table ... entering
# Done.
# Reading GO index table ... entering
# Done.
# go_terms_num: 3733
# Creating hash table for gene names in gene ontology index file ... Done.
# gene num = 4141 out of 4271
# Creating hash table for gene ontology names ... Done.
# Populating the GO profile table ... 4141	3733
# Done.
# Writing internal quantized groups ...Done
# 376 hits go_terms_num = 3733
# cat 3477, mi = 0.00577213, MIR548AU_3P
# cat 1341, mi = 0.00547969, MIR10526_3P
# cat 3168, mi = 0.00537835, MIR3138
# cat 1888, mi = 0.00526220, MIR4735_5P
# cat 1709, mi = 0.00493745, TTGGGAG_MIR150
# cat 2442, mi = 0.00487453, MIR4274
# cat 2612, mi = 0.00457680, MIR6739_3P
# cat 3191, mi = 0.00451498, MIR891B
# cat 542, mi = 0.00450564, SNAPC4_TARGET_GENES
# cat 648, mi = 0.00449732, MIR889_5P
# cat 2432, mi = 0.00448102, MIR1910_5P
# cat 413, mi = 0.00445127, TCTGATA_MIR361
# cat 1353, mi = 0.00444310, MIR3614_3P
# cat 2364, mi = 0.00443191, MIR500A_5P
# cat 609, mi = 0.00440474, MIR1248
#
# RESULTS
# Passed: cat 3477, mi = 0.006, pvalue = 0.001, MIR548AU_3P
# Passed: cat 1341, mi = 0.005, pvalue = 0.001, MIR10526_3P
# Passed: cat 3168, mi = 0.005, pvalue = 0.001, MIR3138
# Passed: cat 1709, mi = 0.005, pvalue = 0.003, TTGGGAG_MIR150
# Passed: cat 2442, mi = 0.005, pvalue = 0.004, MIR4274
# Didn't pass (cutoff=0.0050): cat 2612, mi = 0.005, pvalue = 0.005, MIR6739_3P
# Didn't pass (cutoff=0.0050): cat 3191, mi = 0.005, pvalue = 0.006, MIR891B
# Didn't pass (cutoff=0.0050): cat 542, mi = 0.005, pvalue = 0.006, SNAPC4_TARGET_GENES
# Didn't pass (cutoff=0.0050): cat 648, mi = 0.004, pvalue = 0.007, MIR889_5P
# Didn't pass (cutoff=0.0050): cat 2432, mi = 0.004, pvalue = 0.009, MIR1910_5P
# Didn't pass (cutoff=0.0050): cat 413, mi = 0.004, pvalue = 0.007, TCTGATA_MIR361
# Didn't pass (cutoff=0.0050): cat 1353, mi = 0.004, pvalue = 0.011, MIR3614_3P
# Didn't pass (cutoff=0.0050): cat 2364, mi = 0.004, pvalue = 0.006, MIR500A_5P
# Didn't pass (cutoff=0.0050): cat 609, mi = 0.004, pvalue = 0.009, MIR1248
# Didn't pass (cutoff=0.0050): cat 1068, mi = 0.004, pvalue = 0.009, SNRNP70_TARGET_GENES
# Didn't pass (cutoff=0.0050): cat 3024, mi = 0.004, pvalue = 0.012, MIR3149
# Didn't pass (cutoff=0.0050): cat 362, mi = 0.004, pvalue = 0.009, MIR4778_5P
# Didn't pass (cutoff=0.0050): cat 2934, mi = 0.004, pvalue = 0.011, ACAWNRNSRCGG_UNKNOWN
# Didn't pass (cutoff=0.0050): cat 281, mi = 0.004, pvalue = 0.010, ZNF486_TARGET_GENES
# Didn't pass (cutoff=0.0050): cat 1225, mi = 0.004, pvalue = 0.008, MIR132_3P
# Didn't pass (cutoff=0.0050): cat 684, mi = 0.004, pvalue = 0.011, MIR4709_3P
# Didn't pass (cutoff=0.0050): cat 3228, mi = 0.004, pvalue = 0.005, MIR1288_5P
# Didn't pass (cutoff=0.0050): cat 1707, mi = 0.004, pvalue = 0.013, MIR3663_3P
# Didn't pass (cutoff=0.0050): cat 2647, mi = 0.004, pvalue = 0.013, MIR1912_3P
# Didn't pass (cutoff=0.0050): cat 234, mi = 0.004, pvalue = 0.013, MIR7843_3P
# Total number of categories evaluated = 18.
# Number of categories that passed the tests = 5
# Number of clusters: 11
# calculating the p-value matrix.
# Allocating memory ... Done
# Done
# Writing the p-value matrix to file...Done
# perl /flash/bin/iPAGEv1.0/SCRIPTS/mi_go_draw_matrix.pl  --pvaluematrixfile=6h_delta_stbl.txt_PAGE/pvmatrix.txt --expfile=6h_delta_stbl.txt --order=1 --draw_sample_heatmap=false --min=-3 --max=3 --cluster=5 --quantized=0
# Reading matrix ... Done.
# Cluster rows .. best merge is 3, 4, 0.315553141445206
# order classes
# 0
# 1
# 2
# 3
# 4
# Done.Start drawing
# 0.66	-0.76
# MIR10526_3P
# MIR4274
# TTGGGAG_MIR150
# MIR548AU_3P
# MIR3138
# Outputing EPS file 6h_delta_stbl.txt_PAGE/6h_delta_stbl.txt.summary.eps
# Convert to PDF 6h_delta_stbl.txt_PAGE/6h_delta_stbl.txt.summary.pdf
# Finished.
# perl /flash/bin/iPAGEv1.0/SCRIPTS/mi_go_draw_matrix_html.pl  --pvaluematrixfile=6h_delta_stbl.txt_PAGE/pvmatrix.txt --expfile=6h_delta_stbl.txt --order=1 --draw_sample_heatmap=false --min=-3 --max=3 --cluster=5 --quantized=0
# Done.
# Cluster rows .. best merge is 3, 4, 0.315553141445206
# order classes
# 0
# 1
# 2
# 3
# 4
# Done.-11.5704225352113	42	0
# -2.40140845070422	42	16.8591549295775
# -1.07042253521126	42	18.3380281690141
# 0.112676056338032	42	19.5211267605634
# 1.14788732394366	42	20.7042253521127
# 1.88732394366197	42	21.5915492957746
# 2.77464788732394	42	22.1830985915493
# 3.80985915492958	42	23.3661971830986
# 4.84507042253522	42	24.2535211267606
# 6.4718309859155	42	25.4366197183099
# 14.7535211267606	42	27.5070422535211
# perl /flash/bin/iPAGEv1.0/SCRIPTS/list_killed_cats.pl --pvmatrixfile=6h_delta_stbl.txt_PAGE/pvmatrix.txt
# DONE
# removed '6h_PAGE/human_ensembl_msigdb_c3/pvmatrix.txt.log'
# removed '6h_PAGE/human_ensembl_msigdb_c3/pvmatrix.txt.killed'
# removed '6h_PAGE/human_ensembl_msigdb_c3/6h_delta_stbl.txt.summary.html'
# removed '6h_PAGE/human_ensembl_msigdb_c3/imgsrc/under.eps'
# removed '6h_PAGE/human_ensembl_msigdb_c3/imgsrc/over.eps'
# removed directory '6h_PAGE/human_ensembl_msigdb_c3/imgsrc'
# removed '6h_PAGE/human_ensembl_msigdb_c3/pvmatrix.txt'
# removed '6h_PAGE/human_ensembl_msigdb_c3/SUMMARY/GATA_Q6.pdf'
# removed '6h_PAGE/human_ensembl_msigdb_c3/SUMMARY/GATA_Q6.eps'
# removed '6h_PAGE/human_ensembl_msigdb_c3/SUMMARY/MIR5591_3P.pdf'
# removed '6h_PAGE/human_ensembl_msigdb_c3/SUMMARY/MIR412_3P.eps'
# removed '6h_PAGE/human_ensembl_msigdb_c3/SUMMARY/MIR5591_3P.eps'
# removed '6h_PAGE/human_ensembl_msigdb_c3/SUMMARY/MIR412_3P.pdf'
# removed directory '6h_PAGE/human_ensembl_msigdb_c3/SUMMARY'
# removed '6h_PAGE/human_ensembl_msigdb_c3/output.ipage_intersections'
# removed '6h_PAGE/human_ensembl_msigdb_c3/info.txt'
# removed '6h_PAGE/human_ensembl_msigdb_c3/6h_delta_stbl.txt.summary.pdf'
# removed '6h_PAGE/human_ensembl_msigdb_c3/input.ipage_quantized'
# removed '6h_PAGE/human_ensembl_msigdb_c3/6h_delta_stbl.txt.summary.eps'
# removed directory '6h_PAGE/human_ensembl_msigdb_c3/'
# renamed '6h_delta_stbl.txt_PAGE/' -> '6h_PAGE/human_ensembl_msigdb_c3/'
# Reading expression data ... 1 by 4271... Done.
# Creating hash ... Done
# Reading GO names table ... entering
# Done.
# Reading GO index table ... entering
# Done.
# go_terms_num: 858
# Creating hash table for gene names in gene ontology index file ... Done.
# gene num = 2858 out of 4271
# Creating hash table for gene ontology names ... Done.
# Populating the GO profile table ... 2858	858
# Done.
# Writing internal quantized groups ...Done
# 260 hits go_terms_num = 858
# cat 702, mi = 0.00801156, MORF_MAP2K2
# cat 191, mi = 0.00765837, GNF2_G22P1
# cat 526, mi = 0.00653869, MORF_CDC16
# cat 678, mi = 0.00647469, MORF_PAPSS1
# cat 342, mi = 0.00623646, GNF2_UBE2I
# cat 22, mi = 0.00614747, MODULE_430
# cat 564, mi = 0.00603218, GNF2_RRM1
# cat 524, mi = 0.00581606, GCM_TPT1
# cat 450, mi = 0.00580142, GCM_DLG1
# cat 267, mi = 0.00573017, MODULE_493
# cat 340, mi = 0.00569053, MODULE_177
# cat 460, mi = 0.00567883, GCM_AQP4
# cat 576, mi = 0.00548471, GNF2_PTPN6
# cat 92, mi = 0.00547786, GNF2_SMC4L1
# cat 363, mi = 0.00540499, GNF2_SELL
#
# RESULTS
# Passed: cat 702, mi = 0.008, pvalue = 0.001, MORF_MAP2K2
# Didn't pass (cutoff=0.0050): cat 22, mi = 0.006, pvalue = 0.011, MODULE_430
# Didn't pass (cutoff=0.0050): cat 564, mi = 0.006, pvalue = 0.013, GNF2_RRM1
# Didn't pass (cutoff=0.0050): cat 524, mi = 0.006, pvalue = 0.017, GCM_TPT1
# Didn't pass (cutoff=0.0050): cat 450, mi = 0.006, pvalue = 0.017, GCM_DLG1
# Didn't pass (cutoff=0.0050): cat 267, mi = 0.006, pvalue = 0.023, MODULE_493
# Didn't pass (cutoff=0.0050): cat 340, mi = 0.006, pvalue = 0.023, MODULE_177
# Passed: cat 460, mi = 0.006, pvalue = 0.002, GCM_AQP4
# Didn't pass (cutoff=0.0050): cat 576, mi = 0.005, pvalue = 0.029, GNF2_PTPN6
# Didn't pass (cutoff=0.0050): cat 92, mi = 0.005, pvalue = 0.022, GNF2_SMC4L1
# Didn't pass (cutoff=0.0050): cat 363, mi = 0.005, pvalue = 0.035, GNF2_SELL
# Didn't pass (cutoff=0.0050): cat 472, mi = 0.005, pvalue = 0.038, GNF2_TTK
# Didn't pass (cutoff=0.0050): cat 285, mi = 0.005, pvalue = 0.033, GNF2_FEN1
# Didn't pass (cutoff=0.0050): cat 543, mi = 0.005, pvalue = 0.036, GNF2_HAT1
# Didn't pass (cutoff=0.0050): cat 756, mi = 0.005, pvalue = 0.029, GNF2_EIF3S6
# Didn't pass (cutoff=0.0050): cat 28, mi = 0.005, pvalue = 0.045, GNF2_CD53
# Didn't pass (cutoff=0.0050): cat 326, mi = 0.005, pvalue = 0.028, GCM_RAB10
# Didn't pass (cutoff=0.0050): cat 390, mi = 0.005, pvalue = 0.042, MODULE_481
# Didn't pass (cutoff=0.0050): cat 548, mi = 0.005, pvalue = 0.044, MODULE_544
# Didn't pass (cutoff=0.0050): cat 129, mi = 0.005, pvalue = 0.055, GNF2_GLTSCR2
# Didn't pass (cutoff=0.0050): cat 356, mi = 0.005, pvalue = 0.047, GCM_TINF2
# Didn't pass (cutoff=0.0050): cat 593, mi = 0.005, pvalue = 0.040, GNF2_RBBP6
# Didn't pass (cutoff=0.0050): cat 625, mi = 0.005, pvalue = 0.035, GNF2_FBL
# Didn't pass (cutoff=0.0050): cat 228, mi = 0.005, pvalue = 0.066, GCM_CASP2
# Didn't pass (cutoff=0.0050): cat 211, mi = 0.005, pvalue = 0.069, GNF2_TPT1
# Didn't pass (cutoff=0.0050): cat 319, mi = 0.005, pvalue = 0.022, MODULE_180
# Didn't pass (cutoff=0.0050): cat 714, mi = 0.005, pvalue = 0.065, GNF2_PCNA
# Didn't pass (cutoff=0.0050): cat 245, mi = 0.005, pvalue = 0.073, GCM_PPM1D
# Total number of categories evaluated = 31.
# Number of categories that passed the tests = 2
# Number of clusters: 11
# calculating the p-value matrix.
# Allocating memory ... Done
# Done
# Writing the p-value matrix to file...Done
# perl /flash/bin/iPAGEv1.0/SCRIPTS/mi_go_draw_matrix.pl  --pvaluematrixfile=6h_delta_stbl.txt_PAGE/pvmatrix.txt --expfile=6h_delta_stbl.txt --order=1 --draw_sample_heatmap=false --min=-3 --max=3 --cluster=5 --quantized=0
# Reading matrix ... Done.
# Start drawing
# 0.66	-0.76
# MORF_MAP2K2
# GCM_AQP4
# Outputing EPS file 6h_delta_stbl.txt_PAGE/6h_delta_stbl.txt.summary.eps
# Convert to PDF 6h_delta_stbl.txt_PAGE/6h_delta_stbl.txt.summary.pdf
# Finished.
# perl /flash/bin/iPAGEv1.0/SCRIPTS/mi_go_draw_matrix_html.pl  --pvaluematrixfile=6h_delta_stbl.txt_PAGE/pvmatrix.txt --expfile=6h_delta_stbl.txt --order=1 --draw_sample_heatmap=false --min=-3 --max=3 --cluster=5 --quantized=0
# Done.
# -11.5704225352113	42	0
# -2.25352112676056	42	16.8591549295775
# -0.774647887323944	42	18.6338028169014
# 0.260563380281688	42	19.8169014084507
# 1.14788732394366	42	20.7042253521127
# 2.03521126760564	42	21.5915492957746
# 2.92253521126761	42	22.4788732394366
# 3.95774647887324	42	23.3661971830986
# 5.14084507042254	42	24.5492957746479
# 6.76760563380282	42	25.7323943661972
# 14.9014084507042	42	27.8028169014084
# perl /flash/bin/iPAGEv1.0/SCRIPTS/list_killed_cats.pl --pvmatrixfile=6h_delta_stbl.txt_PAGE/pvmatrix.txt
# DONE
# removed '6h_PAGE/human_ensembl_msigdb_c4/output.ipage_intersections'
# removed '6h_PAGE/human_ensembl_msigdb_c4/pvmatrix.txt.log'
# removed '6h_PAGE/human_ensembl_msigdb_c4/6h_delta_stbl.txt.summary.html'
# removed '6h_PAGE/human_ensembl_msigdb_c4/6h_delta_stbl.txt.summary.pdf'
# removed '6h_PAGE/human_ensembl_msigdb_c4/info.txt'
# removed '6h_PAGE/human_ensembl_msigdb_c4/input.ipage_quantized'
# removed '6h_PAGE/human_ensembl_msigdb_c4/imgsrc/under.eps'
# removed '6h_PAGE/human_ensembl_msigdb_c4/imgsrc/over.eps'
# removed directory '6h_PAGE/human_ensembl_msigdb_c4/imgsrc'
# removed '6h_PAGE/human_ensembl_msigdb_c4/6h_delta_stbl.txt.summary.eps'
# removed '6h_PAGE/human_ensembl_msigdb_c4/pvmatrix.txt.killed'
# removed '6h_PAGE/human_ensembl_msigdb_c4/SUMMARY/MODULE_105.eps'
# removed '6h_PAGE/human_ensembl_msigdb_c4/SUMMARY/MODULE_105.pdf'
# removed directory '6h_PAGE/human_ensembl_msigdb_c4/SUMMARY'
# removed '6h_PAGE/human_ensembl_msigdb_c4/pvmatrix.txt'
# removed directory '6h_PAGE/human_ensembl_msigdb_c4/'
# renamed '6h_delta_stbl.txt_PAGE/' -> '6h_PAGE/human_ensembl_msigdb_c4/'
# Reading expression data ... 1 by 4271... Done.
# Creating hash ... Done
# Reading GO names table ... entering
# Done.
# Reading GO index table ... entering
# Done.
# go_terms_num: 10191
# Creating hash table for gene names in gene ontology index file ... Done.
# gene num = 3996 out of 4271
# Creating hash table for gene ontology names ... Done.
# Populating the GO profile table ... 3996	10191
# Done.
# Writing internal quantized groups ...Done
# 363 hits go_terms_num = 10191
# cat 1963, mi = 0.00646544, GO_METHYLATED_HISTONE_BINDING
# cat 8133, mi = 0.00557545, GO_HISTONE_UBIQUITINATION
# cat 3589, mi = 0.00557041, GO_VACUOLAR_LUMEN
# cat 5017, mi = 0.00550045, GO_CLATHRIN_ADAPTOR_COMPLEX
# cat 8368, mi = 0.00536877, GO_RNA_POLYADENYLATION
# cat 4146, mi = 0.00518297, GO_FATTY_ACID_CATABOLIC_PROCESS
# cat 7184, mi = 0.00513987, GO_HISTONE_MONOUBIQUITINATION
# cat 4551, mi = 0.00508822, GO_BIOMINERALIZATION
# cat 5721, mi = 0.00494063, GO_AZUROPHIL_GRANULE_LUMEN
# cat 446, mi = 0.00490412, GO_FATTY_ACID_BETA_OXIDATION
# cat 6038, mi = 0.00473959, GO_CAVEOLA
# cat 9724, mi = 0.00472437, GO_REGULATION_OF_CELL_SHAPE
# cat 4500, mi = 0.00470230, GO_AMINO_ACID_ACTIVATION
# cat 519, mi = 0.00463921, GO_CLATHRIN_COAT
# cat 7898, mi = 0.00462807, GO_GOLGI_CISTERNA
#
# RESULTS
# Passed: cat 1963, mi = 0.006, pvalue = 0.000, GO_METHYLATED_HISTONE_BINDING
# Passed: cat 3589, mi = 0.006, pvalue = 0.002, GO_VACUOLAR_LUMEN
# Passed: cat 5017, mi = 0.006, pvalue = 0.000, GO_CLATHRIN_ADAPTOR_COMPLEX
# Passed: cat 8368, mi = 0.005, pvalue = 0.002, GO_RNA_POLYADENYLATION
# Passed: cat 4146, mi = 0.005, pvalue = 0.003, GO_FATTY_ACID_CATABOLIC_PROCESS
# Passed: cat 4551, mi = 0.005, pvalue = 0.003, GO_BIOMINERALIZATION
# Passed: cat 6038, mi = 0.005, pvalue = 0.003, GO_CAVEOLA
# Didn't pass (cutoff=0.0050): cat 4500, mi = 0.005, pvalue = 0.007, GO_AMINO_ACID_ACTIVATION
# Didn't pass (cutoff=0.0050): cat 7898, mi = 0.005, pvalue = 0.009, GO_GOLGI_CISTERNA
# Didn't pass (cutoff=0.0050): cat 6844, mi = 0.005, pvalue = 0.007, GO_CELLULAR_RESPONSE_TO_RADIATION
# Didn't pass (cutoff=0.0050): cat 7626, mi = 0.005, pvalue = 0.005, GO_POSITIVE_REGULATION_OF_CELL_DIVISION
# Didn't pass (cutoff=0.0050): cat 85, mi = 0.005, pvalue = 0.006, GO_POSITIVE_REGULATION_OF_PROTEIN_DEPHOSPHORYLATION
# Didn't pass (cutoff=0.0050): cat 2934, mi = 0.005, pvalue = 0.006, GO_FEMALE_SEX_DIFFERENTIATION
# Didn't pass (cutoff=0.0050): cat 5682, mi = 0.005, pvalue = 0.008, GO_DEVELOPMENT_OF_PRIMARY_FEMALE_SEXUAL_CHARACTERISTICS
# Didn't pass (cutoff=0.0050): cat 7433, mi = 0.004, pvalue = 0.010, GO_STEROL_BIOSYNTHETIC_PROCESS
# Didn't pass (cutoff=0.0050): cat 9693, mi = 0.004, pvalue = 0.011, GO_REGULATION_OF_CYTOKINESIS
# Didn't pass (cutoff=0.0050): cat 7760, mi = 0.004, pvalue = 0.008, GO_NCRNA_TRANSCRIPTION
# Didn't pass (cutoff=0.0050): cat 4181, mi = 0.004, pvalue = 0.011, GO_IRON_ION_HOMEOSTASIS
# Didn't pass (cutoff=0.0050): cat 141, mi = 0.004, pvalue = 0.010, GO_SNRNA_METABOLIC_PROCESS
# Didn't pass (cutoff=0.0050): cat 9829, mi = 0.004, pvalue = 0.007, GO_ENDOPEPTIDASE_REGULATOR_ACTIVITY
# Didn't pass (cutoff=0.0050): cat 3927, mi = 0.004, pvalue = 0.015, GO_REPLICATION_FORK
# Didn't pass (cutoff=0.0050): cat 7011, mi = 0.004, pvalue = 0.017, GO_TRNA_BINDING
# Didn't pass (cutoff=0.0050): cat 249, mi = 0.004, pvalue = 0.018, GO_NEGATIVE_REGULATION_OF_RESPONSE_TO_DNA_DAMAGE_STIMULUS
# Didn't pass (cutoff=0.0050): cat 1032, mi = 0.004, pvalue = 0.012, GO_SNRNA_PROCESSING
# Didn't pass (cutoff=0.0050): cat 8028, mi = 0.004, pvalue = 0.007, GO_HISTONE_H2A_UBIQUITINATION
# Didn't pass (cutoff=0.0050): cat 2956, mi = 0.004, pvalue = 0.018, GO_NAD_METABOLIC_PROCESS
# Didn't pass (cutoff=0.0050): cat 9104, mi = 0.004, pvalue = 0.018, GO_DNA_REPLICATION_INITIATION
# Total number of categories evaluated = 27.
# Number of categories that passed the tests = 7
# Number of clusters: 11
# calculating the p-value matrix.
# Allocating memory ... Done
# Done
# Writing the p-value matrix to file...Done
# perl /flash/bin/iPAGEv1.0/SCRIPTS/mi_go_draw_matrix.pl  --pvaluematrixfile=6h_delta_stbl.txt_PAGE/pvmatrix.txt --expfile=6h_delta_stbl.txt --order=1 --draw_sample_heatmap=false --min=-3 --max=3 --cluster=5 --quantized=0
# Reading matrix ... Done.
# Cluster rows .. best merge is 1, 5, 0.338318913059155
# best merge is 2, 6, 0.481346579876071
# best merge is 3, 4, 0.565776603636944
# order classes
# 2 - 0.592058097853521
# 2 - 0.842356514783125
# 1 5
# 0
# 2 6
# 3
# 4
# Done.Start drawing
# 0.66	-0.76
# GO_VACUOLAR_LUMEN
# GO_BIOMINERALIZATION
# GO_METHYLATED_HISTONE_BINDING
# GO_RNA_POLYADENYLATION
# GO_FATTY_ACID_CATABOLIC_PROCESS
# GO_CLATHRIN_ADAPTOR_COMPLEX
# GO_CAVEOLA
# Outputing EPS file 6h_delta_stbl.txt_PAGE/6h_delta_stbl.txt.summary.eps
# Convert to PDF 6h_delta_stbl.txt_PAGE/6h_delta_stbl.txt.summary.pdf
# Finished.
# perl /flash/bin/iPAGEv1.0/SCRIPTS/mi_go_draw_matrix_html.pl  --pvaluematrixfile=6h_delta_stbl.txt_PAGE/pvmatrix.txt --expfile=6h_delta_stbl.txt --order=1 --draw_sample_heatmap=false --min=-3 --max=3 --cluster=5 --quantized=0
# Done.
# Cluster rows .. best merge is 1, 5, 0.338318913059155
# best merge is 2, 6, 0.481346579876071
# best merge is 3, 4, 0.565776603636944
# order classes
# 2 - 0.592058097853521
# 2 - 0.842356514783125
# 1 5
# 0
# 2 6
# 3
# 4
# Done.-11.5704225352113	42	0
# -2.40140845070422	42	16.8591549295775
# -0.922535211267608	42	18.3380281690141
# 0.260563380281688	42	19.8169014084507
# 1.14788732394366	42	20.7042253521127
# 2.03521126760564	42	21.5915492957746
# 2.92253521126761	42	22.4788732394366
# 3.80985915492958	42	23.3661971830986
# 4.84507042253522	42	24.2535211267606
# 6.4718309859155	42	25.4366197183099
# 14.7535211267606	42	27.5070422535211
# perl /flash/bin/iPAGEv1.0/SCRIPTS/list_killed_cats.pl --pvmatrixfile=6h_delta_stbl.txt_PAGE/pvmatrix.txt
# DONE
# removed '6h_PAGE/human_ensembl_msigdb_c5/pvmatrix.txt'
# removed '6h_PAGE/human_ensembl_msigdb_c5/imgsrc/under.eps'
# removed '6h_PAGE/human_ensembl_msigdb_c5/imgsrc/over.eps'
# removed directory '6h_PAGE/human_ensembl_msigdb_c5/imgsrc'
# removed '6h_PAGE/human_ensembl_msigdb_c5/6h_delta_stbl.txt.summary.pdf'
# removed '6h_PAGE/human_ensembl_msigdb_c5/6h_delta_stbl.txt.summary.html'
# removed '6h_PAGE/human_ensembl_msigdb_c5/SUMMARY/GO_PALLIUM_DEVELOPMENT.pdf'
# removed '6h_PAGE/human_ensembl_msigdb_c5/SUMMARY/GO_PALLIUM_DEVELOPMENT.eps'
# removed directory '6h_PAGE/human_ensembl_msigdb_c5/SUMMARY'
# removed '6h_PAGE/human_ensembl_msigdb_c5/output.ipage_intersections'
# removed '6h_PAGE/human_ensembl_msigdb_c5/6h_delta_stbl.txt.summary.eps'
# removed '6h_PAGE/human_ensembl_msigdb_c5/pvmatrix.txt.log'
# removed '6h_PAGE/human_ensembl_msigdb_c5/input.ipage_quantized'
# removed '6h_PAGE/human_ensembl_msigdb_c5/pvmatrix.txt.killed'
# removed '6h_PAGE/human_ensembl_msigdb_c5/info.txt'
# removed directory '6h_PAGE/human_ensembl_msigdb_c5/'
# renamed '6h_delta_stbl.txt_PAGE/' -> '6h_PAGE/human_ensembl_msigdb_c5/'
# Reading expression data ... 1 by 4271... Done.
# Creating hash ... Done
# Reading GO names table ... entering
# Done.
# Reading GO index table ... entering
# Done.
# go_terms_num: 189
# Creating hash table for gene names in gene ontology index file ... Done.
# gene num = 2342 out of 4271
# Creating hash table for gene ontology names ... Done.
# Populating the GO profile table ... 2342	189
# Done.
# Writing internal quantized groups ...Done
# 213 hits go_terms_num = 189
# cat 52, mi = 0.00849476, EGFR_UP.V1_UP
# cat 91, mi = 0.00743050, BMI1_DN_MEL18_DN.V1_UP
# cat 160, mi = 0.00740138, KRAS.DF.V1_UP
# cat 94, mi = 0.00701598, AKT_UP.V1_DN
# cat 110, mi = 0.00693228, ESC_J1_UP_EARLY.V1_DN
# cat 180, mi = 0.00677730, NOTCH_DN.V1_UP
# cat 113, mi = 0.00666769, CYCLIN_D1_UP.V1_DN
# cat 51, mi = 0.00634879, MEK_UP.V1_UP
# cat 106, mi = 0.00633703, RB_P107_DN.V1_UP
# cat 164, mi = 0.00630477, CYCLIN_D1_UP.V1_UP
# cat 45, mi = 0.00630004, RELA_DN.V1_UP
# cat 185, mi = 0.00628796, DCA_UP.V1_UP
# cat 73, mi = 0.00608638, ESC_J1_UP_LATE.V1_DN
# cat 114, mi = 0.00603681, ESC_J1_UP_EARLY.V1_UP
# cat 102, mi = 0.00602821, PIGF_UP.V1_UP
#
# RESULTS
# Didn't pass (cutoff=0.0050): cat 52, mi = 0.008, pvalue = 0.005, EGFR_UP.V1_UP
# Didn't pass (cutoff=0.0050): cat 91, mi = 0.007, pvalue = 0.009, BMI1_DN_MEL18_DN.V1_UP
# Didn't pass (cutoff=0.0050): cat 160, mi = 0.007, pvalue = 0.013, KRAS.DF.V1_UP
# Didn't pass (cutoff=0.0050): cat 94, mi = 0.007, pvalue = 0.018, AKT_UP.V1_DN
# Didn't pass (cutoff=0.0050): cat 110, mi = 0.007, pvalue = 0.024, ESC_J1_UP_EARLY.V1_DN
# Didn't pass (cutoff=0.0050): cat 180, mi = 0.007, pvalue = 0.029, NOTCH_DN.V1_UP
# Didn't pass (cutoff=0.0050): cat 113, mi = 0.007, pvalue = 0.025, CYCLIN_D1_UP.V1_DN
# Didn't pass (cutoff=0.0050): cat 51, mi = 0.006, pvalue = 0.041, MEK_UP.V1_UP
# Didn't pass (cutoff=0.0050): cat 106, mi = 0.006, pvalue = 0.040, RB_P107_DN.V1_UP
# Didn't pass (cutoff=0.0050): cat 164, mi = 0.006, pvalue = 0.045, CYCLIN_D1_UP.V1_UP
# Didn't pass (cutoff=0.0050): cat 45, mi = 0.006, pvalue = 0.040, RELA_DN.V1_UP
# Didn't pass (cutoff=0.0050): cat 185, mi = 0.006, pvalue = 0.033, DCA_UP.V1_UP
# Didn't pass (cutoff=0.0050): cat 73, mi = 0.006, pvalue = 0.057, ESC_J1_UP_LATE.V1_DN
# Didn't pass (cutoff=0.0050): cat 114, mi = 0.006, pvalue = 0.061, ESC_J1_UP_EARLY.V1_UP
# ...
# cat 373, mi = 0.00303589, LARP4_K562_POSTAR_eCLIP
#
# RESULTS
# Passed: cat 184, mi = 0.005, pvalue = 0.005, ELAVL1_HeLa_POSTAR_PARalyzer
# Didn't pass (cutoff=0.0050): cat 308, mi = 0.004, pvalue = 0.012, HNRNPK_K562_POSTAR_eCLIP
# Didn't pass (cutoff=0.0050): cat 52, mi = 0.004, pvalue = 0.011, CF_Im68_HEK293_Plass
# Didn't pass (cutoff=0.0050): cat 446, mi = 0.004, pvalue = 0.032, NOP58_HEK293_Plass
# Didn't pass (cutoff=0.0050): cat 404, mi = 0.004, pvalue = 0.025, MBNL2_frontalcortex_POSTAR_Piranha_0.01
# Didn't pass (cutoff=0.0050): cat 748, mi = 0.003, pvalue = 0.034, YTHDC2_HEK293T_POSTAR_CIMS
# Didn't pass (cutoff=0.0050): cat 750, mi = 0.003, pvalue = 0.031, YTHDC2_HEK293T_POSTAR_iCLIP
# Didn't pass (cutoff=0.0050): cat 678, mi = 0.003, pvalue = 0.056, TRA2A_HepG2_POSTAR_eCLIP
# Didn't pass (cutoff=0.0050): cat 588, mi = 0.003, pvalue = 0.048, SRSF1_K562_POSTAR_eCLIP
# Didn't pass (cutoff=0.0050): cat 439, mi = 0.003, pvalue = 0.086, NOP56_HEK293_POSTAR_PAR-CLIP
# Didn't pass (cutoff=0.0050): cat 419, mi = 0.003, pvalue = 0.077, MOV10_HEK293_Plass
# Didn't pass (cutoff=0.0050): cat 406, mi = 0.003, pvalue = 0.079, MBNL2_hippocampus_POSTAR_HITS-CLIP
# Didn't pass (cutoff=0.0050): cat 513, mi = 0.003, pvalue = 0.117, RBM10_HEK293T_POSTAR_HITS-CLIP
# Didn't pass (cutoff=0.0050): cat 58, mi = 0.003, pvalue = 0.106, CPSF-160_HEK293_Plass
# Didn't pass (cutoff=0.0050): cat 648, mi = 0.003, pvalue = 0.132, TBRG4_K562_POSTAR_eCLIP
# Didn't pass (cutoff=0.0050): cat 398, mi = 0.003, pvalue = 0.144, LSM11_K562_POSTAR_eCLIP
# Didn't pass (cutoff=0.0050): cat 440, mi = 0.003, pvalue = 0.148, NOP56_HEK293_POSTAR_PARalyzer
# Didn't pass (cutoff=0.0050): cat 593, mi = 0.003, pvalue = 0.112, SRSF7_HepG2_POSTAR_eCLIP
# Didn't pass (cutoff=0.0050): cat 512, mi = 0.003, pvalue = 0.159, RBM10_HEK293T_POSTAR_CIMS
# Didn't pass (cutoff=0.0050): cat 375, mi = 0.003, pvalue = 0.151, LARP7_HepG2_POSTAR_eCLIP
# Didn't pass (cutoff=0.0050): cat 111, mi = 0.003, pvalue = 0.166, DDX42_K562_POSTAR_eCLIP
# Total number of categories evaluated = 17.
# Number of categories that passed the tests = 1
# Number of clusters: 11
# calculating the p-value matrix.
# Allocating memory ... Done
# Done
# Writing the p-value matrix to file...Done
# perl /flash/bin/iPAGEv1.0/SCRIPTS/mi_go_draw_matrix.pl  --pvaluematrixfile=120h_delta_stbl.txt_PAGE/pvmatrix.txt --expfile=120h_delta_stbl.txt --order=1 --draw_sample_heatmap=false --min=-3 --max=3 --cluster=5 --quantized=0
# Reading matrix ... Done.
# Start drawing
# 1.51	-1.03
# ELAVL1_HeLa_POSTAR_PARalyzer
# Outputing EPS file 120h_delta_stbl.txt_PAGE/120h_delta_stbl.txt.summary.eps
# Convert to PDF 120h_delta_stbl.txt_PAGE/120h_delta_stbl.txt.summary.pdf
# Finished.
# perl /flash/bin/iPAGEv1.0/SCRIPTS/mi_go_draw_matrix_html.pl  --pvaluematrixfile=120h_delta_stbl.txt_PAGE/pvmatrix.txt --expfile=120h_delta_stbl.txt --order=1 --draw_sample_heatmap=false --min=-3 --max=3 --cluster=5 --quantized=0
# Done.
# -13.8818897637795	42	0
# -7.01968503937008	42	12.2362204724409
# -5.77952755905512	42	13.7244094488189
# -4.95275590551181	42	14.7165354330709
# -4.29133858267716	42	15.3779527559055
# -3.54724409448819	42	16.0393700787402
# -2.88582677165354	42	16.8661417322835
# -2.2244094488189	42	17.3622047244094
# -1.39763779527559	42	18.1889763779528
# -0.240157480314963	42	19.0157480314961
# 11.251968503937	42	20.503937007874
# perl /flash/bin/iPAGEv1.0/SCRIPTS/list_killed_cats.pl --pvmatrixfile=120h_delta_stbl.txt_PAGE/pvmatrix.txt
# DONE
# removed '120h_PAGE/human_ensembl_RBPs_coding_gene_ids_by_coding_exons/pvmatrix.txt'
# removed '120h_PAGE/human_ensembl_RBPs_coding_gene_ids_by_coding_exons/120h_delta_stbl.txt.summary.pdf'
# removed '120h_PAGE/human_ensembl_RBPs_coding_gene_ids_by_coding_exons/input.ipage_quantized'
# removed '120h_PAGE/human_ensembl_RBPs_coding_gene_ids_by_coding_exons/120h_delta_stbl.txt.summary.eps'
# removed directory '120h_PAGE/human_ensembl_RBPs_coding_gene_ids_by_coding_exons/SUMMARY'
# removed '120h_PAGE/human_ensembl_RBPs_coding_gene_ids_by_coding_exons/pvmatrix.txt.log'
# removed '120h_PAGE/human_ensembl_RBPs_coding_gene_ids_by_coding_exons/info.txt'
# removed '120h_PAGE/human_ensembl_RBPs_coding_gene_ids_by_coding_exons/pvmatrix.txt.killed'
# removed '120h_PAGE/human_ensembl_RBPs_coding_gene_ids_by_coding_exons/output.ipage_intersections'
# removed directory '120h_PAGE/human_ensembl_RBPs_coding_gene_ids_by_coding_exons/'
# renamed '120h_delta_stbl.txt_PAGE/' -> '120h_PAGE/human_ensembl_RBPs_coding_gene_ids_by_coding_exons/'
# Reading expression data ... 1 by 4271... Done.
# Creating hash ... Done
# Reading GO names table ... entering
# Done.
# Reading GO index table ... entering
# Done.
# go_terms_num: 790
# Creating hash table for gene names in gene ontology index file ... Done.
# gene num = 4218 out of 4271
# Creating hash table for gene ontology names ... Done.
# Populating the GO profile table ... 4218	790
# Done.
# Writing internal quantized groups ...Done
# 383 hits go_terms_num = 790
# cat 569, mi = 0.00483246, SLBP_K562_POSTAR_eCLIP
# cat 10, mi = 0.00370753, AGO3_HEK293_Plass
# cat 447, mi = 0.00345730, NPM1_K562_POSTAR_eCLIP
# cat 129, mi = 0.00324640, DGCR8_HEK293_Plass
# cat 456, mi = 0.00307434, PAPD5_HEK293_Plass
# cat 57, mi = 0.00306843, CPSF-100_HEK293_Plass
# cat 387, mi = 0.00302813, LIN28A_HEK293_Plass
# cat 676, mi = 0.00300729, TNRC6C_HEK293_POSTAR_Piranha_0.01
# cat 673, mi = 0.00287223, TNRC6B_HEK293_Plass
# cat 428, mi = 0.00276575, NCBP3_HEK293_POSTAR_Piranha_0.01
# cat 256, mi = 0.00269866, GNL3_K562_POSTAR_eCLIP
# cat 677, mi = 0.00269116, TNRC6C_HEK293_Plass
# cat 39, mi = 0.00262673, C17orf85_HEK293_Plass
# cat 686, mi = 0.00249047, TTP_HEK293_Plass
# cat 553, mi = 0.00247618, SBDS_K562_POSTAR_eCLIP
#
# RESULTS
# Passed: cat 569, mi = 0.005, pvalue = 0.003, SLBP_K562_POSTAR_eCLIP
# Didn't pass (cutoff=0.0050): cat 10, mi = 0.004, pvalue = 0.026, AGO3_HEK293_Plass
# Didn't pass (cutoff=0.0050): cat 129, mi = 0.003, pvalue = 0.056, DGCR8_HEK293_Plass
# Didn't pass (cutoff=0.0050): cat 456, mi = 0.003, pvalue = 0.101, PAPD5_HEK293_Plass
# Didn't pass (cutoff=0.0050): cat 57, mi = 0.003, pvalue = 0.098, CPSF-100_HEK293_Plass
# Didn't pass (cutoff=0.0050): cat 387, mi = 0.003, pvalue = 0.089, LIN28A_HEK293_Plass
# Didn't pass (cutoff=0.0050): cat 673, mi = 0.003, pvalue = 0.099, TNRC6B_HEK293_Plass
# Didn't pass (cutoff=0.0050): cat 428, mi = 0.003, pvalue = 0.119, NCBP3_HEK293_POSTAR_Piranha_0.01
# Didn't pass (cutoff=0.0050): cat 677, mi = 0.003, pvalue = 0.085, TNRC6C_HEK293_Plass
# Didn't pass (cutoff=0.0050): cat 39, mi = 0.003, pvalue = 0.164, C17orf85_HEK293_Plass
# Didn't pass (cutoff=0.0050): cat 686, mi = 0.002, pvalue = 0.181, TTP_HEK293_Plass
# Didn't pass (cutoff=0.0050): cat 11, mi = 0.002, pvalue = 0.242, AGO4_HEK293_Plass
# Didn't pass (cutoff=0.0050): cat 237, mi = 0.002, pvalue = 0.314, FUS_HeLa_POSTAR_Piranha_0.01
# Didn't pass (cutoff=0.0050): cat 236, mi = 0.002, pvalue = 0.437, FUS_HeLa_POSTAR_HITS-CLIP
# Didn't pass (cutoff=0.0050): cat 635, mi = 0.002, pvalue = 0.440, TARDBP_H9_POSTAR_CIMS
# Didn't pass (cutoff=0.0050): cat 637, mi = 0.002, pvalue = 0.448, TARDBP_H9_POSTAR_iCLIP
# Didn't pass (cutoff=0.0050): cat 173, mi = 0.002, pvalue = 0.340, EIF4A3_HeLa_POSTAR_CIMS
# Didn't pass (cutoff=0.0050): cat 329, mi = 0.002, pvalue = 0.353, HNRNPU_HepG2_POSTAR_eCLIP
# Didn't pass (cutoff=0.0050): cat 97, mi = 0.002, pvalue = 0.430, DCK1_HEK293_Plass
# Didn't pass (cutoff=0.0050): cat 270, mi = 0.002, pvalue = 0.416, HLTF_K562_POSTAR_eCLIP
# Didn't pass (cutoff=0.0050): cat 666, mi = 0.002, pvalue = 0.389, TNRC6A_HEK293_POSTAR_PARalyzer
# Total number of categories evaluated = 23.
# Number of categories that passed the tests = 1
# Number of clusters: 11
# calculating the p-value matrix.
# Allocating memory ... Done
# Done
# Writing the p-value matrix to file...Done
# perl /flash/bin/iPAGEv1.0/SCRIPTS/mi_go_draw_matrix.pl  --pvaluematrixfile=120h_delta_stbl.txt_PAGE/pvmatrix.txt --expfile=120h_delta_stbl.txt --order=1 --draw_sample_heatmap=false --min=-3 --max=3 --cluster=5 --quantized=0
# Reading matrix ... Done.
# Start drawing
# 1.51	-1.03
# SLBP_K562_POSTAR_eCLIP
# Outputing EPS file 120h_delta_stbl.txt_PAGE/120h_delta_stbl.txt.summary.eps
# Convert to PDF 120h_delta_stbl.txt_PAGE/120h_delta_stbl.txt.summary.pdf
# Finished.
# perl /flash/bin/iPAGEv1.0/SCRIPTS/mi_go_draw_matrix_html.pl  --pvaluematrixfile=120h_delta_stbl.txt_PAGE/pvmatrix.txt --expfile=120h_delta_stbl.txt --order=1 --draw_sample_heatmap=false --min=-3 --max=3 --cluster=5 --quantized=0
# Done.
# -13.8818897637795	42	0
# -7.01968503937008	42	12.2362204724409
# -5.86220472440945	42	13.7244094488189
# -5.03543307086614	42	14.5511811023622
# -4.29133858267716	42	15.3779527559055
# -3.54724409448819	42	16.0393700787402
# -2.88582677165354	42	16.8661417322835
# -2.2244094488189	42	17.3622047244094
# -1.39763779527559	42	18.1889763779528
# -0.240157480314963	42	19.0157480314961
# 11.251968503937	42	20.503937007874
# perl /flash/bin/iPAGEv1.0/SCRIPTS/list_killed_cats.pl --pvmatrixfile=120h_delta_stbl.txt_PAGE/pvmatrix.txt
# DONE
# removed '120h_PAGE/human_ensembl_RBPs_coding_gene_ids_by_introns/pvmatrix.txt.killed'
# removed '120h_PAGE/human_ensembl_RBPs_coding_gene_ids_by_introns/120h_delta_stbl.txt.summary.eps'
# removed '120h_PAGE/human_ensembl_RBPs_coding_gene_ids_by_introns/info.txt'
# removed '120h_PAGE/human_ensembl_RBPs_coding_gene_ids_by_introns/pvmatrix.txt.log'
# removed '120h_PAGE/human_ensembl_RBPs_coding_gene_ids_by_introns/pvmatrix.txt'
# removed '120h_PAGE/human_ensembl_RBPs_coding_gene_ids_by_introns/120h_delta_stbl.txt.summary.pdf'
# removed directory '120h_PAGE/human_ensembl_RBPs_coding_gene_ids_by_introns/SUMMARY'
# removed '120h_PAGE/human_ensembl_RBPs_coding_gene_ids_by_introns/input.ipage_quantized'
# removed '120h_PAGE/human_ensembl_RBPs_coding_gene_ids_by_introns/output.ipage_intersections'
# removed directory '120h_PAGE/human_ensembl_RBPs_coding_gene_ids_by_introns/'
# renamed '120h_delta_stbl.txt_PAGE/' -> '120h_PAGE/human_ensembl_RBPs_coding_gene_ids_by_introns/'
# Reading expression data ... 1 by 4271... Done.
# Creating hash ... Done
# Reading GO names table ... entering
# Done.
# Reading GO index table ... entering
# Done.
# go_terms_num: 101
# Creating hash table for gene names in gene ontology index file ... Done.
# gene num = 4218 out of 4271
# Creating hash table for gene ontology names ... Done.
# Populating the GO profile table ... 4218	101
# Done.
# Writing internal quantized groups ...Done
# 383 hits go_terms_num = 101
# cat 56, mi = 0.00292659, RBM3
# cat 6, mi = 0.00230860, CPEB4
# cat 62, mi = 0.00230076, RBM46
# cat 68, mi = 0.00227911, RBMS3
# cat 88, mi = 0.00225105, SRSF9.1
# cat 27, mi = 0.00223001, HuR.2
# cat 13, mi = 0.00138676, FXR2
# cat 34, mi = 0.00135164, KHDRBS3
# cat 69, mi = 0.00126307, RBMS3.1
# cat 9, mi = 0.00116770, ESRP2
# cat 21, mi = 0.00082097, HNRNPK
# cat 0, mi = 0.00000000, ANKHD1
# cat 1, mi = 0.00000000, BRUNOL4
# cat 2, mi = 0.00000000, BRUNOL5
# cat 3, mi = 0.00000000, BRUNOL6
#
# RESULTS
# Didn't pass (cutoff=0.0050): cat 56, mi = 0.003, pvalue = 0.133, RBM3
# Didn't pass (cutoff=0.0050): cat 6, mi = 0.002, pvalue = 0.339, CPEB4
# Didn't pass (cutoff=0.0050): cat 62, mi = 0.002, pvalue = 0.278, RBM46
# Didn't pass (cutoff=0.0050): cat 68, mi = 0.002, pvalue = 0.281, RBMS3
# Didn't pass (cutoff=0.0050): cat 88, mi = 0.002, pvalue = 0.329, SRSF9.1
# Didn't pass (cutoff=0.0050): cat 27, mi = 0.002, pvalue = 0.383, HuR.2
# Didn't pass (cutoff=0.0050): cat 13, mi = 0.001, pvalue = 0.796, FXR2
# Didn't pass (cutoff=0.0050): cat 34, mi = 0.001, pvalue = 0.846, KHDRBS3
# Didn't pass (cutoff=0.0050): cat 69, mi = 0.001, pvalue = 0.771, RBMS3.1
# Didn't pass (cutoff=0.0050): cat 9, mi = 0.001, pvalue = 0.831, ESRP2
# Didn't pass (cutoff=0.0050): cat 21, mi = 0.001, pvalue = 0.908, HNRNPK
# Didn't pass: cat 0, mi = 0.000, pvalue = 1.000, ANKHD1
# Didn't pass: cat 1, mi = 0.000, pvalue = 1.000, BRUNOL4
# Didn't pass: cat 2, mi = 0.000, pvalue = 1.000, BRUNOL5
# Didn't pass: cat 3, mi = 0.000, pvalue = 1.000, BRUNOL6
# Didn't pass: cat 4, mi = 0.000, pvalue = 1.000, CNOT4
# Didn't pass: cat 5, mi = 0.000, pvalue = 1.000, CPEB2
# Didn't pass: cat 7, mi = 0.000, pvalue = 1.000, DAZAP1
# Didn't pass: cat 8, mi = 0.000, pvalue = 1.000, ENOX1
# Didn't pass: cat 10, mi = 0.000, pvalue = 1.000, FMR1
# Total number of categories evaluated = 10.
# Number of categories that passed the tests = 0
# Number of clusters: 11
# calculating the p-value matrix.
# Allocating memory ... Done
# Done
# Writing the p-value matrix to file...Done
# perl /flash/bin/iPAGEv1.0/SCRIPTS/mi_go_draw_matrix.pl  --pvaluematrixfile=120h_delta_stbl.txt_PAGE/pvmatrix.txt --expfile=120h_delta_stbl.txt --order=1 --draw_sample_heatmap=false --min=-3 --max=3 --cluster=5 --quantized=0
# Reading matrix ... Done.
# Start drawing
# 1.51	-1.03
# Outputing EPS file 120h_delta_stbl.txt_PAGE/120h_delta_stbl.txt.summary.eps
# Convert to PDF 120h_delta_stbl.txt_PAGE/120h_delta_stbl.txt.summary.pdf
# Finished.
# perl /flash/bin/iPAGEv1.0/SCRIPTS/mi_go_draw_matrix_html.pl  --pvaluematrixfile=120h_delta_stbl.txt_PAGE/pvmatrix.txt --expfile=120h_delta_stbl.txt --order=1 --draw_sample_heatmap=false --min=-3 --max=3 --cluster=5 --quantized=0
# perl /flash/bin/iPAGEv1.0/SCRIPTS/list_killed_cats.pl --pvmatrixfile=120h_delta_stbl.txt_PAGE/pvmatrix.txt
# DONE
# removed '120h_PAGE/human_ensembl_RBPs_DeepBind/pvmatrix.txt'
# removed '120h_PAGE/human_ensembl_RBPs_DeepBind/output.ipage_intersections'
# removed '120h_PAGE/human_ensembl_RBPs_DeepBind/pvmatrix.txt.log'
# removed '120h_PAGE/human_ensembl_RBPs_DeepBind/input.ipage_quantized'
# removed '120h_PAGE/human_ensembl_RBPs_DeepBind/pvmatrix.txt.killed'
# removed '120h_PAGE/human_ensembl_RBPs_DeepBind/120h_delta_stbl.txt.summary.pdf'
# removed directory '120h_PAGE/human_ensembl_RBPs_DeepBind/SUMMARY'
# removed '120h_PAGE/human_ensembl_RBPs_DeepBind/120h_delta_stbl.txt.summary.eps'
# removed '120h_PAGE/human_ensembl_RBPs_DeepBind/info.txt'
# removed directory '120h_PAGE/human_ensembl_RBPs_DeepBind/'
# renamed '120h_delta_stbl.txt_PAGE/' -> '120h_PAGE/human_ensembl_RBPs_DeepBind/'
# nothing to output for html page at /flash/bin/iPAGEv1.0/SCRIPTS/mi_go_draw_matrix_html.pl line 79.
# nothing to output for html page at /flash/bin/iPAGEv1.0/SCRIPTS/mi_go_draw_matrix_html.pl line 79.
# nothing to output for html page at /flash/bin/iPAGEv1.0/SCRIPTS/mi_go_draw_matrix_html.pl line 79.
# command failed: /flash/bin/iPAGEv1.0/PROGRAMS/page -expfile 6h_delta_stbl.txt -goindexfile /flash/bin/iPAGEv1.0/PAGE_DATA/ANNOTATIONS/human_ensembl_RBPs_all_gene_names/human_ensembl_RBPs_all_gene_names_index.txt -gonamesfile /flash/bin/iPAGEv1.0/PAGE_DATA/ANNOTATIONS/human_ensembl_RBPs_all_gene_names/human_ensembl_RBPs_all_gene_names_names.txt -catmaxcount 200 -catmincount 0 -logfile 6h_delta_stbl.txt_PAGE/pvmatrix.txt.log  -quantized 0 -pvaluematrixfile 6h_delta_stbl.txt_PAGE/pvmatrix.txt -max_p 0.005  -F 1  -P 1  -C 1  -independence 1  -ebins 11  at /flash/bin/iPAGEv1.0/page.pl line 300.
# nothing to output for html page at /flash/bin/iPAGEv1.0/SCRIPTS/mi_go_draw_matrix_html.pl line 79.
# nothing to output for html page at /flash/bin/iPAGEv1.0/SCRIPTS/mi_go_draw_matrix_html.pl line 79.
# nothing to output for html page at /flash/bin/iPAGEv1.0/SCRIPTS/mi_go_draw_matrix_html.pl line 79.
# nothing to output for html page at /flash/bin/iPAGEv1.0/SCRIPTS/mi_go_draw_matrix_html.pl line 79.
# command failed: /flash/bin/iPAGEv1.0/PROGRAMS/page -expfile 120h_delta_stbl.txt -goindexfile /flash/bin/iPAGEv1.0/PAGE_DATA/ANNOTATIONS/human_ensembl_RBPs_all_gene_names/human_ensembl_RBPs_all_gene_names_index.txt -gonamesfile /flash/bin/iPAGEv1.0/PAGE_DATA/ANNOTATIONS/human_ensembl_RBPs_all_gene_names/human_ensembl_RBPs_all_gene_names_names.txt -catmaxcount 200 -catmincount 0 -logfile 120h_delta_stbl.txt_PAGE/pvmatrix.txt.log  -quantized 0 -pvaluematrixfile 120h_delta_stbl.txt_PAGE/pvmatrix.txt -max_p 0.005  -F 1  -P 1  -C 1  -independence 1  -ebins 11  at /flash/bin/iPAGEv1.0/page.pl line 300.
# nothing to output for html page at /flash/bin/iPAGEv1.0/SCRIPTS/mi_go_draw_matrix_html.pl line 79.
# nothing to output for html page at /flash/bin/iPAGEv1.0/SCRIPTS/mi_go_draw_matrix_html.pl line 79.
# nothing to output for html page at /flash/bin/iPAGEv1.0/SCRIPTS/mi_go_draw_matrix_html.pl line 79.

# %%
# %%bash
# mkdir -p plots
#
# declare -a Comp=('6h' '120h')
#
# for C in "${Comp[@]}"; do
#     for f in ${C}_PAGE/human_ensembl*/*pdf; do
#         d=`dirname $f`; b=`basename $d`;
#         o=plots/${C}_PAGE_${b}.pdf;
#         cp -v $f $o
#         bash ~/Workflows/my_scripts/pdf2png.sh $o
#     done
# done
# Out:
# '6h_PAGE/human_ensembl/6h_delta_stbl.txt.summary.pdf' -> 'plots/6h_PAGE_human_ensembl.pdf'
# plots/6h_PAGE_human_ensembl.pdf > plots/6h_PAGE_human_ensembl.png
# done!
# '6h_PAGE/human_ensembl_encode_tf/6h_delta_stbl.txt.summary.pdf' -> 'plots/6h_PAGE_human_ensembl_encode_tf.pdf'
# plots/6h_PAGE_human_ensembl_encode_tf.pdf > plots/6h_PAGE_human_ensembl_encode_tf.png
# done!
# '6h_PAGE/human_ensembl_msigdb_c1/6h_delta_stbl.txt.summary.pdf' -> 'plots/6h_PAGE_human_ensembl_msigdb_c1.pdf'
# plots/6h_PAGE_human_ensembl_msigdb_c1.pdf > plots/6h_PAGE_human_ensembl_msigdb_c1.png
# done!
# '6h_PAGE/human_ensembl_msigdb_c2/6h_delta_stbl.txt.summary.pdf' -> 'plots/6h_PAGE_human_ensembl_msigdb_c2.pdf'
# plots/6h_PAGE_human_ensembl_msigdb_c2.pdf > plots/6h_PAGE_human_ensembl_msigdb_c2.png
# done!
# '6h_PAGE/human_ensembl_msigdb_c3/6h_delta_stbl.txt.summary.pdf' -> 'plots/6h_PAGE_human_ensembl_msigdb_c3.pdf'
# plots/6h_PAGE_human_ensembl_msigdb_c3.pdf > plots/6h_PAGE_human_ensembl_msigdb_c3.png
# done!
# '6h_PAGE/human_ensembl_msigdb_c4/6h_delta_stbl.txt.summary.pdf' -> 'plots/6h_PAGE_human_ensembl_msigdb_c4.pdf'
# plots/6h_PAGE_human_ensembl_msigdb_c4.pdf > plots/6h_PAGE_human_ensembl_msigdb_c4.png
# done!
# '6h_PAGE/human_ensembl_msigdb_c5/6h_delta_stbl.txt.summary.pdf' -> 'plots/6h_PAGE_human_ensembl_msigdb_c5.pdf'
# plots/6h_PAGE_human_ensembl_msigdb_c5.pdf > plots/6h_PAGE_human_ensembl_msigdb_c5.png
# done!
# '6h_PAGE/human_ensembl_msigdb_c6/6h_delta_stbl.txt.summary.pdf' -> 'plots/6h_PAGE_human_ensembl_msigdb_c6.pdf'
# plots/6h_PAGE_human_ensembl_msigdb_c6.pdf > plots/6h_PAGE_human_ensembl_msigdb_c6.png
# done!
# '6h_PAGE/human_ensembl_msigdb_c7/6h_delta_stbl.txt.summary.pdf' -> 'plots/6h_PAGE_human_ensembl_msigdb_c7.pdf'
# plots/6h_PAGE_human_ensembl_msigdb_c7.pdf > plots/6h_PAGE_human_ensembl_msigdb_c7.png
# done!
# '6h_PAGE/human_ensembl_msigdb_full/6h_delta_stbl.txt.summary.pdf' -> 'plots/6h_PAGE_human_ensembl_msigdb_full.pdf'
# plots/6h_PAGE_human_ensembl_msigdb_full.pdf > plots/6h_PAGE_human_ensembl_msigdb_full.png
# done!
# '6h_PAGE/human_ensembl_msigdb_h/6h_delta_stbl.txt.summary.pdf' -> 'plots/6h_PAGE_human_ensembl_msigdb_h.pdf'
# plots/6h_PAGE_human_ensembl_msigdb_h.pdf > plots/6h_PAGE_human_ensembl_msigdb_h.png
# done!
# '6h_PAGE/human_ensembl_RBPs_all_gene_ids/6h_delta_stbl.txt.summary.pdf' -> 'plots/6h_PAGE_human_ensembl_RBPs_all_gene_ids.pdf'
# plots/6h_PAGE_human_ensembl_RBPs_all_gene_ids.pdf > plots/6h_PAGE_human_ensembl_RBPs_all_gene_ids.png
# done!
# '6h_PAGE/human_ensembl_RBPs_coding_gene_ids/6h_delta_stbl.txt.summary.pdf' -> 'plots/6h_PAGE_human_ensembl_RBPs_coding_gene_ids.pdf'
# plots/6h_PAGE_human_ensembl_RBPs_coding_gene_ids.pdf > plots/6h_PAGE_human_ensembl_RBPs_coding_gene_ids.png
# done!
# '6h_PAGE/human_ensembl_RBPs_coding_gene_ids_by_3UTR/6h_delta_stbl.txt.summary.pdf' -> 'plots/6h_PAGE_human_ensembl_RBPs_coding_gene_ids_by_3UTR.pdf'
# plots/6h_PAGE_human_ensembl_RBPs_coding_gene_ids_by_3UTR.pdf > plots/6h_PAGE_human_ensembl_RBPs_coding_gene_ids_by_3UTR.png
# done!
# '6h_PAGE/human_ensembl_RBPs_coding_gene_ids_by_5UTR/6h_delta_stbl.txt.summary.pdf' -> 'plots/6h_PAGE_human_ensembl_RBPs_coding_gene_ids_by_5UTR.pdf'
# plots/6h_PAGE_human_ensembl_RBPs_coding_gene_ids_by_5UTR.pdf > plots/6h_PAGE_human_ensembl_RBPs_coding_gene_ids_by_5UTR.png
# done!
# '6h_PAGE/human_ensembl_RBPs_coding_gene_ids_by_coding_exons/6h_delta_stbl.txt.summary.pdf' -> 'plots/6h_PAGE_human_ensembl_RBPs_coding_gene_ids_by_coding_exons.pdf'
# plots/6h_PAGE_human_ensembl_RBPs_coding_gene_ids_by_coding_exons.pdf > plots/6h_PAGE_human_ensembl_RBPs_coding_gene_ids_by_coding_exons.png
# done!
# '6h_PAGE/human_ensembl_RBPs_coding_gene_ids_by_introns/6h_delta_stbl.txt.summary.pdf' -> 'plots/6h_PAGE_human_ensembl_RBPs_coding_gene_ids_by_introns.pdf'
# plots/6h_PAGE_human_ensembl_RBPs_coding_gene_ids_by_introns.pdf > plots/6h_PAGE_human_ensembl_RBPs_coding_gene_ids_by_introns.png
# done!
# '6h_PAGE/human_ensembl_RBPs_DeepBind/6h_delta_stbl.txt.summary.pdf' -> 'plots/6h_PAGE_human_ensembl_RBPs_DeepBind.pdf'
# plots/6h_PAGE_human_ensembl_RBPs_DeepBind.pdf > plots/6h_PAGE_human_ensembl_RBPs_DeepBind.png
# done!
# '120h_PAGE/human_ensembl/120h_delta_stbl.txt.summary.pdf' -> 'plots/120h_PAGE_human_ensembl.pdf'
# plots/120h_PAGE_human_ensembl.pdf > plots/120h_PAGE_human_ensembl.png
# done!
# '120h_PAGE/human_ensembl_encode_tf/120h_delta_stbl.txt.summary.pdf' -> 'plots/120h_PAGE_human_ensembl_encode_tf.pdf'
# plots/120h_PAGE_human_ensembl_encode_tf.pdf > plots/120h_PAGE_human_ensembl_encode_tf.png
# done!
# '120h_PAGE/human_ensembl_msigdb_c1/120h_delta_stbl.txt.summary.pdf' -> 'plots/120h_PAGE_human_ensembl_msigdb_c1.pdf'
# plots/120h_PAGE_human_ensembl_msigdb_c1.pdf > plots/120h_PAGE_human_ensembl_msigdb_c1.png
# done!
# '120h_PAGE/human_ensembl_msigdb_c2/120h_delta_stbl.txt.summary.pdf' -> 'plots/120h_PAGE_human_ensembl_msigdb_c2.pdf'
# plots/120h_PAGE_human_ensembl_msigdb_c2.pdf > plots/120h_PAGE_human_ensembl_msigdb_c2.png
# done!
# '120h_PAGE/human_ensembl_msigdb_c3/120h_delta_stbl.txt.summary.pdf' -> 'plots/120h_PAGE_human_ensembl_msigdb_c3.pdf'
# plots/120h_PAGE_human_ensembl_msigdb_c3.pdf > plots/120h_PAGE_human_ensembl_msigdb_c3.png
# done!
# '120h_PAGE/human_ensembl_msigdb_c4/120h_delta_stbl.txt.summary.pdf' -> 'plots/120h_PAGE_human_ensembl_msigdb_c4.pdf'
# plots/120h_PAGE_human_ensembl_msigdb_c4.pdf > plots/120h_PAGE_human_ensembl_msigdb_c4.png
# done!
# '120h_PAGE/human_ensembl_msigdb_c5/120h_delta_stbl.txt.summary.pdf' -> 'plots/120h_PAGE_human_ensembl_msigdb_c5.pdf'
# plots/120h_PAGE_human_ensembl_msigdb_c5.pdf > plots/120h_PAGE_human_ensembl_msigdb_c5.png
# done!
# '120h_PAGE/human_ensembl_msigdb_c6/120h_delta_stbl.txt.summary.pdf' -> 'plots/120h_PAGE_human_ensembl_msigdb_c6.pdf'
# plots/120h_PAGE_human_ensembl_msigdb_c6.pdf > plots/120h_PAGE_human_ensembl_msigdb_c6.png
# done!
# '120h_PAGE/human_ensembl_msigdb_c7/120h_delta_stbl.txt.summary.pdf' -> 'plots/120h_PAGE_human_ensembl_msigdb_c7.pdf'
# plots/120h_PAGE_human_ensembl_msigdb_c7.pdf > plots/120h_PAGE_human_ensembl_msigdb_c7.png
# done!
# '120h_PAGE/human_ensembl_msigdb_full/120h_delta_stbl.txt.summary.pdf' -> 'plots/120h_PAGE_human_ensembl_msigdb_full.pdf'
# plots/120h_PAGE_human_ensembl_msigdb_full.pdf > plots/120h_PAGE_human_ensembl_msigdb_full.png
# done!
# '120h_PAGE/human_ensembl_msigdb_h/120h_delta_stbl.txt.summary.pdf' -> 'plots/120h_PAGE_human_ensembl_msigdb_h.pdf'
# plots/120h_PAGE_human_ensembl_msigdb_h.pdf > plots/120h_PAGE_human_ensembl_msigdb_h.png
# done!
# '120h_PAGE/human_ensembl_RBPs_all_gene_ids/120h_delta_stbl.txt.summary.pdf' -> 'plots/120h_PAGE_human_ensembl_RBPs_all_gene_ids.pdf'
# plots/120h_PAGE_human_ensembl_RBPs_all_gene_ids.pdf > plots/120h_PAGE_human_ensembl_RBPs_all_gene_ids.png
# done!
# '120h_PAGE/human_ensembl_RBPs_coding_gene_ids/120h_delta_stbl.txt.summary.pdf' -> 'plots/120h_PAGE_human_ensembl_RBPs_coding_gene_ids.pdf'
# plots/120h_PAGE_human_ensembl_RBPs_coding_gene_ids.pdf > plots/120h_PAGE_human_ensembl_RBPs_coding_gene_ids.png
# done!
# '120h_PAGE/human_ensembl_RBPs_coding_gene_ids_by_3UTR/120h_delta_stbl.txt.summary.pdf' -> 'plots/120h_PAGE_human_ensembl_RBPs_coding_gene_ids_by_3UTR.pdf'
# plots/120h_PAGE_human_ensembl_RBPs_coding_gene_ids_by_3UTR.pdf > plots/120h_PAGE_human_ensembl_RBPs_coding_gene_ids_by_3UTR.png
# done!
# '120h_PAGE/human_ensembl_RBPs_coding_gene_ids_by_5UTR/120h_delta_stbl.txt.summary.pdf' -> 'plots/120h_PAGE_human_ensembl_RBPs_coding_gene_ids_by_5UTR.pdf'
# plots/120h_PAGE_human_ensembl_RBPs_coding_gene_ids_by_5UTR.pdf > plots/120h_PAGE_human_ensembl_RBPs_coding_gene_ids_by_5UTR.png
# done!
# '120h_PAGE/human_ensembl_RBPs_coding_gene_ids_by_coding_exons/120h_delta_stbl.txt.summary.pdf' -> 'plots/120h_PAGE_human_ensembl_RBPs_coding_gene_ids_by_coding_exons.pdf'
# plots/120h_PAGE_human_ensembl_RBPs_coding_gene_ids_by_coding_exons.pdf > plots/120h_PAGE_human_ensembl_RBPs_coding_gene_ids_by_coding_exons.png
# done!
# '120h_PAGE/human_ensembl_RBPs_coding_gene_ids_by_introns/120h_delta_stbl.txt.summary.pdf' -> 'plots/120h_PAGE_human_ensembl_RBPs_coding_gene_ids_by_introns.pdf'
# plots/120h_PAGE_human_ensembl_RBPs_coding_gene_ids_by_introns.pdf > plots/120h_PAGE_human_ensembl_RBPs_coding_gene_ids_by_introns.png
# done!
# '120h_PAGE/human_ensembl_RBPs_DeepBind/120h_delta_stbl.txt.summary.pdf' -> 'plots/120h_PAGE_human_ensembl_RBPs_DeepBind.pdf'
# plots/120h_PAGE_human_ensembl_RBPs_DeepBind.pdf > plots/120h_PAGE_human_ensembl_RBPs_DeepBind.png
# done!

# %%
# %%bash
# declare -a Comp=('6h' '120h')
#
# for f in `ls -d /flash/bin/iPAGEv1.0/PAGE_DATA/ANNOTATIONS/human_ensembl*`; do
#     base=`basename "$f"`
#     echo '<table>'
#     echo '  <tr>'
#     echo '  <h2>'$base'<h2>'
#     for C in "${Comp[@]}"; do
#         echo '    <td><img src=plots/'${C}'_PAGE_'${base}'.png style="width:600px">'
#     done
#     echo '  <tr>'
#     echo '<table>'
# done
# Out:
# <table>
#   <tr>
#   <h2>human_ensembl<h2>
#     <td><img src=plots/6h_PAGE_human_ensembl.png style="width:600px">
#     <td><img src=plots/120h_PAGE_human_ensembl.png style="width:600px">
#   <tr>
# <table>
# <table>
#   <tr>
#   <h2>human_ensembl_encode_tf<h2>
#     <td><img src=plots/6h_PAGE_human_ensembl_encode_tf.png style="width:600px">
#     <td><img src=plots/120h_PAGE_human_ensembl_encode_tf.png style="width:600px">
#   <tr>
# <table>
# <table>
#   <tr>
#   <h2>human_ensembl_msigdb_c1<h2>
#     <td><img src=plots/6h_PAGE_human_ensembl_msigdb_c1.png style="width:600px">
#     <td><img src=plots/120h_PAGE_human_ensembl_msigdb_c1.png style="width:600px">
#   <tr>
# <table>
# <table>
#   <tr>
#   <h2>human_ensembl_msigdb_c2<h2>
#     <td><img src=plots/6h_PAGE_human_ensembl_msigdb_c2.png style="width:600px">
#     <td><img src=plots/120h_PAGE_human_ensembl_msigdb_c2.png style="width:600px">
#   <tr>
# <table>
# <table>
#   <tr>
#   <h2>human_ensembl_msigdb_c3<h2>
#     <td><img src=plots/6h_PAGE_human_ensembl_msigdb_c3.png style="width:600px">
#     <td><img src=plots/120h_PAGE_human_ensembl_msigdb_c3.png style="width:600px">
#   <tr>
# <table>
# <table>
#   <tr>
#   <h2>human_ensembl_msigdb_c4<h2>
#     <td><img src=plots/6h_PAGE_human_ensembl_msigdb_c4.png style="width:600px">
#     <td><img src=plots/120h_PAGE_human_ensembl_msigdb_c4.png style="width:600px">
#   <tr>
# <table>
# <table>
#   <tr>
#   <h2>human_ensembl_msigdb_c5<h2>
#     <td><img src=plots/6h_PAGE_human_ensembl_msigdb_c5.png style="width:600px">
#     <td><img src=plots/120h_PAGE_human_ensembl_msigdb_c5.png style="width:600px">
#   <tr>
# <table>
# <table>
#   <tr>
#   <h2>human_ensembl_msigdb_c6<h2>
#     <td><img src=plots/6h_PAGE_human_ensembl_msigdb_c6.png style="width:600px">
#     <td><img src=plots/120h_PAGE_human_ensembl_msigdb_c6.png style="width:600px">
#   <tr>
# <table>
# <table>
#   <tr>
#   <h2>human_ensembl_msigdb_c7<h2>
#     <td><img src=plots/6h_PAGE_human_ensembl_msigdb_c7.png style="width:600px">
#     <td><img src=plots/120h_PAGE_human_ensembl_msigdb_c7.png style="width:600px">
#   <tr>
# <table>
# <table>
#   <tr>
#   <h2>human_ensembl_msigdb_full<h2>
#     <td><img src=plots/6h_PAGE_human_ensembl_msigdb_full.png style="width:600px">
#     <td><img src=plots/120h_PAGE_human_ensembl_msigdb_full.png style="width:600px">
#   <tr>
# <table>
# <table>
#   <tr>
#   <h2>human_ensembl_msigdb_h<h2>
#     <td><img src=plots/6h_PAGE_human_ensembl_msigdb_h.png style="width:600px">
#     <td><img src=plots/120h_PAGE_human_ensembl_msigdb_h.png style="width:600px">
#   <tr>
# <table>
# <table>
#   <tr>
#   <h2>human_ensembl_RBPs_all_gene_ids<h2>
#     <td><img src=plots/6h_PAGE_human_ensembl_RBPs_all_gene_ids.png style="width:600px">
#     <td><img src=plots/120h_PAGE_human_ensembl_RBPs_all_gene_ids.png style="width:600px">
#   <tr>
# <table>
# <table>
#   <tr>
#   <h2>human_ensembl_RBPs_all_gene_names<h2>
#     <td><img src=plots/6h_PAGE_human_ensembl_RBPs_all_gene_names.png style="width:600px">
#     <td><img src=plots/120h_PAGE_human_ensembl_RBPs_all_gene_names.png style="width:600px">
#   <tr>
# <table>
# <table>
#   <tr>
#   <h2>human_ensembl_RBPs_coding_gene_ids<h2>
#     <td><img src=plots/6h_PAGE_human_ensembl_RBPs_coding_gene_ids.png style="width:600px">
#     <td><img src=plots/120h_PAGE_human_ensembl_RBPs_coding_gene_ids.png style="width:600px">
#   <tr>
# <table>
# <table>
#   <tr>
#   <h2>human_ensembl_RBPs_coding_gene_ids_by_3UTR<h2>
#     <td><img src=plots/6h_PAGE_human_ensembl_RBPs_coding_gene_ids_by_3UTR.png style="width:600px">
#     <td><img src=plots/120h_PAGE_human_ensembl_RBPs_coding_gene_ids_by_3UTR.png style="width:600px">
#   <tr>
# <table>
# <table>
#   <tr>
#   <h2>human_ensembl_RBPs_coding_gene_ids_by_5UTR<h2>
#     <td><img src=plots/6h_PAGE_human_ensembl_RBPs_coding_gene_ids_by_5UTR.png style="width:600px">
#     <td><img src=plots/120h_PAGE_human_ensembl_RBPs_coding_gene_ids_by_5UTR.png style="width:600px">
#   <tr>
# <table>
# <table>
#   <tr>
#   <h2>human_ensembl_RBPs_coding_gene_ids_by_coding_exons<h2>
#     <td><img src=plots/6h_PAGE_human_ensembl_RBPs_coding_gene_ids_by_coding_exons.png style="width:600px">
#     <td><img src=plots/120h_PAGE_human_ensembl_RBPs_coding_gene_ids_by_coding_exons.png style="width:600px">
#   <tr>
# <table>
# <table>
#   <tr>
#   <h2>human_ensembl_RBPs_coding_gene_ids_by_introns<h2>
#     <td><img src=plots/6h_PAGE_human_ensembl_RBPs_coding_gene_ids_by_introns.png style="width:600px">
#     <td><img src=plots/120h_PAGE_human_ensembl_RBPs_coding_gene_ids_by_introns.png style="width:600px">
#   <tr>
# <table>
# <table>
#   <tr>
#   <h2>human_ensembl_RBPs_DeepBind<h2>
#     <td><img src=plots/6h_PAGE_human_ensembl_RBPs_DeepBind.png style="width:600px">
#     <td><img src=plots/120h_PAGE_human_ensembl_RBPs_DeepBind.png style="width:600px">
#   <tr>
# <table>

# %% [markdown]
# <table>
#   <tr>
#   <h2>human_ensembl<h2>
#     <td><img src=plots/6h_PAGE_human_ensembl.png style="width:600px">
#     <td><img src=plots/120h_PAGE_human_ensembl.png style="width:600px">
#   <tr>
# <table>
# <table>
#   <tr>
#   <h2>human_ensembl_encode_tf<h2>
#     <td><img src=plots/6h_PAGE_human_ensembl_encode_tf.png style="width:600px">
#     <td><img src=plots/120h_PAGE_human_ensembl_encode_tf.png style="width:600px">
#   <tr>
# <table>
# <table>
#   <tr>
#   <h2>human_ensembl_msigdb_c1<h2>
#     <td><img src=plots/6h_PAGE_human_ensembl_msigdb_c1.png style="width:600px">
#     <td><img src=plots/120h_PAGE_human_ensembl_msigdb_c1.png style="width:600px">
#   <tr>
# <table>
# <table>
#   <tr>
#   <h2>human_ensembl_msigdb_c2<h2>
#     <td><img src=plots/6h_PAGE_human_ensembl_msigdb_c2.png style="width:600px">
#     <td><img src=plots/120h_PAGE_human_ensembl_msigdb_c2.png style="width:600px">
#   <tr>
# <table>
# <table>
#   <tr>
#   <h2>human_ensembl_msigdb_c3<h2>
#     <td><img src=plots/6h_PAGE_human_ensembl_msigdb_c3.png style="width:600px">
#     <td><img src=plots/120h_PAGE_human_ensembl_msigdb_c3.png style="width:600px">
#   <tr>
# <table>
# <table>
#   <tr>
#   <h2>human_ensembl_msigdb_c4<h2>
#     <td><img src=plots/6h_PAGE_human_ensembl_msigdb_c4.png style="width:600px">
#     <td><img src=plots/120h_PAGE_human_ensembl_msigdb_c4.png style="width:600px">
#   <tr>
# <table>
# <table>
#   <tr>
#   <h2>human_ensembl_msigdb_c5<h2>
#     <td><img src=plots/6h_PAGE_human_ensembl_msigdb_c5.png style="width:600px">
#     <td><img src=plots/120h_PAGE_human_ensembl_msigdb_c5.png style="width:600px">
#   <tr>
# <table>
# <table>
#   <tr>
#   <h2>human_ensembl_msigdb_c6<h2>
#     <td><img src=plots/6h_PAGE_human_ensembl_msigdb_c6.png style="width:600px">
#     <td><img src=plots/120h_PAGE_human_ensembl_msigdb_c6.png style="width:600px">
#   <tr>
# <table>
# <table>
#   <tr>
#   <h2>human_ensembl_msigdb_c7<h2>
#     <td><img src=plots/6h_PAGE_human_ensembl_msigdb_c7.png style="width:600px">
#     <td><img src=plots/120h_PAGE_human_ensembl_msigdb_c7.png style="width:600px">
#   <tr>
# <table>
# <table>
#   <tr>
#   <h2>human_ensembl_msigdb_full<h2>
#     <td><img src=plots/6h_PAGE_human_ensembl_msigdb_full.png style="width:600px">
#     <td><img src=plots/120h_PAGE_human_ensembl_msigdb_full.png style="width:600px">
#   <tr>
# <table>
# <table>
#   <tr>
#   <h2>human_ensembl_msigdb_h<h2>
#     <td><img src=plots/6h_PAGE_human_ensembl_msigdb_h.png style="width:600px">
#     <td><img src=plots/120h_PAGE_human_ensembl_msigdb_h.png style="width:600px">
#   <tr>
# <table>
# <table>
#   <tr>
#   <h2>human_ensembl_RBPs_all_gene_ids<h2>
#     <td><img src=plots/6h_PAGE_human_ensembl_RBPs_all_gene_ids.png style="width:600px">
#     <td><img src=plots/120h_PAGE_human_ensembl_RBPs_all_gene_ids.png style="width:600px">
#   <tr>
# <table>
# <table>
#   <tr>
#   <h2>human_ensembl_RBPs_all_gene_names<h2>
#     <td><img src=plots/6h_PAGE_human_ensembl_RBPs_all_gene_names.png style="width:600px">
#     <td><img src=plots/120h_PAGE_human_ensembl_RBPs_all_gene_names.png style="width:600px">
#   <tr>
# <table>
# <table>
#   <tr>
#   <h2>human_ensembl_RBPs_coding_gene_ids<h2>
#     <td><img src=plots/6h_PAGE_human_ensembl_RBPs_coding_gene_ids.png style="width:600px">
#     <td><img src=plots/120h_PAGE_human_ensembl_RBPs_coding_gene_ids.png style="width:600px">
#   <tr>
# <table>
# <table>
#   <tr>
#   <h2>human_ensembl_RBPs_coding_gene_ids_by_3UTR<h2>
#     <td><img src=plots/6h_PAGE_human_ensembl_RBPs_coding_gene_ids_by_3UTR.png style="width:600px">
#     <td><img src=plots/120h_PAGE_human_ensembl_RBPs_coding_gene_ids_by_3UTR.png style="width:600px">
#   <tr>
# <table>
# <table>
#   <tr>
#   <h2>human_ensembl_RBPs_coding_gene_ids_by_5UTR<h2>
#     <td><img src=plots/6h_PAGE_human_ensembl_RBPs_coding_gene_ids_by_5UTR.png style="width:600px">
#     <td><img src=plots/120h_PAGE_human_ensembl_RBPs_coding_gene_ids_by_5UTR.png style="width:600px">
#   <tr>
# <table>
# <table>
#   <tr>
#   <h2>human_ensembl_RBPs_coding_gene_ids_by_coding_exons<h2>
#     <td><img src=plots/6h_PAGE_human_ensembl_RBPs_coding_gene_ids_by_coding_exons.png style="width:600px">
#     <td><img src=plots/120h_PAGE_human_ensembl_RBPs_coding_gene_ids_by_coding_exons.png style="width:600px">
#   <tr>
# <table>
# <table>
#   <tr>
#   <h2>human_ensembl_RBPs_coding_gene_ids_by_introns<h2>
#     <td><img src=plots/6h_PAGE_human_ensembl_RBPs_coding_gene_ids_by_introns.png style="width:600px">
#     <td><img src=plots/120h_PAGE_human_ensembl_RBPs_coding_gene_ids_by_introns.png style="width:600px">
#   <tr>
# <table>
# <table>
#   <tr>
#   <h2>human_ensembl_RBPs_DeepBind<h2>
#     <td><img src=plots/6h_PAGE_human_ensembl_RBPs_DeepBind.png style="width:600px">
#     <td><img src=plots/120h_PAGE_human_ensembl_RBPs_DeepBind.png style="width:600px">
#   <tr>
# <table>

# %%
# %%R
# sessionInfo()
# Out:
# R version 4.0.2 (2020-06-22)
# Platform: x86_64-conda_cos6-linux-gnu (64-bit)
# Running under: Ubuntu 18.04.4 LTS
#
# Matrix products: default
# BLAS/LAPACK: /rumi/shams/abe/anaconda3/envs/limma/lib/libopenblasp-r0.3.10.so
#
# locale:
#  [1] LC_CTYPE=en_US.UTF-8       LC_NUMERIC=C
#  [3] LC_TIME=en_US.UTF-8        LC_COLLATE=en_US.UTF-8
#  [5] LC_MONETARY=en_US.UTF-8    LC_MESSAGES=en_US.UTF-8
#  [7] LC_PAPER=en_US.UTF-8       LC_NAME=C
#  [9] LC_ADDRESS=C               LC_TELEPHONE=C
# [11] LC_MEASUREMENT=en_US.UTF-8 LC_IDENTIFICATION=C
#
# attached base packages:
#  [1] stats4    parallel  tools     stats     graphics  grDevices utils
#  [8] datasets  methods   base
#
# other attached packages:
#  [1] pheatmap_1.0.12      forcats_0.5.0        stringr_1.4.0
#  [4] dplyr_1.0.1          purrr_0.3.4          readr_1.3.1
#  [7] tidyr_1.1.1          tibble_3.0.3         ggplot2_3.3.2
# [10] tidyverse_1.3.0      rtracklayer_1.48.0   GenomicRanges_1.40.0
# [13] GenomeInfoDb_1.24.0  IRanges_2.22.1       S4Vectors_0.26.0
# [16] Biobase_2.48.0       BiocGenerics_0.34.0  edgeR_3.30.0
# [19] limma_3.44.1
#
# loaded via a namespace (and not attached):
#  [1] Rcpp_1.0.4.6                locfit_1.5-9.4
#  [3] lubridate_1.7.9             lattice_0.20-41
#  [5] Rsamtools_2.4.0             Biostrings_2.56.0
#  [7] assertthat_0.2.1            R6_2.4.1
#  [9] cellranger_1.1.0            backports_1.1.8
# [11] reprex_0.3.0                httr_1.4.2
# [13] pillar_1.4.6                zlibbioc_1.34.0
# [15] rlang_0.4.7                 readxl_1.3.1
# [17] rstudioapi_0.11             blob_1.2.1
# [19] Matrix_1.2-18               BiocParallel_1.22.0
# [21] RCurl_1.98-1.2              munsell_0.5.0
# [23] DelayedArray_0.14.0         broom_0.7.0
# [25] compiler_4.0.2              modelr_0.1.8
# [27] pkgconfig_2.0.3             tidyselect_1.1.0
# [29] SummarizedExperiment_1.18.1 GenomeInfoDbData_1.2.3
# [31] matrixStats_0.56.0          XML_3.99-0.3
# [33] fansi_0.4.1                 withr_2.2.0
# [35] crayon_1.3.4                dbplyr_1.4.4
# [37] GenomicAlignments_1.24.0    bitops_1.0-6
# [39] grid_4.0.2                  jsonlite_1.7.0
# [41] gtable_0.3.0                lifecycle_0.2.0
# [43] DBI_1.1.0                   magrittr_1.5
# [45] scales_1.1.1                cli_2.0.2
# [47] stringi_1.4.6               XVector_0.28.0
# [49] fs_1.5.0                    xml2_1.3.2
# [51] ellipsis_0.3.1              generics_0.0.2
# [53] vctrs_0.3.2                 RColorBrewer_1.1-2
# [55] glue_1.4.1                  hms_0.5.3
# [57] colorspace_1.4-1            rvest_0.3.6
# [59] haven_2.3.1
