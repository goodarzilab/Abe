# %% [markdown]
# Rename bams

# %%
# %%bash
#
# for f in hl60-bam/*.bam; do
#     o=${f/.bamAligned.sortedByCoord.out.bam/.bam};
#     mv -v $f $o;
# done
# Out:
# renamed 'hl60-bam/120h_DMSO_rep1.bamAligned.sortedByCoord.out.bam' -> 'hl60-bam/120h_DMSO_rep1.bam'
# renamed 'hl60-bam/120h_DMSO_rep2.bamAligned.sortedByCoord.out.bam' -> 'hl60-bam/120h_DMSO_rep2.bam'
# renamed 'hl60-bam/120h_treated_rep1.bamAligned.sortedByCoord.out.bam' -> 'hl60-bam/120h_treated_rep1.bam'
# renamed 'hl60-bam/120h_treated_rep2.bamAligned.sortedByCoord.out.bam' -> 'hl60-bam/120h_treated_rep2.bam'
# renamed 'hl60-bam/6h_DMSO_rep1.bamAligned.sortedByCoord.out.bam' -> 'hl60-bam/6h_DMSO_rep1.bam'
# renamed 'hl60-bam/6h_DMSO_rep2.bamAligned.sortedByCoord.out.bam' -> 'hl60-bam/6h_DMSO_rep2.bam'
# renamed 'hl60-bam/6h_treated_rep1.bamAligned.sortedByCoord.out.bam' -> 'hl60-bam/6h_treated_rep1.bam'
# renamed 'hl60-bam/6h_treated_rep2.bamAligned.sortedByCoord.out.bam' -> 'hl60-bam/6h_treated_rep2.bam'
# renamed 'hl60-bam/72h_DMSO_rep1.bamAligned.sortedByCoord.out.bam' -> 'hl60-bam/72h_DMSO_rep1.bam'
# renamed 'hl60-bam/72h_DMSO_rep2.bamAligned.sortedByCoord.out.bam' -> 'hl60-bam/72h_DMSO_rep2.bam'
# renamed 'hl60-bam/72h_treated_rep1.bamAligned.sortedByCoord.out.bam' -> 'hl60-bam/72h_treated_rep1.bam'
# renamed 'hl60-bam/72h_treated_rep2.bamAligned.sortedByCoord.out.bam' -> 'hl60-bam/72h_treated_rep2.bam'

# %% [markdown]
# fastq QC

# %%
# %%bash
# for f in other-fastq/*; do
#     fastqc $f
# done
# Out:
# Analysis complete for kg1_t_1.fastq.gz
# Analysis complete for kg1_t_2.fastq.gz
# Analysis complete for kg1_t_3.fastq.gz
# Analysis complete for kg1_u_1.fastq.gz
# Analysis complete for kg1_u_2.fastq.gz
# Analysis complete for kg1_u_3.fastq.gz
# Analysis complete for molm14_t_1.fastq.gz
# Analysis complete for molm14_t_2.fastq.gz
# Analysis complete for molm14_t_3.fastq.gz
# Analysis complete for molm14_u_1.fastq.gz
# Analysis complete for molm14_u_2.fastq.gz
# Analysis complete for molm14_u_3.fastq.gz
# Analysis complete for ociaml2_t_1.fastq.gz
# Analysis complete for ociaml2_t_2.fastq.gz
# Analysis complete for ociaml2_t_3.fastq.gz
# Analysis complete for ociaml2_u_1.fastq.gz
# Analysis complete for ociaml2_u_2.fastq.gz
# Analysis complete for ociaml2_u_3.fastq.gz
# Analysis complete for ociaml3_t_1.fastq.gz
# Analysis complete for ociaml3_t_2.fastq.gz
# Analysis complete for ociaml3_t_3.fastq.gz
# Analysis complete for ociaml3_u_1.fastq.gz
# Analysis complete for ociaml3_u_2.fastq.gz
# Analysis complete for ociaml3_u_3.fastq.gz
# Analysis complete for thp1_t_1.fastq.gz
# Analysis complete for thp1_t_2.fastq.gz
# Analysis complete for thp1_t_3.fastq.gz
# Analysis complete for thp1_u_1.fastq.gz
# Analysis complete for thp1_u_2.fastq.gz
# Analysis complete for thp1_u_3.fastq.gz
# Started analysis of kg1_t_1.fastq.gz
# Approx 5% complete for kg1_t_1.fastq.gz
# Approx 10% complete for kg1_t_1.fastq.gz
# Approx 15% complete for kg1_t_1.fastq.gz
# Approx 20% complete for kg1_t_1.fastq.gz
# Approx 25% complete for kg1_t_1.fastq.gz
# Approx 30% complete for kg1_t_1.fastq.gz
# Approx 35% complete for kg1_t_1.fastq.gz
# Approx 40% complete for kg1_t_1.fastq.gz
# Approx 45% complete for kg1_t_1.fastq.gz
# Approx 50% complete for kg1_t_1.fastq.gz
# Approx 55% complete for kg1_t_1.fastq.gz
# Approx 60% complete for kg1_t_1.fastq.gz
# Approx 65% complete for kg1_t_1.fastq.gz
# Approx 70% complete for kg1_t_1.fastq.gz
# Approx 75% complete for kg1_t_1.fastq.gz
# Approx 80% complete for kg1_t_1.fastq.gz
# Approx 85% complete for kg1_t_1.fastq.gz
# Approx 90% complete for kg1_t_1.fastq.gz
# Approx 95% complete for kg1_t_1.fastq.gz
# Started analysis of kg1_t_2.fastq.gz
# Approx 5% complete for kg1_t_2.fastq.gz
# Approx 10% complete for kg1_t_2.fastq.gz
# Approx 15% complete for kg1_t_2.fastq.gz
# Approx 20% complete for kg1_t_2.fastq.gz
# Approx 25% complete for kg1_t_2.fastq.gz
# Approx 30% complete for kg1_t_2.fastq.gz
# Approx 35% complete for kg1_t_2.fastq.gz
# Approx 40% complete for kg1_t_2.fastq.gz
# Approx 45% complete for kg1_t_2.fastq.gz
# Approx 50% complete for kg1_t_2.fastq.gz
# Approx 55% complete for kg1_t_2.fastq.gz
# Approx 60% complete for kg1_t_2.fastq.gz
# Approx 65% complete for kg1_t_2.fastq.gz
# Approx 70% complete for kg1_t_2.fastq.gz
# Approx 75% complete for kg1_t_2.fastq.gz
# Approx 80% complete for kg1_t_2.fastq.gz
# Approx 85% complete for kg1_t_2.fastq.gz
# Approx 90% complete for kg1_t_2.fastq.gz
# Approx 95% complete for kg1_t_2.fastq.gz
# Started analysis of kg1_t_3.fastq.gz
# Approx 5% complete for kg1_t_3.fastq.gz
# Approx 10% complete for kg1_t_3.fastq.gz
# Approx 15% complete for kg1_t_3.fastq.gz
# Approx 20% complete for kg1_t_3.fastq.gz
# Approx 25% complete for kg1_t_3.fastq.gz
# Approx 30% complete for kg1_t_3.fastq.gz
# Approx 35% complete for kg1_t_3.fastq.gz
# Approx 40% complete for kg1_t_3.fastq.gz
# Approx 45% complete for kg1_t_3.fastq.gz
# Approx 50% complete for kg1_t_3.fastq.gz
# Approx 55% complete for kg1_t_3.fastq.gz
# Approx 60% complete for kg1_t_3.fastq.gz
# Approx 65% complete for kg1_t_3.fastq.gz
# Approx 70% complete for kg1_t_3.fastq.gz
# Approx 75% complete for kg1_t_3.fastq.gz
# Approx 80% complete for kg1_t_3.fastq.gz
# Approx 85% complete for kg1_t_3.fastq.gz
# Approx 90% complete for kg1_t_3.fastq.gz
# Approx 95% complete for kg1_t_3.fastq.gz
# Started analysis of kg1_u_1.fastq.gz
# Approx 5% complete for kg1_u_1.fastq.gz
# Approx 10% complete for kg1_u_1.fastq.gz
# Approx 15% complete for kg1_u_1.fastq.gz
# Approx 20% complete for kg1_u_1.fastq.gz
# Approx 25% complete for kg1_u_1.fastq.gz
# Approx 30% complete for kg1_u_1.fastq.gz
# Approx 35% complete for kg1_u_1.fastq.gz
# Approx 40% complete for kg1_u_1.fastq.gz
# Approx 45% complete for kg1_u_1.fastq.gz
# Approx 50% complete for kg1_u_1.fastq.gz
# Approx 55% complete for kg1_u_1.fastq.gz
# Approx 60% complete for kg1_u_1.fastq.gz
# Approx 65% complete for kg1_u_1.fastq.gz
# Approx 70% complete for kg1_u_1.fastq.gz
# Approx 75% complete for kg1_u_1.fastq.gz
# Approx 80% complete for kg1_u_1.fastq.gz
# Approx 85% complete for kg1_u_1.fastq.gz
# Approx 90% complete for kg1_u_1.fastq.gz
# Approx 95% complete for kg1_u_1.fastq.gz
# Started analysis of kg1_u_2.fastq.gz
# Approx 5% complete for kg1_u_2.fastq.gz
# Approx 10% complete for kg1_u_2.fastq.gz
# Approx 15% complete for kg1_u_2.fastq.gz
# Approx 20% complete for kg1_u_2.fastq.gz
# Approx 25% complete for kg1_u_2.fastq.gz
# Approx 30% complete for kg1_u_2.fastq.gz
# Approx 35% complete for kg1_u_2.fastq.gz
# Approx 40% complete for kg1_u_2.fastq.gz
# Approx 45% complete for kg1_u_2.fastq.gz
# Approx 50% complete for kg1_u_2.fastq.gz
# Approx 55% complete for kg1_u_2.fastq.gz
# Approx 60% complete for kg1_u_2.fastq.gz
# Approx 65% complete for kg1_u_2.fastq.gz
# Approx 70% complete for kg1_u_2.fastq.gz
# Approx 75% complete for kg1_u_2.fastq.gz
# Approx 80% complete for kg1_u_2.fastq.gz
# Approx 85% complete for kg1_u_2.fastq.gz
# Approx 90% complete for kg1_u_2.fastq.gz
# Approx 95% complete for kg1_u_2.fastq.gz
# Started analysis of kg1_u_3.fastq.gz
# Approx 5% complete for kg1_u_3.fastq.gz
# Approx 10% complete for kg1_u_3.fastq.gz
# Approx 15% complete for kg1_u_3.fastq.gz
# Approx 20% complete for kg1_u_3.fastq.gz
# Approx 25% complete for kg1_u_3.fastq.gz
# Approx 30% complete for kg1_u_3.fastq.gz
# Approx 35% complete for kg1_u_3.fastq.gz
# Approx 40% complete for kg1_u_3.fastq.gz
# Approx 45% complete for kg1_u_3.fastq.gz
# Approx 50% complete for kg1_u_3.fastq.gz
# Approx 55% complete for kg1_u_3.fastq.gz
# Approx 60% complete for kg1_u_3.fastq.gz
# Approx 65% complete for kg1_u_3.fastq.gz
# Approx 70% complete for kg1_u_3.fastq.gz
# Approx 75% complete for kg1_u_3.fastq.gz
# Approx 80% complete for kg1_u_3.fastq.gz
# Approx 85% complete for kg1_u_3.fastq.gz
# Approx 90% complete for kg1_u_3.fastq.gz
# Approx 95% complete for kg1_u_3.fastq.gz
# Started analysis of molm14_t_1.fastq.gz
# Approx 5% complete for molm14_t_1.fastq.gz
# Approx 10% complete for molm14_t_1.fastq.gz
# Approx 15% complete for molm14_t_1.fastq.gz
# Approx 20% complete for molm14_t_1.fastq.gz
# Approx 25% complete for molm14_t_1.fastq.gz
# Approx 30% complete for molm14_t_1.fastq.gz
# Approx 35% complete for molm14_t_1.fastq.gz
# Approx 40% complete for molm14_t_1.fastq.gz
# Approx 45% complete for molm14_t_1.fastq.gz
# Approx 50% complete for molm14_t_1.fastq.gz
# Approx 55% complete for molm14_t_1.fastq.gz
# Approx 60% complete for molm14_t_1.fastq.gz
# Approx 65% complete for molm14_t_1.fastq.gz
# Approx 70% complete for molm14_t_1.fastq.gz
# Approx 75% complete for molm14_t_1.fastq.gz
# Approx 80% complete for molm14_t_1.fastq.gz
# Approx 85% complete for molm14_t_1.fastq.gz
# Approx 90% complete for molm14_t_1.fastq.gz
# Approx 95% complete for molm14_t_1.fastq.gz
# Started analysis of molm14_t_2.fastq.gz
# Approx 5% complete for molm14_t_2.fastq.gz
# Approx 10% complete for molm14_t_2.fastq.gz
# Approx 15% complete for molm14_t_2.fastq.gz
# Approx 20% complete for molm14_t_2.fastq.gz
# Approx 25% complete for molm14_t_2.fastq.gz
# Approx 30% complete for molm14_t_2.fastq.gz
# Approx 35% complete for molm14_t_2.fastq.gz
# Approx 40% complete for molm14_t_2.fastq.gz
# Approx 45% complete for molm14_t_2.fastq.gz
# Approx 50% complete for molm14_t_2.fastq.gz
# Approx 55% complete for molm14_t_2.fastq.gz
# Approx 60% complete for molm14_t_2.fastq.gz
# Approx 65% complete for molm14_t_2.fastq.gz
# Approx 70% complete for molm14_t_2.fastq.gz
# Approx 75% complete for molm14_t_2.fastq.gz
# Approx 80% complete for molm14_t_2.fastq.gz
# Approx 85% complete for molm14_t_2.fastq.gz
# Approx 90% complete for molm14_t_2.fastq.gz
# Approx 95% complete for molm14_t_2.fastq.gz
# Started analysis of molm14_t_3.fastq.gz
# Approx 5% complete for molm14_t_3.fastq.gz
# Approx 10% complete for molm14_t_3.fastq.gz
# Approx 15% complete for molm14_t_3.fastq.gz
# Approx 20% complete for molm14_t_3.fastq.gz
# Approx 25% complete for molm14_t_3.fastq.gz
# Approx 30% complete for molm14_t_3.fastq.gz
# Approx 35% complete for molm14_t_3.fastq.gz
# Approx 40% complete for molm14_t_3.fastq.gz
# Approx 45% complete for molm14_t_3.fastq.gz
# Approx 50% complete for molm14_t_3.fastq.gz
# Approx 55% complete for molm14_t_3.fastq.gz
# Approx 60% complete for molm14_t_3.fastq.gz
# Approx 65% complete for molm14_t_3.fastq.gz
# Approx 70% complete for molm14_t_3.fastq.gz
# Approx 75% complete for molm14_t_3.fastq.gz
# Approx 80% complete for molm14_t_3.fastq.gz
# Approx 85% complete for molm14_t_3.fastq.gz
# Approx 90% complete for molm14_t_3.fastq.gz
# Approx 95% complete for molm14_t_3.fastq.gz
# Started analysis of molm14_u_1.fastq.gz
# Approx 5% complete for molm14_u_1.fastq.gz
# Approx 10% complete for molm14_u_1.fastq.gz
# Approx 15% complete for molm14_u_1.fastq.gz
# Approx 20% complete for molm14_u_1.fastq.gz
# Approx 25% complete for molm14_u_1.fastq.gz
# Approx 30% complete for molm14_u_1.fastq.gz
# Approx 35% complete for molm14_u_1.fastq.gz
# Approx 40% complete for molm14_u_1.fastq.gz
# Approx 45% complete for molm14_u_1.fastq.gz
# Approx 50% complete for molm14_u_1.fastq.gz
# Approx 55% complete for molm14_u_1.fastq.gz
# Approx 60% complete for molm14_u_1.fastq.gz
# Approx 65% complete for molm14_u_1.fastq.gz
# Approx 70% complete for molm14_u_1.fastq.gz
# Approx 75% complete for molm14_u_1.fastq.gz
# Approx 80% complete for molm14_u_1.fastq.gz
# Approx 85% complete for molm14_u_1.fastq.gz
# Approx 90% complete for molm14_u_1.fastq.gz
# Approx 95% complete for molm14_u_1.fastq.gz
# Started analysis of molm14_u_2.fastq.gz
# Approx 5% complete for molm14_u_2.fastq.gz
# Approx 10% complete for molm14_u_2.fastq.gz
# Approx 15% complete for molm14_u_2.fastq.gz
# Approx 20% complete for molm14_u_2.fastq.gz
# Approx 25% complete for molm14_u_2.fastq.gz
# Approx 30% complete for molm14_u_2.fastq.gz
# Approx 35% complete for molm14_u_2.fastq.gz
# Approx 40% complete for molm14_u_2.fastq.gz
# Approx 45% complete for molm14_u_2.fastq.gz
# Approx 50% complete for molm14_u_2.fastq.gz
# Approx 55% complete for molm14_u_2.fastq.gz
# Approx 60% complete for molm14_u_2.fastq.gz
# Approx 65% complete for molm14_u_2.fastq.gz
# Approx 70% complete for molm14_u_2.fastq.gz
# Approx 75% complete for molm14_u_2.fastq.gz
# Approx 80% complete for molm14_u_2.fastq.gz
# Approx 85% complete for molm14_u_2.fastq.gz
# Approx 90% complete for molm14_u_2.fastq.gz
# Approx 95% complete for molm14_u_2.fastq.gz
# Started analysis of molm14_u_3.fastq.gz
# Approx 5% complete for molm14_u_3.fastq.gz
# Approx 10% complete for molm14_u_3.fastq.gz
# Approx 15% complete for molm14_u_3.fastq.gz
# Approx 20% complete for molm14_u_3.fastq.gz
# Approx 25% complete for molm14_u_3.fastq.gz
# Approx 30% complete for molm14_u_3.fastq.gz
# Approx 35% complete for molm14_u_3.fastq.gz
# Approx 40% complete for molm14_u_3.fastq.gz
# Approx 45% complete for molm14_u_3.fastq.gz
# Approx 50% complete for molm14_u_3.fastq.gz
# Approx 55% complete for molm14_u_3.fastq.gz
# Approx 60% complete for molm14_u_3.fastq.gz
# Approx 65% complete for molm14_u_3.fastq.gz
# Approx 70% complete for molm14_u_3.fastq.gz
# Approx 75% complete for molm14_u_3.fastq.gz
# Approx 80% complete for molm14_u_3.fastq.gz
# Approx 85% complete for molm14_u_3.fastq.gz
# Approx 90% complete for molm14_u_3.fastq.gz
# Approx 95% complete for molm14_u_3.fastq.gz
# Started analysis of ociaml2_t_1.fastq.gz
# Approx 5% complete for ociaml2_t_1.fastq.gz
# Approx 10% complete for ociaml2_t_1.fastq.gz
# Approx 15% complete for ociaml2_t_1.fastq.gz
# Approx 20% complete for ociaml2_t_1.fastq.gz
# Approx 25% complete for ociaml2_t_1.fastq.gz
# Approx 30% complete for ociaml2_t_1.fastq.gz
# Approx 35% complete for ociaml2_t_1.fastq.gz
# Approx 40% complete for ociaml2_t_1.fastq.gz
# Approx 45% complete for ociaml2_t_1.fastq.gz
# Approx 50% complete for ociaml2_t_1.fastq.gz
# Approx 55% complete for ociaml2_t_1.fastq.gz
# Approx 60% complete for ociaml2_t_1.fastq.gz
# Approx 65% complete for ociaml2_t_1.fastq.gz
# Approx 70% complete for ociaml2_t_1.fastq.gz
# Approx 75% complete for ociaml2_t_1.fastq.gz
# Approx 80% complete for ociaml2_t_1.fastq.gz
# Approx 85% complete for ociaml2_t_1.fastq.gz
# Approx 90% complete for ociaml2_t_1.fastq.gz
# Approx 95% complete for ociaml2_t_1.fastq.gz
# Started analysis of ociaml2_t_2.fastq.gz
# Approx 5% complete for ociaml2_t_2.fastq.gz
# Approx 10% complete for ociaml2_t_2.fastq.gz
# Approx 15% complete for ociaml2_t_2.fastq.gz
# Approx 20% complete for ociaml2_t_2.fastq.gz
# Approx 25% complete for ociaml2_t_2.fastq.gz
# Approx 30% complete for ociaml2_t_2.fastq.gz
# Approx 35% complete for ociaml2_t_2.fastq.gz
# Approx 40% complete for ociaml2_t_2.fastq.gz
# Approx 45% complete for ociaml2_t_2.fastq.gz
# Approx 50% complete for ociaml2_t_2.fastq.gz
# Approx 55% complete for ociaml2_t_2.fastq.gz
# Approx 60% complete for ociaml2_t_2.fastq.gz
# Approx 65% complete for ociaml2_t_2.fastq.gz
# Approx 70% complete for ociaml2_t_2.fastq.gz
# Approx 75% complete for ociaml2_t_2.fastq.gz
# Approx 80% complete for ociaml2_t_2.fastq.gz
# Approx 85% complete for ociaml2_t_2.fastq.gz
# Approx 90% complete for ociaml2_t_2.fastq.gz
# Approx 95% complete for ociaml2_t_2.fastq.gz
# Started analysis of ociaml2_t_3.fastq.gz
# Approx 5% complete for ociaml2_t_3.fastq.gz
# Approx 10% complete for ociaml2_t_3.fastq.gz
# Approx 15% complete for ociaml2_t_3.fastq.gz
# Approx 20% complete for ociaml2_t_3.fastq.gz
# Approx 25% complete for ociaml2_t_3.fastq.gz
# Approx 30% complete for ociaml2_t_3.fastq.gz
# Approx 35% complete for ociaml2_t_3.fastq.gz
# Approx 40% complete for ociaml2_t_3.fastq.gz
# Approx 45% complete for ociaml2_t_3.fastq.gz
# Approx 50% complete for ociaml2_t_3.fastq.gz
# Approx 55% complete for ociaml2_t_3.fastq.gz
# Approx 60% complete for ociaml2_t_3.fastq.gz
# Approx 65% complete for ociaml2_t_3.fastq.gz
# Approx 70% complete for ociaml2_t_3.fastq.gz
# Approx 75% complete for ociaml2_t_3.fastq.gz
# Approx 80% complete for ociaml2_t_3.fastq.gz
# Approx 85% complete for ociaml2_t_3.fastq.gz
# Approx 90% complete for ociaml2_t_3.fastq.gz
# Approx 95% complete for ociaml2_t_3.fastq.gz
# Started analysis of ociaml2_u_1.fastq.gz
# Approx 5% complete for ociaml2_u_1.fastq.gz
# Approx 10% complete for ociaml2_u_1.fastq.gz
# Approx 15% complete for ociaml2_u_1.fastq.gz
# Approx 20% complete for ociaml2_u_1.fastq.gz
# Approx 25% complete for ociaml2_u_1.fastq.gz
# Approx 30% complete for ociaml2_u_1.fastq.gz
# Approx 35% complete for ociaml2_u_1.fastq.gz
# Approx 40% complete for ociaml2_u_1.fastq.gz
# Approx 45% complete for ociaml2_u_1.fastq.gz
# Approx 50% complete for ociaml2_u_1.fastq.gz
# Approx 55% complete for ociaml2_u_1.fastq.gz
# Approx 60% complete for ociaml2_u_1.fastq.gz
# Approx 65% complete for ociaml2_u_1.fastq.gz
# Approx 70% complete for ociaml2_u_1.fastq.gz
# Approx 75% complete for ociaml2_u_1.fastq.gz
# Approx 80% complete for ociaml2_u_1.fastq.gz
# Approx 85% complete for ociaml2_u_1.fastq.gz
# Approx 90% complete for ociaml2_u_1.fastq.gz
# Approx 95% complete for ociaml2_u_1.fastq.gz
# Started analysis of ociaml2_u_2.fastq.gz
# Approx 5% complete for ociaml2_u_2.fastq.gz
# Approx 10% complete for ociaml2_u_2.fastq.gz
# Approx 15% complete for ociaml2_u_2.fastq.gz
# Approx 20% complete for ociaml2_u_2.fastq.gz
# Approx 25% complete for ociaml2_u_2.fastq.gz
# Approx 30% complete for ociaml2_u_2.fastq.gz
# Approx 35% complete for ociaml2_u_2.fastq.gz
# Approx 40% complete for ociaml2_u_2.fastq.gz
# Approx 45% complete for ociaml2_u_2.fastq.gz
# Approx 50% complete for ociaml2_u_2.fastq.gz
# Approx 55% complete for ociaml2_u_2.fastq.gz
# Approx 60% complete for ociaml2_u_2.fastq.gz
# Approx 65% complete for ociaml2_u_2.fastq.gz
# Approx 70% complete for ociaml2_u_2.fastq.gz
# Approx 75% complete for ociaml2_u_2.fastq.gz
# Approx 80% complete for ociaml2_u_2.fastq.gz
# Approx 85% complete for ociaml2_u_2.fastq.gz
# Approx 90% complete for ociaml2_u_2.fastq.gz
# Approx 95% complete for ociaml2_u_2.fastq.gz
# Started analysis of ociaml2_u_3.fastq.gz
# Approx 5% complete for ociaml2_u_3.fastq.gz
# Approx 10% complete for ociaml2_u_3.fastq.gz
# Approx 15% complete for ociaml2_u_3.fastq.gz
# Approx 20% complete for ociaml2_u_3.fastq.gz
# Approx 25% complete for ociaml2_u_3.fastq.gz
# Approx 30% complete for ociaml2_u_3.fastq.gz
# Approx 35% complete for ociaml2_u_3.fastq.gz
# Approx 40% complete for ociaml2_u_3.fastq.gz
# Approx 45% complete for ociaml2_u_3.fastq.gz
# Approx 50% complete for ociaml2_u_3.fastq.gz
# Approx 55% complete for ociaml2_u_3.fastq.gz
# Approx 60% complete for ociaml2_u_3.fastq.gz
# Approx 65% complete for ociaml2_u_3.fastq.gz
# Approx 70% complete for ociaml2_u_3.fastq.gz
# Approx 75% complete for ociaml2_u_3.fastq.gz
# Approx 80% complete for ociaml2_u_3.fastq.gz
# Approx 85% complete for ociaml2_u_3.fastq.gz
# Approx 90% complete for ociaml2_u_3.fastq.gz
# Approx 95% complete for ociaml2_u_3.fastq.gz
# Started analysis of ociaml3_t_1.fastq.gz
# Approx 5% complete for ociaml3_t_1.fastq.gz
# Approx 10% complete for ociaml3_t_1.fastq.gz
# Approx 15% complete for ociaml3_t_1.fastq.gz
# Approx 20% complete for ociaml3_t_1.fastq.gz
# Approx 25% complete for ociaml3_t_1.fastq.gz
# Approx 30% complete for ociaml3_t_1.fastq.gz
# Approx 35% complete for ociaml3_t_1.fastq.gz
# Approx 40% complete for ociaml3_t_1.fastq.gz
# Approx 45% complete for ociaml3_t_1.fastq.gz
# Approx 50% complete for ociaml3_t_1.fastq.gz
# Approx 55% complete for ociaml3_t_1.fastq.gz
# Approx 60% complete for ociaml3_t_1.fastq.gz
# Approx 65% complete for ociaml3_t_1.fastq.gz
# Approx 70% complete for ociaml3_t_1.fastq.gz
# Approx 75% complete for ociaml3_t_1.fastq.gz
# Approx 80% complete for ociaml3_t_1.fastq.gz
# Approx 85% complete for ociaml3_t_1.fastq.gz
# Approx 90% complete for ociaml3_t_1.fastq.gz
# Approx 95% complete for ociaml3_t_1.fastq.gz
# Started analysis of ociaml3_t_2.fastq.gz
# Approx 5% complete for ociaml3_t_2.fastq.gz
# Approx 10% complete for ociaml3_t_2.fastq.gz
# Approx 15% complete for ociaml3_t_2.fastq.gz
# Approx 20% complete for ociaml3_t_2.fastq.gz
# Approx 25% complete for ociaml3_t_2.fastq.gz
# Approx 30% complete for ociaml3_t_2.fastq.gz
# Approx 35% complete for ociaml3_t_2.fastq.gz
# Approx 40% complete for ociaml3_t_2.fastq.gz
# Approx 45% complete for ociaml3_t_2.fastq.gz
# Approx 50% complete for ociaml3_t_2.fastq.gz
# Approx 55% complete for ociaml3_t_2.fastq.gz
# Approx 60% complete for ociaml3_t_2.fastq.gz
# Approx 65% complete for ociaml3_t_2.fastq.gz
# Approx 70% complete for ociaml3_t_2.fastq.gz
# Approx 75% complete for ociaml3_t_2.fastq.gz
# Approx 80% complete for ociaml3_t_2.fastq.gz
# Approx 85% complete for ociaml3_t_2.fastq.gz
# Approx 90% complete for ociaml3_t_2.fastq.gz
# Approx 95% complete for ociaml3_t_2.fastq.gz
# Started analysis of ociaml3_t_3.fastq.gz
# Approx 5% complete for ociaml3_t_3.fastq.gz
# Approx 10% complete for ociaml3_t_3.fastq.gz
# Approx 15% complete for ociaml3_t_3.fastq.gz
# Approx 20% complete for ociaml3_t_3.fastq.gz
# Approx 25% complete for ociaml3_t_3.fastq.gz
# Approx 30% complete for ociaml3_t_3.fastq.gz
# Approx 35% complete for ociaml3_t_3.fastq.gz
# Approx 40% complete for ociaml3_t_3.fastq.gz
# Approx 45% complete for ociaml3_t_3.fastq.gz
# Approx 50% complete for ociaml3_t_3.fastq.gz
# Approx 55% complete for ociaml3_t_3.fastq.gz
# Approx 60% complete for ociaml3_t_3.fastq.gz
# Approx 65% complete for ociaml3_t_3.fastq.gz
# Approx 70% complete for ociaml3_t_3.fastq.gz
# Approx 75% complete for ociaml3_t_3.fastq.gz
# Approx 80% complete for ociaml3_t_3.fastq.gz
# Approx 85% complete for ociaml3_t_3.fastq.gz
# Approx 90% complete for ociaml3_t_3.fastq.gz
# Approx 95% complete for ociaml3_t_3.fastq.gz
# Started analysis of ociaml3_u_1.fastq.gz
# Approx 5% complete for ociaml3_u_1.fastq.gz
# Approx 10% complete for ociaml3_u_1.fastq.gz
# Approx 15% complete for ociaml3_u_1.fastq.gz
# Approx 20% complete for ociaml3_u_1.fastq.gz
# Approx 25% complete for ociaml3_u_1.fastq.gz
# Approx 30% complete for ociaml3_u_1.fastq.gz
# Approx 35% complete for ociaml3_u_1.fastq.gz
# Approx 40% complete for ociaml3_u_1.fastq.gz
# Approx 45% complete for ociaml3_u_1.fastq.gz
# Approx 50% complete for ociaml3_u_1.fastq.gz
# Approx 55% complete for ociaml3_u_1.fastq.gz
# Approx 60% complete for ociaml3_u_1.fastq.gz
# Approx 65% complete for ociaml3_u_1.fastq.gz
# Approx 70% complete for ociaml3_u_1.fastq.gz
# Approx 75% complete for ociaml3_u_1.fastq.gz
# Approx 80% complete for ociaml3_u_1.fastq.gz
# Approx 85% complete for ociaml3_u_1.fastq.gz
# Approx 90% complete for ociaml3_u_1.fastq.gz
# Approx 95% complete for ociaml3_u_1.fastq.gz
# Started analysis of ociaml3_u_2.fastq.gz
# Approx 5% complete for ociaml3_u_2.fastq.gz
# Approx 10% complete for ociaml3_u_2.fastq.gz
# Approx 15% complete for ociaml3_u_2.fastq.gz
# Approx 20% complete for ociaml3_u_2.fastq.gz
# Approx 25% complete for ociaml3_u_2.fastq.gz
# Approx 30% complete for ociaml3_u_2.fastq.gz
# Approx 35% complete for ociaml3_u_2.fastq.gz
# Approx 40% complete for ociaml3_u_2.fastq.gz
# Approx 45% complete for ociaml3_u_2.fastq.gz
# Approx 50% complete for ociaml3_u_2.fastq.gz
# Approx 55% complete for ociaml3_u_2.fastq.gz
# Approx 60% complete for ociaml3_u_2.fastq.gz
# Approx 65% complete for ociaml3_u_2.fastq.gz
# Approx 70% complete for ociaml3_u_2.fastq.gz
# Approx 75% complete for ociaml3_u_2.fastq.gz
# Approx 80% complete for ociaml3_u_2.fastq.gz
# Approx 85% complete for ociaml3_u_2.fastq.gz
# Approx 90% complete for ociaml3_u_2.fastq.gz
# Approx 95% complete for ociaml3_u_2.fastq.gz
# Started analysis of ociaml3_u_3.fastq.gz
# Approx 5% complete for ociaml3_u_3.fastq.gz
# Approx 10% complete for ociaml3_u_3.fastq.gz
# Approx 15% complete for ociaml3_u_3.fastq.gz
# Approx 20% complete for ociaml3_u_3.fastq.gz
# Approx 25% complete for ociaml3_u_3.fastq.gz
# Approx 30% complete for ociaml3_u_3.fastq.gz
# Approx 35% complete for ociaml3_u_3.fastq.gz
# Approx 40% complete for ociaml3_u_3.fastq.gz
# Approx 45% complete for ociaml3_u_3.fastq.gz
# Approx 50% complete for ociaml3_u_3.fastq.gz
# Approx 55% complete for ociaml3_u_3.fastq.gz
# Approx 60% complete for ociaml3_u_3.fastq.gz
# Approx 65% complete for ociaml3_u_3.fastq.gz
# Approx 70% complete for ociaml3_u_3.fastq.gz
# Approx 75% complete for ociaml3_u_3.fastq.gz
# Approx 80% complete for ociaml3_u_3.fastq.gz
# Approx 85% complete for ociaml3_u_3.fastq.gz
# Approx 90% complete for ociaml3_u_3.fastq.gz
# Approx 95% complete for ociaml3_u_3.fastq.gz
# Started analysis of thp1_t_1.fastq.gz
# Approx 5% complete for thp1_t_1.fastq.gz
# Approx 10% complete for thp1_t_1.fastq.gz
# Approx 15% complete for thp1_t_1.fastq.gz
# Approx 20% complete for thp1_t_1.fastq.gz
# Approx 25% complete for thp1_t_1.fastq.gz
# Approx 30% complete for thp1_t_1.fastq.gz
# Approx 35% complete for thp1_t_1.fastq.gz
# Approx 40% complete for thp1_t_1.fastq.gz
# Approx 45% complete for thp1_t_1.fastq.gz
# Approx 50% complete for thp1_t_1.fastq.gz
# Approx 55% complete for thp1_t_1.fastq.gz
# Approx 60% complete for thp1_t_1.fastq.gz
# Approx 65% complete for thp1_t_1.fastq.gz
# Approx 70% complete for thp1_t_1.fastq.gz
# Approx 75% complete for thp1_t_1.fastq.gz
# Approx 80% complete for thp1_t_1.fastq.gz
# Approx 85% complete for thp1_t_1.fastq.gz
# Approx 90% complete for thp1_t_1.fastq.gz
# Approx 95% complete for thp1_t_1.fastq.gz
# Started analysis of thp1_t_2.fastq.gz
# Approx 5% complete for thp1_t_2.fastq.gz
# Approx 10% complete for thp1_t_2.fastq.gz
# Approx 15% complete for thp1_t_2.fastq.gz
# Approx 20% complete for thp1_t_2.fastq.gz
# Approx 25% complete for thp1_t_2.fastq.gz
# Approx 30% complete for thp1_t_2.fastq.gz
# Approx 35% complete for thp1_t_2.fastq.gz
# Approx 40% complete for thp1_t_2.fastq.gz
# Approx 45% complete for thp1_t_2.fastq.gz
# Approx 50% complete for thp1_t_2.fastq.gz
# Approx 55% complete for thp1_t_2.fastq.gz
# Approx 60% complete for thp1_t_2.fastq.gz
# Approx 65% complete for thp1_t_2.fastq.gz
# Approx 70% complete for thp1_t_2.fastq.gz
# Approx 75% complete for thp1_t_2.fastq.gz
# Approx 80% complete for thp1_t_2.fastq.gz
# Approx 85% complete for thp1_t_2.fastq.gz
# Approx 90% complete for thp1_t_2.fastq.gz
# Approx 95% complete for thp1_t_2.fastq.gz
# Started analysis of thp1_t_3.fastq.gz
# Approx 5% complete for thp1_t_3.fastq.gz
# Approx 10% complete for thp1_t_3.fastq.gz
# Approx 15% complete for thp1_t_3.fastq.gz
# Approx 20% complete for thp1_t_3.fastq.gz
# Approx 25% complete for thp1_t_3.fastq.gz
# Approx 30% complete for thp1_t_3.fastq.gz
# Approx 35% complete for thp1_t_3.fastq.gz
# Approx 40% complete for thp1_t_3.fastq.gz
# Approx 45% complete for thp1_t_3.fastq.gz
# Approx 50% complete for thp1_t_3.fastq.gz
# Approx 55% complete for thp1_t_3.fastq.gz
# Approx 60% complete for thp1_t_3.fastq.gz
# Approx 65% complete for thp1_t_3.fastq.gz
# Approx 70% complete for thp1_t_3.fastq.gz
# Approx 75% complete for thp1_t_3.fastq.gz
# Approx 80% complete for thp1_t_3.fastq.gz
# Approx 85% complete for thp1_t_3.fastq.gz
# Approx 90% complete for thp1_t_3.fastq.gz
# Approx 95% complete for thp1_t_3.fastq.gz
# Started analysis of thp1_u_1.fastq.gz
# Approx 5% complete for thp1_u_1.fastq.gz
# Approx 10% complete for thp1_u_1.fastq.gz
# Approx 15% complete for thp1_u_1.fastq.gz
# Approx 20% complete for thp1_u_1.fastq.gz
# Approx 25% complete for thp1_u_1.fastq.gz
# Approx 30% complete for thp1_u_1.fastq.gz
# Approx 35% complete for thp1_u_1.fastq.gz
# Approx 40% complete for thp1_u_1.fastq.gz
# Approx 45% complete for thp1_u_1.fastq.gz
# Approx 50% complete for thp1_u_1.fastq.gz
# Approx 55% complete for thp1_u_1.fastq.gz
# Approx 60% complete for thp1_u_1.fastq.gz
# Approx 65% complete for thp1_u_1.fastq.gz
# Approx 70% complete for thp1_u_1.fastq.gz
# Approx 75% complete for thp1_u_1.fastq.gz
# Approx 80% complete for thp1_u_1.fastq.gz
# Approx 85% complete for thp1_u_1.fastq.gz
# Approx 90% complete for thp1_u_1.fastq.gz
# Approx 95% complete for thp1_u_1.fastq.gz
# Started analysis of thp1_u_2.fastq.gz
# Approx 5% complete for thp1_u_2.fastq.gz
# Approx 10% complete for thp1_u_2.fastq.gz
# Approx 15% complete for thp1_u_2.fastq.gz
# Approx 20% complete for thp1_u_2.fastq.gz
# Approx 25% complete for thp1_u_2.fastq.gz
# Approx 30% complete for thp1_u_2.fastq.gz
# Approx 35% complete for thp1_u_2.fastq.gz
# Approx 40% complete for thp1_u_2.fastq.gz
# Approx 45% complete for thp1_u_2.fastq.gz
# Approx 50% complete for thp1_u_2.fastq.gz
# Approx 55% complete for thp1_u_2.fastq.gz
# Approx 60% complete for thp1_u_2.fastq.gz
# Approx 65% complete for thp1_u_2.fastq.gz
# Approx 70% complete for thp1_u_2.fastq.gz
# Approx 75% complete for thp1_u_2.fastq.gz
# Approx 80% complete for thp1_u_2.fastq.gz
# Approx 85% complete for thp1_u_2.fastq.gz
# Approx 90% complete for thp1_u_2.fastq.gz
# Approx 95% complete for thp1_u_2.fastq.gz
# Started analysis of thp1_u_3.fastq.gz
# Approx 5% complete for thp1_u_3.fastq.gz
# Approx 10% complete for thp1_u_3.fastq.gz
# Approx 15% complete for thp1_u_3.fastq.gz
# Approx 20% complete for thp1_u_3.fastq.gz
# Approx 25% complete for thp1_u_3.fastq.gz
# Approx 30% complete for thp1_u_3.fastq.gz
# Approx 35% complete for thp1_u_3.fastq.gz
# Approx 40% complete for thp1_u_3.fastq.gz
# Approx 45% complete for thp1_u_3.fastq.gz
# Approx 50% complete for thp1_u_3.fastq.gz
# Approx 55% complete for thp1_u_3.fastq.gz
# Approx 60% complete for thp1_u_3.fastq.gz
# Approx 65% complete for thp1_u_3.fastq.gz
# Approx 70% complete for thp1_u_3.fastq.gz
# Approx 75% complete for thp1_u_3.fastq.gz
# Approx 80% complete for thp1_u_3.fastq.gz
# Approx 85% complete for thp1_u_3.fastq.gz
# Approx 90% complete for thp1_u_3.fastq.gz
# Approx 95% complete for thp1_u_3.fastq.gz

# %%
# !multiqc other-fastq other-bam other-exp -n other-multiqc.html
# Out:
# [INFO   ]         multiqc : This is MultiQC v1.9
# [INFO   ]         multiqc : Template    : default
# [INFO   ]         multiqc : Searching   : /rumi/shams/abe/Gilbertlab/Decitabine_treatment/RNA-seq/other-fastq
# [INFO   ]         multiqc : Searching   : /rumi/shams/abe/Gilbertlab/Decitabine_treatment/RNA-seq/other-bam
# [INFO   ]         multiqc : Searching   : /rumi/shams/abe/Gilbertlab/Decitabine_treatment/RNA-seq/other-exp
# Searching 577 files..  [####################################]  100%
# [INFO   ]          salmon : Found 30 meta reports
# [INFO   ]          salmon : Found 30 fragment length distributions
# [INFO   ]            star : Found 30 reports
# [INFO   ]          fastqc : Found 30 reports
# [INFO   ]         multiqc : Compressing plot data
# [INFO   ]         multiqc : Report      : other-multiqc.html
# [INFO   ]         multiqc : Data        : other-multiqc_data
# [INFO   ]         multiqc : MultiQC complete

# %% [markdown]
# # hl-60

# %%
# %%bash
# for f in hl60-fastq/*; do
#     fastqc $f
# done
# Out:
# Analysis complete for 120h_DMSO_rep1.fastq.gz
# Analysis complete for 120h_DMSO_rep2.fastq.gz
# Analysis complete for 120h_treated_rep1.fastq.gz
# Analysis complete for 120h_treated_rep2.fastq.gz
# Analysis complete for 6h_DMSO_rep1.fastq.gz
# Analysis complete for 6h_DMSO_rep2.fastq.gz
# Analysis complete for 6h_treated_rep1.fastq.gz
# Analysis complete for 6h_treated_rep2.fastq.gz
# Analysis complete for 72h_DMSO_rep1.fastq.gz
# Analysis complete for 72h_DMSO_rep2.fastq.gz
# Analysis complete for 72h_treated_rep1.fastq.gz
# Analysis complete for 72h_treated_rep2.fastq.gz
# Started analysis of 120h_DMSO_rep1.fastq.gz
# Approx 5% complete for 120h_DMSO_rep1.fastq.gz
# Approx 10% complete for 120h_DMSO_rep1.fastq.gz
# Approx 15% complete for 120h_DMSO_rep1.fastq.gz
# Approx 20% complete for 120h_DMSO_rep1.fastq.gz
# Approx 25% complete for 120h_DMSO_rep1.fastq.gz
# Approx 30% complete for 120h_DMSO_rep1.fastq.gz
# Approx 35% complete for 120h_DMSO_rep1.fastq.gz
# Approx 40% complete for 120h_DMSO_rep1.fastq.gz
# Approx 45% complete for 120h_DMSO_rep1.fastq.gz
# Approx 50% complete for 120h_DMSO_rep1.fastq.gz
# Approx 55% complete for 120h_DMSO_rep1.fastq.gz
# Approx 60% complete for 120h_DMSO_rep1.fastq.gz
# Approx 65% complete for 120h_DMSO_rep1.fastq.gz
# Approx 70% complete for 120h_DMSO_rep1.fastq.gz
# Approx 75% complete for 120h_DMSO_rep1.fastq.gz
# Approx 80% complete for 120h_DMSO_rep1.fastq.gz
# Approx 85% complete for 120h_DMSO_rep1.fastq.gz
# Approx 90% complete for 120h_DMSO_rep1.fastq.gz
# Approx 95% complete for 120h_DMSO_rep1.fastq.gz
# Started analysis of 120h_DMSO_rep2.fastq.gz
# Approx 5% complete for 120h_DMSO_rep2.fastq.gz
# Approx 10% complete for 120h_DMSO_rep2.fastq.gz
# Approx 15% complete for 120h_DMSO_rep2.fastq.gz
# Approx 20% complete for 120h_DMSO_rep2.fastq.gz
# Approx 25% complete for 120h_DMSO_rep2.fastq.gz
# Approx 30% complete for 120h_DMSO_rep2.fastq.gz
# Approx 35% complete for 120h_DMSO_rep2.fastq.gz
# Approx 40% complete for 120h_DMSO_rep2.fastq.gz
# Approx 45% complete for 120h_DMSO_rep2.fastq.gz
# Approx 50% complete for 120h_DMSO_rep2.fastq.gz
# Approx 55% complete for 120h_DMSO_rep2.fastq.gz
# Approx 60% complete for 120h_DMSO_rep2.fastq.gz
# Approx 65% complete for 120h_DMSO_rep2.fastq.gz
# Approx 70% complete for 120h_DMSO_rep2.fastq.gz
# Approx 75% complete for 120h_DMSO_rep2.fastq.gz
# Approx 80% complete for 120h_DMSO_rep2.fastq.gz
# Approx 85% complete for 120h_DMSO_rep2.fastq.gz
# Approx 90% complete for 120h_DMSO_rep2.fastq.gz
# Approx 95% complete for 120h_DMSO_rep2.fastq.gz
# Started analysis of 120h_treated_rep1.fastq.gz
# Approx 5% complete for 120h_treated_rep1.fastq.gz
# Approx 10% complete for 120h_treated_rep1.fastq.gz
# Approx 15% complete for 120h_treated_rep1.fastq.gz
# Approx 20% complete for 120h_treated_rep1.fastq.gz
# Approx 25% complete for 120h_treated_rep1.fastq.gz
# Approx 30% complete for 120h_treated_rep1.fastq.gz
# Approx 35% complete for 120h_treated_rep1.fastq.gz
# Approx 40% complete for 120h_treated_rep1.fastq.gz
# Approx 45% complete for 120h_treated_rep1.fastq.gz
# Approx 50% complete for 120h_treated_rep1.fastq.gz
# Approx 55% complete for 120h_treated_rep1.fastq.gz
# Approx 60% complete for 120h_treated_rep1.fastq.gz
# Approx 65% complete for 120h_treated_rep1.fastq.gz
# Approx 70% complete for 120h_treated_rep1.fastq.gz
# Approx 75% complete for 120h_treated_rep1.fastq.gz
# Approx 80% complete for 120h_treated_rep1.fastq.gz
# Approx 85% complete for 120h_treated_rep1.fastq.gz
# Approx 90% complete for 120h_treated_rep1.fastq.gz
# Approx 95% complete for 120h_treated_rep1.fastq.gz
# Started analysis of 120h_treated_rep2.fastq.gz
# Approx 5% complete for 120h_treated_rep2.fastq.gz
# Approx 10% complete for 120h_treated_rep2.fastq.gz
# Approx 15% complete for 120h_treated_rep2.fastq.gz
# Approx 20% complete for 120h_treated_rep2.fastq.gz
# Approx 25% complete for 120h_treated_rep2.fastq.gz
# Approx 30% complete for 120h_treated_rep2.fastq.gz
# Approx 35% complete for 120h_treated_rep2.fastq.gz
# Approx 40% complete for 120h_treated_rep2.fastq.gz
# Approx 45% complete for 120h_treated_rep2.fastq.gz
# Approx 50% complete for 120h_treated_rep2.fastq.gz
# Approx 55% complete for 120h_treated_rep2.fastq.gz
# Approx 60% complete for 120h_treated_rep2.fastq.gz
# Approx 65% complete for 120h_treated_rep2.fastq.gz
# Approx 70% complete for 120h_treated_rep2.fastq.gz
# Approx 75% complete for 120h_treated_rep2.fastq.gz
# Approx 80% complete for 120h_treated_rep2.fastq.gz
# Approx 85% complete for 120h_treated_rep2.fastq.gz
# Approx 90% complete for 120h_treated_rep2.fastq.gz
# Approx 95% complete for 120h_treated_rep2.fastq.gz
# Started analysis of 6h_DMSO_rep1.fastq.gz
# Approx 5% complete for 6h_DMSO_rep1.fastq.gz
# Approx 10% complete for 6h_DMSO_rep1.fastq.gz
# Approx 15% complete for 6h_DMSO_rep1.fastq.gz
# Approx 20% complete for 6h_DMSO_rep1.fastq.gz
# Approx 25% complete for 6h_DMSO_rep1.fastq.gz
# Approx 30% complete for 6h_DMSO_rep1.fastq.gz
# Approx 35% complete for 6h_DMSO_rep1.fastq.gz
# Approx 40% complete for 6h_DMSO_rep1.fastq.gz
# Approx 45% complete for 6h_DMSO_rep1.fastq.gz
# Approx 50% complete for 6h_DMSO_rep1.fastq.gz
# Approx 55% complete for 6h_DMSO_rep1.fastq.gz
# Approx 60% complete for 6h_DMSO_rep1.fastq.gz
# Approx 65% complete for 6h_DMSO_rep1.fastq.gz
# Approx 70% complete for 6h_DMSO_rep1.fastq.gz
# Approx 75% complete for 6h_DMSO_rep1.fastq.gz
# Approx 80% complete for 6h_DMSO_rep1.fastq.gz
# Approx 85% complete for 6h_DMSO_rep1.fastq.gz
# Approx 90% complete for 6h_DMSO_rep1.fastq.gz
# Approx 95% complete for 6h_DMSO_rep1.fastq.gz
# Started analysis of 6h_DMSO_rep2.fastq.gz
# Approx 5% complete for 6h_DMSO_rep2.fastq.gz
# Approx 10% complete for 6h_DMSO_rep2.fastq.gz
# Approx 15% complete for 6h_DMSO_rep2.fastq.gz
# Approx 20% complete for 6h_DMSO_rep2.fastq.gz
# Approx 25% complete for 6h_DMSO_rep2.fastq.gz
# Approx 30% complete for 6h_DMSO_rep2.fastq.gz
# Approx 35% complete for 6h_DMSO_rep2.fastq.gz
# Approx 40% complete for 6h_DMSO_rep2.fastq.gz
# Approx 45% complete for 6h_DMSO_rep2.fastq.gz
# Approx 50% complete for 6h_DMSO_rep2.fastq.gz
# Approx 55% complete for 6h_DMSO_rep2.fastq.gz
# Approx 60% complete for 6h_DMSO_rep2.fastq.gz
# Approx 65% complete for 6h_DMSO_rep2.fastq.gz
# Approx 70% complete for 6h_DMSO_rep2.fastq.gz
# Approx 75% complete for 6h_DMSO_rep2.fastq.gz
# Approx 80% complete for 6h_DMSO_rep2.fastq.gz
# Approx 85% complete for 6h_DMSO_rep2.fastq.gz
# Approx 90% complete for 6h_DMSO_rep2.fastq.gz
# Approx 95% complete for 6h_DMSO_rep2.fastq.gz
# Started analysis of 6h_treated_rep1.fastq.gz
# Approx 5% complete for 6h_treated_rep1.fastq.gz
# Approx 10% complete for 6h_treated_rep1.fastq.gz
# Approx 15% complete for 6h_treated_rep1.fastq.gz
# Approx 20% complete for 6h_treated_rep1.fastq.gz
# Approx 25% complete for 6h_treated_rep1.fastq.gz
# Approx 30% complete for 6h_treated_rep1.fastq.gz
# Approx 35% complete for 6h_treated_rep1.fastq.gz
# Approx 40% complete for 6h_treated_rep1.fastq.gz
# Approx 45% complete for 6h_treated_rep1.fastq.gz
# Approx 50% complete for 6h_treated_rep1.fastq.gz
# Approx 55% complete for 6h_treated_rep1.fastq.gz
# Approx 60% complete for 6h_treated_rep1.fastq.gz
# Approx 65% complete for 6h_treated_rep1.fastq.gz
# Approx 70% complete for 6h_treated_rep1.fastq.gz
# Approx 75% complete for 6h_treated_rep1.fastq.gz
# Approx 80% complete for 6h_treated_rep1.fastq.gz
# Approx 85% complete for 6h_treated_rep1.fastq.gz
# Approx 90% complete for 6h_treated_rep1.fastq.gz
# Approx 95% complete for 6h_treated_rep1.fastq.gz
# Started analysis of 6h_treated_rep2.fastq.gz
# Approx 5% complete for 6h_treated_rep2.fastq.gz
# Approx 10% complete for 6h_treated_rep2.fastq.gz
# Approx 15% complete for 6h_treated_rep2.fastq.gz
# Approx 20% complete for 6h_treated_rep2.fastq.gz
# Approx 25% complete for 6h_treated_rep2.fastq.gz
# Approx 30% complete for 6h_treated_rep2.fastq.gz
# Approx 35% complete for 6h_treated_rep2.fastq.gz
# Approx 40% complete for 6h_treated_rep2.fastq.gz
# Approx 45% complete for 6h_treated_rep2.fastq.gz
# Approx 50% complete for 6h_treated_rep2.fastq.gz
# Approx 55% complete for 6h_treated_rep2.fastq.gz
# Approx 60% complete for 6h_treated_rep2.fastq.gz
# Approx 65% complete for 6h_treated_rep2.fastq.gz
# Approx 70% complete for 6h_treated_rep2.fastq.gz
# Approx 75% complete for 6h_treated_rep2.fastq.gz
# Approx 80% complete for 6h_treated_rep2.fastq.gz
# Approx 85% complete for 6h_treated_rep2.fastq.gz
# Approx 90% complete for 6h_treated_rep2.fastq.gz
# Approx 95% complete for 6h_treated_rep2.fastq.gz
# Started analysis of 72h_DMSO_rep1.fastq.gz
# Approx 5% complete for 72h_DMSO_rep1.fastq.gz
# Approx 10% complete for 72h_DMSO_rep1.fastq.gz
# Approx 15% complete for 72h_DMSO_rep1.fastq.gz
# Approx 20% complete for 72h_DMSO_rep1.fastq.gz
# Approx 25% complete for 72h_DMSO_rep1.fastq.gz
# Approx 30% complete for 72h_DMSO_rep1.fastq.gz
# Approx 35% complete for 72h_DMSO_rep1.fastq.gz
# Approx 40% complete for 72h_DMSO_rep1.fastq.gz
# Approx 45% complete for 72h_DMSO_rep1.fastq.gz
# Approx 50% complete for 72h_DMSO_rep1.fastq.gz
# Approx 55% complete for 72h_DMSO_rep1.fastq.gz
# Approx 60% complete for 72h_DMSO_rep1.fastq.gz
# Approx 65% complete for 72h_DMSO_rep1.fastq.gz
# Approx 70% complete for 72h_DMSO_rep1.fastq.gz
# Approx 75% complete for 72h_DMSO_rep1.fastq.gz
# Approx 80% complete for 72h_DMSO_rep1.fastq.gz
# Approx 85% complete for 72h_DMSO_rep1.fastq.gz
# Approx 90% complete for 72h_DMSO_rep1.fastq.gz
# Approx 95% complete for 72h_DMSO_rep1.fastq.gz
# Started analysis of 72h_DMSO_rep2.fastq.gz
# Approx 5% complete for 72h_DMSO_rep2.fastq.gz
# Approx 10% complete for 72h_DMSO_rep2.fastq.gz
# Approx 15% complete for 72h_DMSO_rep2.fastq.gz
# Approx 20% complete for 72h_DMSO_rep2.fastq.gz
# Approx 25% complete for 72h_DMSO_rep2.fastq.gz
# Approx 30% complete for 72h_DMSO_rep2.fastq.gz
# Approx 35% complete for 72h_DMSO_rep2.fastq.gz
# Approx 40% complete for 72h_DMSO_rep2.fastq.gz
# Approx 45% complete for 72h_DMSO_rep2.fastq.gz
# Approx 50% complete for 72h_DMSO_rep2.fastq.gz
# Approx 55% complete for 72h_DMSO_rep2.fastq.gz
# Approx 60% complete for 72h_DMSO_rep2.fastq.gz
# Approx 65% complete for 72h_DMSO_rep2.fastq.gz
# Approx 70% complete for 72h_DMSO_rep2.fastq.gz
# Approx 75% complete for 72h_DMSO_rep2.fastq.gz
# Approx 80% complete for 72h_DMSO_rep2.fastq.gz
# Approx 85% complete for 72h_DMSO_rep2.fastq.gz
# Approx 90% complete for 72h_DMSO_rep2.fastq.gz
# Approx 95% complete for 72h_DMSO_rep2.fastq.gz
# Started analysis of 72h_treated_rep1.fastq.gz
# Approx 5% complete for 72h_treated_rep1.fastq.gz
# Approx 10% complete for 72h_treated_rep1.fastq.gz
# Approx 15% complete for 72h_treated_rep1.fastq.gz
# Approx 20% complete for 72h_treated_rep1.fastq.gz
# Approx 25% complete for 72h_treated_rep1.fastq.gz
# Approx 30% complete for 72h_treated_rep1.fastq.gz
# Approx 35% complete for 72h_treated_rep1.fastq.gz
# Approx 40% complete for 72h_treated_rep1.fastq.gz
# Approx 45% complete for 72h_treated_rep1.fastq.gz
# Approx 50% complete for 72h_treated_rep1.fastq.gz
# Approx 55% complete for 72h_treated_rep1.fastq.gz
# Approx 60% complete for 72h_treated_rep1.fastq.gz
# Approx 65% complete for 72h_treated_rep1.fastq.gz
# Approx 70% complete for 72h_treated_rep1.fastq.gz
# Approx 75% complete for 72h_treated_rep1.fastq.gz
# Approx 80% complete for 72h_treated_rep1.fastq.gz
# Approx 85% complete for 72h_treated_rep1.fastq.gz
# Approx 90% complete for 72h_treated_rep1.fastq.gz
# Approx 95% complete for 72h_treated_rep1.fastq.gz
# Started analysis of 72h_treated_rep2.fastq.gz
# Approx 5% complete for 72h_treated_rep2.fastq.gz
# Approx 10% complete for 72h_treated_rep2.fastq.gz
# Approx 15% complete for 72h_treated_rep2.fastq.gz
# Approx 20% complete for 72h_treated_rep2.fastq.gz
# Approx 25% complete for 72h_treated_rep2.fastq.gz
# Approx 30% complete for 72h_treated_rep2.fastq.gz
# Approx 35% complete for 72h_treated_rep2.fastq.gz
# Approx 40% complete for 72h_treated_rep2.fastq.gz
# Approx 45% complete for 72h_treated_rep2.fastq.gz
# Approx 50% complete for 72h_treated_rep2.fastq.gz
# Approx 55% complete for 72h_treated_rep2.fastq.gz
# Approx 60% complete for 72h_treated_rep2.fastq.gz
# Approx 65% complete for 72h_treated_rep2.fastq.gz
# Approx 70% complete for 72h_treated_rep2.fastq.gz
# Approx 75% complete for 72h_treated_rep2.fastq.gz
# Approx 80% complete for 72h_treated_rep2.fastq.gz
# Approx 85% complete for 72h_treated_rep2.fastq.gz
# Approx 90% complete for 72h_treated_rep2.fastq.gz
# Approx 95% complete for 72h_treated_rep2.fastq.gz

# %%
# !multiqc hl60-fastq hl60-bam hl60-exp -n hl60-multiqc.html
# Out:
# [INFO   ]         multiqc : This is MultiQC v1.9
# [INFO   ]         multiqc : Template    : default
# [INFO   ]         multiqc : Searching   : /rumi/shams/abe/Gilbertlab/Decitabine_treatment/RNA-seq/hl60-fastq
# [INFO   ]         multiqc : Searching   : /rumi/shams/abe/Gilbertlab/Decitabine_treatment/RNA-seq/hl60-bam
# [INFO   ]         multiqc : Searching   : /rumi/shams/abe/Gilbertlab/Decitabine_treatment/RNA-seq/hl60-exp
# Searching 4981 files..  [####################################]  100%
# [INFO   ]  feature_counts : Found 1 reports
# [INFO   ]          salmon : Found 12 meta reports
# [INFO   ]          salmon : Found 12 fragment length distributions
# [INFO   ]            star : Found 12 reports
# [INFO   ]          fastqc : Found 12 reports
# [INFO   ]         multiqc : Compressing plot data
# [INFO   ]         multiqc : Report      : hl60-multiqc.html
# [INFO   ]         multiqc : Data        : hl60-multiqc_data
# [INFO   ]         multiqc : MultiQC complete

# %%
# !multiqc hl60-stbl/counts/*_exons* -n hl60-stbl/counts-exons-multiqc.html
# !multiqc hl60-stbl/counts/*_Introns* -n hl60-stbl/counts-introns-multiqc.html
# Out:
# [INFO   ]         multiqc : This is MultiQC v1.9
# [INFO   ]         multiqc : Template    : default
# [INFO   ]         multiqc : Searching   : /rumi/shams/abe/Gilbertlab/Decitabine_treatment/RNA-seq/hl60-stbl/counts/120h_DMSO_rep1_exons.ol.txt
# [INFO   ]         multiqc : Searching   : /rumi/shams/abe/Gilbertlab/Decitabine_treatment/RNA-seq/hl60-stbl/counts/120h_DMSO_rep1_exons.txt
# [INFO   ]         multiqc : Searching   : /rumi/shams/abe/Gilbertlab/Decitabine_treatment/RNA-seq/hl60-stbl/counts/120h_DMSO_rep1_exons.txt.summary
# [INFO   ]         multiqc : Searching   : /rumi/shams/abe/Gilbertlab/Decitabine_treatment/RNA-seq/hl60-stbl/counts/120h_DMSO_rep2_exons.ol.txt
# [INFO   ]         multiqc : Searching   : /rumi/shams/abe/Gilbertlab/Decitabine_treatment/RNA-seq/hl60-stbl/counts/120h_DMSO_rep2_exons.txt
# [INFO   ]         multiqc : Searching   : /rumi/shams/abe/Gilbertlab/Decitabine_treatment/RNA-seq/hl60-stbl/counts/120h_DMSO_rep2_exons.txt.summary
# [INFO   ]         multiqc : Searching   : /rumi/shams/abe/Gilbertlab/Decitabine_treatment/RNA-seq/hl60-stbl/counts/120h_treated_rep1_exons.ol.txt
# [INFO   ]         multiqc : Searching   : /rumi/shams/abe/Gilbertlab/Decitabine_treatment/RNA-seq/hl60-stbl/counts/120h_treated_rep1_exons.txt
# [INFO   ]         multiqc : Searching   : /rumi/shams/abe/Gilbertlab/Decitabine_treatment/RNA-seq/hl60-stbl/counts/120h_treated_rep1_exons.txt.summary
# [INFO   ]         multiqc : Searching   : /rumi/shams/abe/Gilbertlab/Decitabine_treatment/RNA-seq/hl60-stbl/counts/120h_treated_rep2_exons.ol.txt
# [INFO   ]         multiqc : Searching   : /rumi/shams/abe/Gilbertlab/Decitabine_treatment/RNA-seq/hl60-stbl/counts/120h_treated_rep2_exons.txt
# [INFO   ]         multiqc : Searching   : /rumi/shams/abe/Gilbertlab/Decitabine_treatment/RNA-seq/hl60-stbl/counts/120h_treated_rep2_exons.txt.summary
# [INFO   ]         multiqc : Searching   : /rumi/shams/abe/Gilbertlab/Decitabine_treatment/RNA-seq/hl60-stbl/counts/6h_DMSO_rep1_exons.ol.txt
# [INFO   ]         multiqc : Searching   : /rumi/shams/abe/Gilbertlab/Decitabine_treatment/RNA-seq/hl60-stbl/counts/6h_DMSO_rep1_exons.txt
# [INFO   ]         multiqc : Searching   : /rumi/shams/abe/Gilbertlab/Decitabine_treatment/RNA-seq/hl60-stbl/counts/6h_DMSO_rep1_exons.txt.summary
# [INFO   ]         multiqc : Searching   : /rumi/shams/abe/Gilbertlab/Decitabine_treatment/RNA-seq/hl60-stbl/counts/6h_DMSO_rep2_exons.ol.txt
# [INFO   ]         multiqc : Searching   : /rumi/shams/abe/Gilbertlab/Decitabine_treatment/RNA-seq/hl60-stbl/counts/6h_DMSO_rep2_exons.txt
# [INFO   ]         multiqc : Searching   : /rumi/shams/abe/Gilbertlab/Decitabine_treatment/RNA-seq/hl60-stbl/counts/6h_DMSO_rep2_exons.txt.summary
# [INFO   ]         multiqc : Searching   : /rumi/shams/abe/Gilbertlab/Decitabine_treatment/RNA-seq/hl60-stbl/counts/6h_treated_rep1_exons.ol.txt
# [INFO   ]         multiqc : Searching   : /rumi/shams/abe/Gilbertlab/Decitabine_treatment/RNA-seq/hl60-stbl/counts/6h_treated_rep1_exons.txt
# [INFO   ]         multiqc : Searching   : /rumi/shams/abe/Gilbertlab/Decitabine_treatment/RNA-seq/hl60-stbl/counts/6h_treated_rep1_exons.txt.summary
# [INFO   ]         multiqc : Searching   : /rumi/shams/abe/Gilbertlab/Decitabine_treatment/RNA-seq/hl60-stbl/counts/6h_treated_rep2_exons.ol.txt
# [INFO   ]         multiqc : Searching   : /rumi/shams/abe/Gilbertlab/Decitabine_treatment/RNA-seq/hl60-stbl/counts/6h_treated_rep2_exons.txt
# [INFO   ]         multiqc : Searching   : /rumi/shams/abe/Gilbertlab/Decitabine_treatment/RNA-seq/hl60-stbl/counts/6h_treated_rep2_exons.txt.summary
# [INFO   ]         multiqc : Searching   : /rumi/shams/abe/Gilbertlab/Decitabine_treatment/RNA-seq/hl60-stbl/counts/72h_DMSO_rep1_exons.ol.txt
# [INFO   ]         multiqc : Searching   : /rumi/shams/abe/Gilbertlab/Decitabine_treatment/RNA-seq/hl60-stbl/counts/72h_DMSO_rep1_exons.txt
# [INFO   ]         multiqc : Searching   : /rumi/shams/abe/Gilbertlab/Decitabine_treatment/RNA-seq/hl60-stbl/counts/72h_DMSO_rep1_exons.txt.summary
# [INFO   ]         multiqc : Searching   : /rumi/shams/abe/Gilbertlab/Decitabine_treatment/RNA-seq/hl60-stbl/counts/72h_DMSO_rep2_exons.ol.txt
# [INFO   ]         multiqc : Searching   : /rumi/shams/abe/Gilbertlab/Decitabine_treatment/RNA-seq/hl60-stbl/counts/72h_DMSO_rep2_exons.txt
# [INFO   ]         multiqc : Searching   : /rumi/shams/abe/Gilbertlab/Decitabine_treatment/RNA-seq/hl60-stbl/counts/72h_DMSO_rep2_exons.txt.summary
# [INFO   ]         multiqc : Searching   : /rumi/shams/abe/Gilbertlab/Decitabine_treatment/RNA-seq/hl60-stbl/counts/72h_treated_rep1_exons.ol.txt
# [INFO   ]         multiqc : Searching   : /rumi/shams/abe/Gilbertlab/Decitabine_treatment/RNA-seq/hl60-stbl/counts/72h_treated_rep1_exons.txt
# [INFO   ]         multiqc : Searching   : /rumi/shams/abe/Gilbertlab/Decitabine_treatment/RNA-seq/hl60-stbl/counts/72h_treated_rep1_exons.txt.summary
# [INFO   ]         multiqc : Searching   : /rumi/shams/abe/Gilbertlab/Decitabine_treatment/RNA-seq/hl60-stbl/counts/72h_treated_rep2_exons.ol.txt
# [INFO   ]         multiqc : Searching   : /rumi/shams/abe/Gilbertlab/Decitabine_treatment/RNA-seq/hl60-stbl/counts/72h_treated_rep2_exons.txt
# [INFO   ]         multiqc : Searching   : /rumi/shams/abe/Gilbertlab/Decitabine_treatment/RNA-seq/hl60-stbl/counts/72h_treated_rep2_exons.txt.summary
# Searching 36 files..  [####################################]  100%
# [INFO   ]  feature_counts : Found 12 reports
# [INFO   ]         multiqc : Compressing plot data
# [INFO   ]         multiqc : Report      : hl60-stbl/counts-exons-multiqc.html
# [INFO   ]         multiqc : Data        : hl60-stbl/counts-exons-multiqc_data
# [INFO   ]         multiqc : MultiQC complete
# [INFO   ]         multiqc : This is MultiQC v1.9
# [INFO   ]         multiqc : Template    : default
# [INFO   ]         multiqc : Searching   : /rumi/shams/abe/Gilbertlab/Decitabine_treatment/RNA-seq/hl60-stbl/counts/120h_DMSO_rep1_Introns.ol.txt
# [INFO   ]         multiqc : Searching   : /rumi/shams/abe/Gilbertlab/Decitabine_treatment/RNA-seq/hl60-stbl/counts/120h_DMSO_rep1_Introns.txt
# [INFO   ]         multiqc : Searching   : /rumi/shams/abe/Gilbertlab/Decitabine_treatment/RNA-seq/hl60-stbl/counts/120h_DMSO_rep1_Introns.txt.summary
# [INFO   ]         multiqc : Searching   : /rumi/shams/abe/Gilbertlab/Decitabine_treatment/RNA-seq/hl60-stbl/counts/120h_DMSO_rep2_Introns.ol.txt
# [INFO   ]         multiqc : Searching   : /rumi/shams/abe/Gilbertlab/Decitabine_treatment/RNA-seq/hl60-stbl/counts/120h_DMSO_rep2_Introns.txt
# [INFO   ]         multiqc : Searching   : /rumi/shams/abe/Gilbertlab/Decitabine_treatment/RNA-seq/hl60-stbl/counts/120h_DMSO_rep2_Introns.txt.summary
# [INFO   ]         multiqc : Searching   : /rumi/shams/abe/Gilbertlab/Decitabine_treatment/RNA-seq/hl60-stbl/counts/120h_treated_rep1_Introns.ol.txt
# [INFO   ]         multiqc : Searching   : /rumi/shams/abe/Gilbertlab/Decitabine_treatment/RNA-seq/hl60-stbl/counts/120h_treated_rep1_Introns.txt
# [INFO   ]         multiqc : Searching   : /rumi/shams/abe/Gilbertlab/Decitabine_treatment/RNA-seq/hl60-stbl/counts/120h_treated_rep1_Introns.txt.summary
# [INFO   ]         multiqc : Searching   : /rumi/shams/abe/Gilbertlab/Decitabine_treatment/RNA-seq/hl60-stbl/counts/120h_treated_rep2_Introns.ol.txt
# [INFO   ]         multiqc : Searching   : /rumi/shams/abe/Gilbertlab/Decitabine_treatment/RNA-seq/hl60-stbl/counts/120h_treated_rep2_Introns.txt
# [INFO   ]         multiqc : Searching   : /rumi/shams/abe/Gilbertlab/Decitabine_treatment/RNA-seq/hl60-stbl/counts/120h_treated_rep2_Introns.txt.summary
# [INFO   ]         multiqc : Searching   : /rumi/shams/abe/Gilbertlab/Decitabine_treatment/RNA-seq/hl60-stbl/counts/6h_DMSO_rep1_Introns.ol.txt
# [INFO   ]         multiqc : Searching   : /rumi/shams/abe/Gilbertlab/Decitabine_treatment/RNA-seq/hl60-stbl/counts/6h_DMSO_rep1_Introns.txt
# [INFO   ]         multiqc : Searching   : /rumi/shams/abe/Gilbertlab/Decitabine_treatment/RNA-seq/hl60-stbl/counts/6h_DMSO_rep1_Introns.txt.summary
# [INFO   ]         multiqc : Searching   : /rumi/shams/abe/Gilbertlab/Decitabine_treatment/RNA-seq/hl60-stbl/counts/6h_DMSO_rep2_Introns.ol.txt
# [INFO   ]         multiqc : Searching   : /rumi/shams/abe/Gilbertlab/Decitabine_treatment/RNA-seq/hl60-stbl/counts/6h_DMSO_rep2_Introns.txt
# [INFO   ]         multiqc : Searching   : /rumi/shams/abe/Gilbertlab/Decitabine_treatment/RNA-seq/hl60-stbl/counts/6h_DMSO_rep2_Introns.txt.summary
# [INFO   ]         multiqc : Searching   : /rumi/shams/abe/Gilbertlab/Decitabine_treatment/RNA-seq/hl60-stbl/counts/6h_treated_rep1_Introns.ol.txt
# [INFO   ]         multiqc : Searching   : /rumi/shams/abe/Gilbertlab/Decitabine_treatment/RNA-seq/hl60-stbl/counts/6h_treated_rep1_Introns.txt
# [INFO   ]         multiqc : Searching   : /rumi/shams/abe/Gilbertlab/Decitabine_treatment/RNA-seq/hl60-stbl/counts/6h_treated_rep1_Introns.txt.summary
# [INFO   ]         multiqc : Searching   : /rumi/shams/abe/Gilbertlab/Decitabine_treatment/RNA-seq/hl60-stbl/counts/6h_treated_rep2_Introns.ol.txt
# [INFO   ]         multiqc : Searching   : /rumi/shams/abe/Gilbertlab/Decitabine_treatment/RNA-seq/hl60-stbl/counts/6h_treated_rep2_Introns.txt
# [INFO   ]         multiqc : Searching   : /rumi/shams/abe/Gilbertlab/Decitabine_treatment/RNA-seq/hl60-stbl/counts/6h_treated_rep2_Introns.txt.summary
# [INFO   ]         multiqc : Searching   : /rumi/shams/abe/Gilbertlab/Decitabine_treatment/RNA-seq/hl60-stbl/counts/72h_DMSO_rep1_Introns.ol.txt
# [INFO   ]         multiqc : Searching   : /rumi/shams/abe/Gilbertlab/Decitabine_treatment/RNA-seq/hl60-stbl/counts/72h_DMSO_rep1_Introns.txt
# [INFO   ]         multiqc : Searching   : /rumi/shams/abe/Gilbertlab/Decitabine_treatment/RNA-seq/hl60-stbl/counts/72h_DMSO_rep1_Introns.txt.summary
# [INFO   ]         multiqc : Searching   : /rumi/shams/abe/Gilbertlab/Decitabine_treatment/RNA-seq/hl60-stbl/counts/72h_DMSO_rep2_Introns.ol.txt
# [INFO   ]         multiqc : Searching   : /rumi/shams/abe/Gilbertlab/Decitabine_treatment/RNA-seq/hl60-stbl/counts/72h_DMSO_rep2_Introns.txt
# [INFO   ]         multiqc : Searching   : /rumi/shams/abe/Gilbertlab/Decitabine_treatment/RNA-seq/hl60-stbl/counts/72h_DMSO_rep2_Introns.txt.summary
# [INFO   ]         multiqc : Searching   : /rumi/shams/abe/Gilbertlab/Decitabine_treatment/RNA-seq/hl60-stbl/counts/72h_treated_rep1_Introns.ol.txt
# [INFO   ]         multiqc : Searching   : /rumi/shams/abe/Gilbertlab/Decitabine_treatment/RNA-seq/hl60-stbl/counts/72h_treated_rep1_Introns.txt
# [INFO   ]         multiqc : Searching   : /rumi/shams/abe/Gilbertlab/Decitabine_treatment/RNA-seq/hl60-stbl/counts/72h_treated_rep1_Introns.txt.summary
# [INFO   ]         multiqc : Searching   : /rumi/shams/abe/Gilbertlab/Decitabine_treatment/RNA-seq/hl60-stbl/counts/72h_treated_rep2_Introns.ol.txt
# [INFO   ]         multiqc : Searching   : /rumi/shams/abe/Gilbertlab/Decitabine_treatment/RNA-seq/hl60-stbl/counts/72h_treated_rep2_Introns.txt
# [INFO   ]         multiqc : Searching   : /rumi/shams/abe/Gilbertlab/Decitabine_treatment/RNA-seq/hl60-stbl/counts/72h_treated_rep2_Introns.txt.summary
# Searching 36 files..  [####################################]  100%
# [INFO   ]  feature_counts : Found 12 reports
# [INFO   ]         multiqc : Compressing plot data
# [INFO   ]         multiqc : Report      : hl60-stbl/counts-introns-multiqc.html
# [INFO   ]         multiqc : Data        : hl60-stbl/counts-introns-multiqc_data
# [INFO   ]         multiqc : MultiQC complete

# %%
# !multiqc hl60-exp/scallop/ -n hl60-exp/scallop-multiqc.html
# Out:
# [INFO   ]         multiqc : This is MultiQC v1.9
# [INFO   ]         multiqc : Template    : default
# [INFO   ]         multiqc : Searching   : /rumi/shams/abe/Gilbertlab/Decitabine_treatment/RNA-seq/hl60-exp/scallop
# Searching 340 files..  [####################################]  100%
# [INFO   ]          salmon : Found 12 meta reports
# [INFO   ]          salmon : Found 12 fragment length distributions
# [INFO   ]         multiqc : Compressing plot data
# [INFO   ]         multiqc : Report      : hl60-exp/scallop-multiqc.html
# [INFO   ]         multiqc : Data        : hl60-exp/scallop-multiqc_data
# [INFO   ]         multiqc : MultiQC complete
