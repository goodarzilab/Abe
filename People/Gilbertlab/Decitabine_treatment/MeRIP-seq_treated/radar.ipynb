# %% [markdown]
# using [RADAR](https://scottzijiezhang.github.io/RADARmanual/workflow.html) for analysis.
#
# # Pre-processing and QC
# <img src="radar/boxPlot.png" style="width:600px">
#
# <table>
#   <tr>
#     <td><img src="radar/PCAPlot.png" style="width:400px">
#     <td><img src="radar/peakDistribution.png" style="width:400px">
#   <tr>
# <table>
#
#
#
# # Differential methylation
# Global analysis show significant hyper-methylation camparing treated vs. untreated.
# <table>
#   <tr>
#     <td><img src="radar/peak_Volcanos.png" style="width:500px">
#     <td><img src="radar/peak_Histograms.png" style="width:500px">
#   <tr>
# <table>
#
#
# ### exp. ZNF93 peak
# <img src="radar/top_peak.png" style="width:400px">

# %% [markdown]
# # iPAGE
#
# ### c1
# <img src="radar/plots/ipage.d_mtyl_T_vs_U_human_c1_gs.png" title="c1" style="width:600px">
#
# ### c2
# <img src="radar/plots/ipage.d_mtyl_T_vs_U_human_c2_gs.png" title="c2" style="width:600px">
#
# ### c3
# <img src="radar/plots/ipage.d_mtyl_T_vs_U_human_c3_gs.png" title="c3" style="width:600px">
#
# ### c4
# <img src="radar/plots/ipage.d_mtyl_T_vs_U_human_c4_gs.png" title="c4" style="width:600px">
#
# ### c5
# <img src="radar/plots/ipage.d_mtyl_T_vs_U_human_c5_gs.png" title="c5" style="width:600px">
#
# ### c7
# <img src="radar/plots/ipage.d_mtyl_T_vs_U_human_c7_gs.png" title="c7" style="width:600px">
#
# ### gs_RBPs_by_3UTR
# <img src="radar/plots/ipage.d_mtyl_T_vs_U_human_gs_RBPs_by_3UTR.png" title="gs_RBPs_by_3UTR" style="width:600px">

# %%
cat radar/code.R
# Out:
# library(RADAR)
# setwd('~/People/Gilbertlab/Decitabine_treatment/MeRIP-seq_treated/')
# # load bam files
# radar <- countReads(samplenames=c('T1','T2','U1','U2'), gtf = "/rumi/shams/genomes/hg38/hg38_genes.gtf",bamFolder='./bam/',modification = "m6A", strandToKeep = "opposite",outputDir='radar', threads = 18)
#
# saveRDS(radar, 'radar/raw.rds')
#
# pdf('radar/boxPlot.pdf')
# radar <- normalizeLibrary(radar)
# dev.off()
# png('radar/boxPlot.png')
# radar <- normalizeLibrary(radar)
# dev.off()
#
# radar <- adjustExprLevel(radar)
#
# variable(radar) <- data.frame( Group = c(rep("T",2),rep("U",2)) )
#
# radar <- filterBins(radar,minCountsCutOff = 15)
# radar <- diffIP_parallel(radar, thread = 8)
# top_bins <- extractIP(radar,filtered = T)[order(rowMeans( extractIP(radar,filtered = T) ),decreasing = T)[1:1000],]
#
# png('radar/PCAPlot.png')
# plotPCAfromMatrix(top_bins,group = unlist(variable(radar)) )
# dev.off()
# pdf('radar/PCAPlot.pdf')
# ...

# %%
# !cat radar/d_mtyl_T_vs_U.txt | awk 'NR>1{print $5"\t"$14}' > radar/d_mtyl_T_vs_U.c.txt
# select hypo and hyper-methylation gene set
